# %% [markdown]
# <a href="https://colab.research.google.com/github/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/Molecular%20Generative%20Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download a utils.py file containing some utility functions we will need
# !wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/utils.py -O utils.py
# download the pre-trained RNN model
# !wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/pretrained.zinc.rnn.pth -O pretrained.rnn.pth
# download the pre-trained VAE model
# !wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/pretrained.vae.pt -O pretrained.vae.pt
# clone RNN generative model repository
# !git clone https://github.com/rociomer/dl-chem-101.git
# download the RNN training data
# !wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/zinc.smi -O zinc.smi
# clone repository to extract the compressed molecular data
# !git clone https://github.com/aksub99/molecular-vae.git
import zipfile
zip_ref = zipfile.ZipFile('molecular-vae/data/processed.zip', 'r')
zip_ref.extractall('molecular-vae/data/')
zip_ref.close()
# Out:
# --2024-10-29 13:22:57--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2031 (2.0K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   1.98K  --.-KB/s    in 0s
#
# 2024-10-29 13:22:57 (24.1 MB/s) - ‘utils.py’ saved [2031/2031]
#
# --2024-10-29 13:22:57--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/pretrained.zinc.rnn.pth
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25454495 (24M) [application/octet-stream]
# Saving to: ‘pretrained.rnn.pth’
#
# pretrained.rnn.pth  100%[===================>]  24.27M   137MB/s    in 0.2s
#
# 2024-10-29 13:22:58 (137 MB/s) - ‘pretrained.rnn.pth’ saved [25454495/25454495]
#
# --2024-10-29 13:22:58--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/pretrained.vae.pt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18455963 (18M) [application/octet-stream]
# Saving to: ‘pretrained.vae.pt’
#
# pretrained.vae.pt   100%[===================>]  17.60M  87.5MB/s    in 0.2s
#
# 2024-10-29 13:22:59 (87.5 MB/s) - ‘pretrained.vae.pt’ saved [18455963/18455963]
#
# Cloning into 'dl-chem-101'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 342 (delta 61), reused 42 (delta 16), pack-reused 219 (from 1)
# Receiving objects: 100% (342/342), 95.87 MiB | 29.07 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# --2024-10-29 13:23:05--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/generative_models/notebooks/05%20-%20Generative%20Models/data/zinc.smi
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2555340 (2.4M) [text/plain]
# Saving to: ‘zinc.smi’
#
# zinc.smi            100%[===================>]   2.44M  --.-KB/s    in 0.09s
#
# 2024-10-29 13:23:05 (25.8 MB/s) - ‘zinc.smi’ saved [2555340/2555340]
#
# Cloning into 'molecular-vae'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 188 (delta 0), reused 1 (delta 0), pack-reused 185 (from 1)
# Receiving objects: 100% (188/188), 2.99 MiB | 16.18 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# ------------------------------------------------------------------------------------
# WARNING: wait to run this cell - let us know when the above cell is finished running
# ------------------------------------------------------------------------------------

# need to install the RNN repository as a package
# %cd dl-chem-101
# %cd 03_gen_SMILES_LSTM
# !pip install -e .
# Out:
# /content/dl-chem-101
# /content/dl-chem-101/03_gen_SMILES_LSTM
# Obtaining file:///content/dl-chem-101/03_gen_SMILES_LSTM
#   Preparing metadata (setup.py) ... done
# Installing collected packages: smiles_lstm
#   Running setup.py develop for smiles_lstm
# Successfully installed smiles_lstm-1.0.0

# %%
# install other packages required
# !pip install rdkit
# !pip install molplotly
# !pip install torch
# !pip install numpy
# !pip install scikit-learn
# !pip install h5py
# Out:
# Collecting rdkit
#   Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (10.4.0)
# Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 18.3 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.3.5
# Collecting molplotly
#   Downloading molplotly-1.1.8.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Discarding https://files.pythonhosted.org/packages/39/40/c0d86942ba668d975570a0fbd7fe4224445198a90a64ec6f0c1cd3bf2527/molplotly-1.1.8.tar.gz (from https://pypi.org/simple/molplotly/): Requested molplotly from https://files.pythonhosted.org/packages/39/40/c0d86942ba668d975570a0fbd7fe4224445198a90a64ec6f0c1cd3bf2527/molplotly-1.1.8.tar.gz has inconsistent version: expected '1.1.8', but metadata has '1.1.7'
#   Downloading molplotly-1.1.7.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dash>=2.0.0 (from molplotly)
#   Downloading dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from molplotly) (3.0.4)
# Collecting jupyter-dash>=0.4.2 (from molplotly)
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from molplotly) (5.24.1)
# Collecting rdkit-pypi>=2021.9.4 (from molplotly)
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from molplotly) (2.2.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from molplotly) (5.5.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from molplotly) (5.10.4)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (2.2.5)
# Collecting dash-html-components==2.0.0 (from dash>=2.0.0->molplotly)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.0.0->molplotly)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.0.0->molplotly)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (2.32.3)
# Collecting retrying (from dash>=2.0.0->molplotly)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash>=2.0.0->molplotly) (75.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->molplotly) (7.34.0)
# Collecting ansi2html (from jupyter-dash>=0.4.2->molplotly)
#   Downloading ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->molplotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->molplotly) (24.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi>=2021.9.4->molplotly) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi>=2021.9.4->molplotly) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=2.0.0->molplotly) (3.0.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->molplotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->molplotly) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->molplotly) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->molplotly) (6.3.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->molplotly) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->molplotly) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat->molplotly) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->molplotly) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->molplotly) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->molplotly) (2024.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->molplotly) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->molplotly) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->molplotly) (8.1.7)
# Collecting jedi>=0.16 (from ipython->jupyter-dash>=0.4.2->molplotly)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash>=0.4.2->molplotly) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->molplotly) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->molplotly) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->molplotly) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->molplotly) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->molplotly) (4.3.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->molplotly) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash>=2.0.0->molplotly) (3.20.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->molplotly) (24.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.0.0->molplotly) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.0.0->molplotly) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.0.0->molplotly) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.0.0->molplotly) (2024.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyter-dash>=0.4.2->molplotly) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jupyter-dash>=0.4.2->molplotly) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash>=0.4.2->molplotly) (0.2.13)
# Downloading dash-2.18.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 49.2 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 44.4 MB/s eta 0:00:00
# Downloading ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.0 MB/s eta 0:00:00
# Building wheels for collected packages: molplotly
#   Building wheel for molplotly (setup.py) ... done
#   Created wheel for molplotly: filename=molplotly-1.1.7-py3-none-any.whl size=14044 sha256=d7119516cdf373ee88ff1c1a3aa4c9873267a6f80b97ed83da1d2768cd3afdb6
#   Stored in directory: /root/.cache/pip/wheels/ae/77/08/2f99e4c8d1010cbfcd58eb3f750405980c4ae9958c8d2fc749
# Successfully built molplotly
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, rdkit-pypi, jedi, ansi2html, dash, jupyter-dash, molplotly
# Successfully installed ansi2html-1.9.2 dash-2.18.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 jedi-0.19.1 jupyter-dash-0.4.2 molplotly-1.1.7 rdkit-pypi-2022.9.5 retrying-1.3.4
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.26.4)

# %%
# %cd ../..
# ***Now restart run-time of the notebook!***
# Out:
# /content

# %% [markdown]
# # Week 5 Tutorial: AI for Chemistry
#
#
# # Molecular Generative Models
#
# In recent years, there has been an explosion in the number of molecular generative models being developed. Regardless of the formulation, these models share some commonalities:
#
# 1. They can generate molecules that are **not** in the training data - therefore, they have the potential to  explore  new chemical space
#
#
# 2. They can be coupled with some optimization algorithm to explicitly tailor the model to generate molecules satisfying some target objective such as possessing high predicted solubility
#
# *You will get the chance to play with [`REINVENT`](https://github.com/MolecularAI/Reinvent) next week which is an open-source SMILES-based generative model developed at AstraZeneca. You will get to choose what properties you want to optimize and see first-hand how the model learns to generate molecules satisfying your specified objective!* 🤠 Here is an example of `REINVENT` in the wild - [Researchers use `REINVENT` to design an experimentally validated nanomolar potent inhibitor](https://chemistry-europe.onlinelibrary.wiley.com/doi/10.1002/cmdc.202000786)
#
# Generative models are not new and have been applied for quite some time especially in the machine learning community. Image generation is a classic example of one such application and is also what gives rise to the cool images you see generated from [Stable Diffusion](https://huggingface.co/spaces/stabilityai/stable-diffusion). Molecular generative models, however, is a less mature field that is seeing rapid progress and wide-spread adoption in industry (pharmaceutical and biotech companies).
#
#
# Below are some early foundational works in the field of molecular generative models (not exhaustive):
# * [Variational Autoencoder (VAE)](https://pubs.acs.org/doi/10.1021/acscentsci.7b00572) this is the first example of using a `VAE`
#
# * [Generative Adversarial Network (GAN)](https://arxiv.org/abs/1805.11973) this is the first example of using a `GAN`
#
# * [Recurrent Neural Network (RNN)](https://pubs.acs.org/doi/10.1021/acscentsci.7b00512) this is one of the first examples of using a `RNN`
#
# * Recurrent Neural Network (RNN) with Reinforcement Learning (RL): [Link 1](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-017-0235-x) [Link 2](https://www.science.org/doi/10.1126/sciadv.aap7885) these are also early examples of using a `RNN` but they also couple `RL` to tailor molecular generation towards desired properties
#
#
# In this `Part 1 Tutorial` (Part 2 is next week), we introduce some of these foundational works and play around with how they generate molecules. For each generative model presented, we will provide high level details of what is going on under-the-hood and reference the original paper for details.

# %% [markdown]
# # 1. Recurrent Neural Network (RNN)
#
# #### The code that is imported from `utils` in this section is from [`Rocío Mercado's`](https://rociomer.github.io/) [dl-chem-101 repository](https://github.com/rociomer/dl-chem-101/tree/main/03_gen_SMILES_LSTM)
#
# **Note:** Next week's tutorial has 2 parts: you get to run your own `REINVENT` generative experiment and **we break down step-by-step** into exactly how `REINVENT` (and any SMILES-based generative model) works. For this reason, we do not show any code of the underlying model in this section
#
# For now, a high-level summary is given.
#
# `Recurrent Neural Networks (RNN)` were very popular for `Natural Language Processing (NLP)` (for example, machine learning on sentences to translate between languages). Generally, these models are trained to predict the next "element" (we say "element" here to be very general for this particular analogy). Consider the following sentence:
#
# **It's so hot outside, I want to eat**
#
# **based on the words seen so far, the model predicts the next "element"** A reasonable next "element" would be "ice cream", yielding the sentence:
#
# **It's so hot outside, I want to eat ice cream**
#
# Now, let's think about the `context` of this sentence. It seems reasonable to say that "ice cream" makes sense because it is hot outside. This idea of `context` is important for machine learning models to predict the next "element". Unfortunately, imagine now a very long excerpt containing many paragraphs. It turns out that `RNNs` can struggle to "remember" long `contexts`. More recently, [`Transformers`](https://proceedings.neurips.cc/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf) (`ChatGPT` is a transformer model!) have demonstrated exceptional ability to handle this problem and has now mostly replaced `RNNs` in `NLP`.
#
# Ok, but now let's relate what we just discussed to `Molecular Generative Models`. It turns out that most molecules represented as `SMILES` strings are not really that long and `RNNs` can perfectly learn to predict these relatively short `SMILES` sequences (compared to the example of an excerpt with many paragraphs). Correspondingly, `RNN`-based `Molecular Generative Models` have shown remarkable performance in learning the `SMILES` syntax. Below is an example of a molecule and its `SMILES`: "NC1=CC(O)=CC=C1" (not very long!)
#
# <div align="middle">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/images/smiles-example.png?raw=1" width="200"/>
# </div>

# %% [markdown]
# # 1.1 Claim
#
# In this section, let's make a claim:
#
# **Training a `Molecular Generative Model` is not training a model to generate molecules, per say. Rather, it is to reproduce the underlying probability distribution of the training data**
#
# What does that mean? 🥴
#
# Let's make "predicting the next element" more concrete in the context of chemistry. `SMILES`-based `RNNs` are typically trained to predict the next `token` which loosely maps to individual `atoms`.
#
# Let's look at an intuitive example. Here's `Benzene`:
#
# <div align="middle">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/images/benzene.png?raw=1" width="200"/>
# </div>
#
#
# Here's the `SMILES`: "c1ccccc1"
#
#
# Let's say our model is in the process of generating `Benzene` with this `SMILES` sequence **so far**:
#
# "c1ccccc"
#
# Comparing the answer, we see that we want to generate **"1"** This `token` closes the ring and recovers `Benzene`
#
# Now imagine we have trained a model that can re-generate the entire dataset of `SMILES`. Then implicitly, the model has learned the `SMILES` syntax **and** the properties of molecules it generates overlaps with the training data. Let's convince ourselves of this.

# %% [markdown]
# # 1.2 Is it a Molecular Generative Model or a Mime? 😵‍💫
#
# *Image was generated using [Stable Diffusion](https://stablediffusionweb.com/#demo). The prompt was "high resolution image of a mime doing chemistry"*
#
# <div align="middle">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/images/mime.png?raw=1" width="500"/>
# </div>
#
#
# Let's do some exercises! We have pre-trained a generative model on a small subset of [ZINC](https://zinc.docking.org/) which is a database of molecules.

# %%
# loading in some helper functions (don't worry about the details here for now)
from utils import load_from_file, sample

# %%
# let's begin our dive into gaining a deeper understanding of molecular generative models
# let's load the pre-trained model
pretrained_rnn_model = load_from_file('pretrained.rnn.pth')

# %%
from rdkit import Chem
# ok, let's now generate 1000 molecules from this model
# keep track of the generated molecules
generated_molecules = []

# for now, don't worry about the "sample()" and "tokenizer" code bits
# the pre-trained model provided actually does not generate valid SMILES strings every time
# we essentially keep generating until we get 1000 **valid** molecules

# NOTE: this may take a few minutes 😭
while len(generated_molecules) != 1000:
    # generate token sequences
    sequences, nlls = sample(model=pretrained_rnn_model)
    # convert the token sequences into SMILES
    smiles = pretrained_rnn_model.tokenizer.untokenize(pretrained_rnn_model.vocabulary.decode(sequences[0].numpy()))
    # transform the generated SMILES into RDKit Mol objects
    # the Mol object is "None" if the SMILES cannot be parted by RDKit
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        # at this point, the Mol is valid so let's keep track of it
        generated_molecules.append(mol)

# %% [markdown]
# In the beginning of this notebook, we claim that all `Molecular Generative Models` can generate molecules that are outside the training data. Your first task is to verify this.

# %%
# there is a file called "zinc.smi" in the "data" folder that contains 50000 SMILES strings
# that form the training data for the provided pre-trained model

# with this information, your first task is to check if there is any
# overlap between the SMILES in "zinc.smi" and the generated molecules above

# Task 1: extract the SMILES from "zinc.smi"

### YOUR CODE #####
# Open the file and read its contents
with open('zinc.smi', 'r') as file:
    lines = file.readlines()

# Extract SMILES strings
smiles_list = [line.split()[0] for line in lines]

smiles_list
# Out:
# ['SMILES',
#  'CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1',
#  'N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)cc2)cc1',
#  'CC[NH+](CC)[C@](C)(CC)[C@H](O)c1cscc1Br',
#  'O=C(Nc1nc[nH]n1)c1cccnc1Nc1cccc(F)c1',
#  'Cc1c(/C=N/c2cc(Br)ccn2)c(O)n2c(nc3ccccc32)c1C#N',
#  'C[C@@H]1CN(C(=O)c2cc(Br)cn2C)CC[C@H]1[NH3+]',
#  'CCOc1ccc(OCC)c([C@H]2C(C#N)=C(N)N(c3ccccc3C(F)(F)F)C3=C2C(=O)CCC3)c1',
#  'Cc1ccccc1C(=O)N1CCC2(CC1)C[C@H](c1ccccc1)C(=O)N2C',
#  'CCCc1cc(NC(=O)CN2C(=O)NC3(CCC(C)CC3)C2=O)n(C)n1',
#  'CC(C)Cc1nc(SCC(=O)NC[C@@H]2CCCO2)c2c(=O)n(C)c(=O)n(C)c2n1',
#  'Cc1ccc(CNC(=O)c2ccccc2NC(=O)[C@@H]2CC(=O)N(c3ccc(C)cc3)C2)cc1',
#  'Cc1c(NC(=O)CSc2nc3sc4c(c3c(=O)[nH]2)CCCC4)c(=O)n(-c2ccccc2)n1C',
#  'CC(C)[C@@H](Oc1cccc(Cl)c1)C(=O)N1CCC(n2cccn2)CC1',
#  'CCN(CC)C(=O)C[C@@H](C)[NH2+][C@H](C)c1cccc(F)c1F',
#  'Cc1nc2c(c(Nc3ncc(C)s3)n1)CCN(C(=O)CCc1ccccc1)C2',
#  'O=c1n(CCO)c2ccccc2n1CCO',
#  'Cc1ccc(N2CC[C@@H](NS(=O)(=O)c3ccccc3C)C2=O)cc1C',
#  'CC[C@H](C)C[C@@H](C)NC(=O)N1CCN(CC(=O)NC2CC2)CC1',
#  'CC(=O)Nc1c2n(c3ccccc13)C[C@](C)(C(=O)NC1CCCCC1)N(C1CCCCC1)C2=O',
#  'N#Cc1ccncc1NC[C@@H]1C[C@@]12CCc1ccccc12',
#  'Cc1cccn2c(=O)c(C(=O)NC[C@H]3CCO[C@@H]3C(C)C)cnc12',
#  'C[C@@H](NC(=O)COC(=O)/C=C/c1ccc(Cl)cc1)c1ccccc1',
#  'O=C(O[C@H]1CCOC1)C1(c2ccc(Cl)c(Cl)c2)CCC1',
#  'CCC[NH2+][C@@H]1COC[C@H]1C(=O)NCc1cscc1C',
#  'O=C(NCc1nccc2ccccc12)c1ccc[nH]c1=O',
#  'CC(=O)c1ccc(S(=O)(=O)N2CCCC[C@H]2C)cc1',
#  'O=[N+]([O-])c1c(Nc2cccc3ncccc23)ncnc1N1CCN(c2cccc(Cl)c2)CC1',
#  'NC(=O)CCOc1ccc(NC(=O)C[C@H]2CCc3ccccc32)cc1',
#  'COc1cc(C)ccc1OCC(=O)Nc1nnc(C)s1',
#  'CCn1cc(S(=O)(=O)N2CCCCC[C@@H]2c2cc(-c3ccc(F)cc3)no2)cn1',
#  'COC(=O)[C@](NC(=O)c1cccc(Cl)c1)(Nc1ccc(Br)c[nH+]1)C(F)(F)F',
#  'Cc1[nH]c2ccc(C(=O)Nc3cc(C(C)(C)C)nn3-c3ncccn3)cc2c1C',
#  'Cc1noc(C)c1C[C@H](C)C(=O)N[C@@H](C)C1CCCCC1',
#  'COc1cccc(-c2cncc3ccccc23)c1C(=O)N(C(C)C)C(C)C',
#  'O=C1C[C@H](c2nc(-c3cccnc3)no2)CN1c1cccc(Cl)c1',
#  'C[C@H]1CCCN(c2ccc(C(=O)Nc3ccc(N4CCOCC4)cc3)cc2[N+](=O)[O-])C1',
#  'C=CCN(C(=O)C/C=C/c1ccc(C)cc1)[C@@H]1CCS(=O)(=O)C1',
#  'O=C(CSc1nnc(-c2cccc([N+](=O)[O-])c2)o1)Nc1nncs1',
#  'CN(CCc1ccc(F)cc1)c1cc(Br)cc(F)c1C(N)=O',
#  'COc1ccccc1NC(=O)CSc1ccc(-c2ccccc2OC)nn1',
#  'Cc1occc1C(=O)/C(C#N)=C\\c1cccc(C(F)(F)F)c1',
#  'COc1ccc2c(c1)N(C(=O)CCSc1ccccn1)C[C@@H](C)O2',
#  'CC[C@@H](NC(=O)[C@H](C)n1cccn1)c1ccc(C)c(F)c1',
#  'CCC[C@]1(C(=O)N[C@@H]2CONC2=O)CC[NH2+]C1',
#  'O=C(c1cc2cc([N+](=O)[O-])ccc2oc1=O)N1CCN(Cc2ccccc2)CC1',
#  'CCn1c(CC2CC[NH2+]CC2)nn(CCO)c1=O',
#  'C=CCn1c(S[C@H](C)C(=O)N2CCC(C)CC2)nnc1-c1ccc(Cl)cc1',
#  'CCO[C@H]1C(=O)O[C@H]([C@@H](O)CO)C1=O',
#  'Cc1cc(-n2c(C)cc(C[NH2+][C@H](C)c3ccc(F)c(F)c3)c2C)no1',
#  'C[C@@H](NC(=O)Nc1ccn(-c2ncccc2Cl)n1)[C@@H]1CCCO1',
#  'COc1ccc([C@@H](NC(=O)Nc2cc(C)ccc2Cl)C2CCOCC2)cc1',
#  'C[C@H](Cc1cccs1)N(C)C[C@@H]1CCCC[C@@H]1[NH3+]',
#  'C[C@H]([NH3+])c1nc2cc(C(F)(F)F)ccc2n1C',
#  'COc1cccc(CN2CCc3nnc(CCc4ccccc4)n3CC2)c1',
#  'O=C(N[C@H]1CCS(=O)(=O)C1)C1CC[NH2+]CC1',
#  'C[C@H](CNC(=O)[C@H]1CC[NH2+][C@@H]1C)C[NH+]1CCCC1',
#  'CN(C)c1ccc([C@H](CNC(=O)C(=O)Nc2ccccc2C#N)N2CC[NH+](C)CC2)cc1',
#  'CCOc1ncnc(S(=O)(=O)CC)c1N',
#  'O=C(Nc1ccc(-c2nc3ccccc3o2)cc1)[C@H]1CCCN1S(=O)(=O)c1ccc(F)cc1',
#  'CC[C@@H](C)CNc1nc2ccc(Cl)cc2s1',
#  'Cc1cc(C)c2nc(N3CCN(C(=O)[C@@H]4CCCCN4S(C)(=O)=O)CC3)sc2c1',
#  'CCc1nnc(-c2cc3ccccc3n2CC(=O)NC(C)(C)C)o1',
#  'CCc1ccc(NC(=O)c2nn(-c3ccc(CC)cc3)ccc2=O)cc1',
#  'C[C@H](OC(=O)c1nc(C2CC2)n2ccccc12)c1cnc2ccccc2c1',
#  'C[C@H]1C(=O)N(c2ccc3c(c2)CCC3)CCN1C(=O)c1ccc(Cl)c(Cl)c1',
#  'COC(=O)C1(NC(=O)[C@H]2C[C@H]2c2c(F)cccc2F)CCSCC1',
#  'N#CC1(NC(=O)COc2cccc(Cl)c2)CCCC1',
#  'COC1CC[NH+](CCNc2nccn(C)c2=O)CC1',
#  'C=CCN(Cc1cccc([N+](=O)[O-])c1)C(=O)Nc1cc(OC)ccc1Cl',
#  'Cc1cc(Cl)ccc1OCC(=O)N/N=C/c1ccccn1',
#  'O=C1NC(=S)NC(=O)C1=CNc1ccc([N+](=O)[O-])cc1O',
#  'Cc1c(C(=O)N2CCOCC2)oc2c1-c1nn(CC(=O)NCc3ccco3)cc1CC2',
#  'CCc1ccc(CNC(=O)c2ccc(-c3nccnc3N3CCCCC3)cc2)cc1',
#  'O=[N+]([O-])c1c(Nc2ccc(F)c(F)c2)ncnc1Oc1cccc2cccnc12',
#  'Cc1ccc([C@@H](C)NC(=O)N[C@@H](CCO)c2cccs2)cc1',
#  'CS(=O)(=O)[C@H]1O[C@H]1c1ccc(Cl)cc1Cl',
#  'C[C@H](CSc1ccc(C(=O)N(C)C)cn1)C(=O)[O-]',
#  'CCC[NH2+]C1CCC(O)(Cc2nc(C)cs2)CC1',
#  'O=C1c2ccccc2N[C@H](CSC2=NC=NC3=NC=N[C@@H]32)N1c1ccc(Cl)cc1',
#  'CCc1nc2ccccc2c(C(=O)NCc2ccc(OC)c(C(=O)OC)c2)c1C',
#  'CC(C)NC(=O)Nc1cccc(C(=O)N(C)Cc2nnc(C3CC3)n2C)c1',
#  'Cc1nnccc1C(=O)N[C@H](C)c1ccc(Cl)s1',
#  'CCC1(CC)[C@@H](NC(=O)Nc2ccc(C(=O)NC)cc2)[C@H](C)[C@@H]1OC',
#  'Cc1ccc2ncc(C(=O)Nc3ncccc3OCc3ccncc3)n2c1',
#  'COc1cccc(COc2ccc(OC)cc2CCl)c1',
#  'CC[C@H](NC(=O)NCc1c(C)noc1C)c1ccc(OC)cc1',
#  'CCc1c(C(=O)Nc2ccc3c(c2)NC(=O)CS3)[nH]c(C)c1C(C)=O',
#  'Cc1cccc(C(=O)N[C@@H](C(=O)N2CCC[C@@H](C)C2)C(C)C)c1',
#  'Cc1cnc(C(=O)Nc2ccc(N(C)C3CC[NH+](C)CC3)cc2)cn1',
#  'CC(=O)Nc1nc2ccc(NC(=O)NCc3ccccc3)cc2s1',
#  'C=CCN1C(=O)/C(=C/c2ccccc2F)S/C1=N\\S(=O)(=O)c1cccs1',
#  'CC[C@H]1CC(=O)N(Cc2ccccc2C#CCCO)C1',
#  'COc1ccc(F)cc1C(=O)Nc1nccs1',
#  'CC[C@@H](CC(=O)NC1(C(=O)OC)CCSCC1)c1ccccc1',
#  'CC[C@@H](C)[C@@H]([NH3+])c1ccc(Cl)s1',
#  'COc1cccc([C@@H](C)[NH2+]CCOc2ncccc2Cl)c1',
#  'CCOc1cccc(NC(=O)NCc2ccc(N3CCSCC3)cc2)c1',
#  'Cc1cccc(NC(=O)CN2CCN(c3ccc4c(c3)OCCO4)C2=O)n1',
#  'C=C(C)C(=O)N[C@H](C)c1nc2ccccc2n1CCC(=O)N1CCCCCC1',
#  'CCOC[C@H]1CC[NH+](Cc2ccc(-c3nc4ccccc4s3)o2)C1',
#  'CCOC(=O)[C@]1(Cc2cccc(Cl)c2)CCCN(C(=O)c2ccnn2C)C1',
#  'CCOCCCNC(=O)N[C@@H]1CCC[C@@H](CC)C1',
#  'COc1ccccc1NC(=O)[C@@H]1CCCN(C(=O)Nc2cccs2)C1',
#  'C[C@H]1CCC[C@](C#N)([C@]2(O)CCCCC2(C)C)C1',
#  'O=C(NCc1ccc([N+]2=CCCC2)cc1)NC1(c2ccc(Cl)cc2)CC1',
#  'CCCC(=O)N[C@@H]1CCC[NH+](Cc2ncccc2C)C1',
#  'O=C(NCc1cccs1)C1(c2cccc(Cl)c2)CCC1',
#  'C[C@H]1CCC[C@H](NC(=O)[C@@H](C)Sc2ncn[nH]2)[C@@H]1C',
#  'COc1ccc([C@@H]([NH2+]Cc2ccc(Cl)nc2)c2ccc(F)cc2)cc1',
#  'COc1cc(NC(=O)[C@H](C)Sc2ccccc2Cl)cc(OC)c1',
#  'CCN1CCC(=NNC(=O)c2ccccc2)CC1',
#  'CCCOc1ccc(Br)cc1C[NH+]1CCC([C@@H](C)O)CC1',
#  'Cc1cc2n(C[C@H](O)CO[C@H](c3ccccc3)c3ccccc3C)c(=O)c3ccccc3n2n1',
#  'CCc1ncc(CN(C)C(=O)Nc2c(C)ccc([N+](=O)[O-])c2C)s1',
#  'Cc1c([C@H](C)[NH2+]Cc2cccn2C)cnn1C',
#  'CC(=O)N[C@@H](C(=O)NC1COC1)C(C)C',
#  'Cc1ccccc1N1C(=O)/C(=C/c2cccn2-c2cccc([N+](=O)[O-])c2)C([O-])=NC1=S',
#  'COCCN1C[C@H](C(=O)N(Cc2cccc(Cl)c2)C(C)C)CC1=O',
#  'COc1ccc(NC(=O)N2CCN(C(=O)Cc3csc4ccccc34)CC2)cc1OC',
#  'COCCCN1C(=O)c2ccc(C(=O)Nc3nc(-c4ccc(C)cc4)cs3)cc2C1=O',
#  'O=S(=O)(Nc1ccc(N2CCCS2(=O)=O)cc1)c1ccc(F)c(Cl)c1',
#  'O=C1/C(=C/c2ccccc2)Oc2c1ccc1c2CN(Cc2cccs2)CO1',
#  'CC[C@@H](C)[C@@H](NC(=O)c1cccc(F)c1)C(=O)N=c1[nH]c2ccccc2[nH]1',
#  'CCOC(=O)C(C)(C)c1nc(-c2ccccc2)no1',
#  'C[C@@H]1CC[C@@H]([NH2+]C2CCC(NS(C)(=O)=O)CC2)c2ccccc21',
#  'CN(C)S(=O)(=O)c1ccc(C(=O)N(C(=O)N2CCCCC2)c2ccccc2)cc1',
#  'C=CCOC(=O)C1=C(C)N=C2S[C@H](C)C(=O)N2[C@H]1c1ccc(F)cc1',
#  'CCC[NH2+][C@]1(C(=O)OCC)CC[C@H](n2cc(Cl)c(C)n2)C1',
#  'Cc1cc(NC(=O)CSc2nnc3c4ccccc4n(C)c3n2)ccc1Br',
#  'CC#CCC(=O)C1([NH+](CC)CC)CCCC1',
#  'O=C(NCCCc1ccccc1)C1CCN(C(=O)[C@@H]2CC(=O)N(c3ccccc3)C2)CC1',
#  'O=Cc1ccc(OCc2ccn(-c3cccc(F)c3)n2)cc1',
#  'Clc1ccccc1Cn1ccnc1',
#  'Cc1[nH]c(=O)c(C(=O)N2CCN(c3ccccc3)C(=O)C2)c(C)c1C',
#  'C[C@@H](NC(=O)NC[C@H]1CCCN(c2ncccn2)C1)C1CCOCC1',
#  'CCc1ccc(-c2nc(C(=O)N3CCO[C@H](CC)C3)cs2)cc1',
#  'Cc1cc(C)cc(OCC(C)(C)C[NH2+]C2CC2)c1',
#  'CCOC(=O)[C@H](F)[C@@]1(O)CCC[NH+](C(C)C)CC1',
#  'CCn1cc(/C=C/C(=O)c2ccc3ccccc3c2)cn1',
#  'CCC(CC)C(=O)Nc1cnn(-c2ccccc2F)c1',
#  'O=C1O[C@H](C(=O)Nc2ccnc3ccnn23)Cc2ccccc21',
#  'COCCn1nnnc1[C@@H](C(C)C)N1CCSCC1',
#  'Cc1ccc(CNC(=O)NCc2nnc3n2CCC3)s1',
#  'O=C(N[C@@H](CO)c1ccco1)c1cc(Cl)ccc1OC1CCCC1',
#  'CCOC(=O)c1cccc(NC(=O)c2cn[nH]c2C)c1',
#  'CCC(CC)[S@](=O)CCC(=O)[O-]',
#  'O=C(CCc1nc2ccccc2c(=O)[nH]1)Nc1cc(Cl)c(Cl)cc1Cl',
#  'COc1ccc(C)cc1-n1nnnc1SCC(=O)Nc1cc(C)cc(C)c1',
#  'C[C@H](NC(=O)Cc1ccc[nH]1)C(=O)N1CCCC[C@H]1C',
#  'CCOC(=O)[C@H]1CCCN(C(=O)c2cc(C(C)C)n(C)n2)C1',
#  'C[C@H]([NH2+]Cc1nc(Cc2ccccc2)no1)[C@@H](C)n1cccn1',
#  'c1cc(CN2CC[NH+](Cc3ccc4c(c3)OCCO4)CC2)no1',
#  'CCCCNC(=O)CCc1c(C)nc2c3ccccc3nn2c1C',
#  'O=C(C[C@@H]1C[NH2+]CCO1)N[C@H]1C=CS(=O)(=O)C1',
#  'CCC[NH2+][C@H](Cc1nn(C)c2ccccc12)c1ncc[nH]1',
#  'CC(C)c1noc(-c2cc[nH+]c(N3CCN(C(=O)[C@H]4C[C@H]4C)CC3)c2)n1',
#  'O=C(NCc1cccnc1)NCc1ccnc(OCC(F)F)c1',
#  'C[C@@H](NC(=O)N1CCCCCCC1)[C@@H]1CCCO1',
#  'COc1ccc([C@H]2C(C(=O)NCc3ccccc3)=C(C)Nc3ncnn32)cc1OC',
#  'Cc1cc(=O)n2c(n1)SC[C@@H]2CC(=O)NCCC(C)C',
#  'CC(C)C1=CN=N[C@H]1[C@H]1CCC[NH+](C[C@@H](C)Cc2ccc3c(c2)OCO3)C1',
#  'COc1cc(CNC(=O)c2occc2Br)ccn1',
#  'Cc1cccc(COc2ccc(Br)cc2/C=C2\\SC(=S)NC2=O)c1',
#  'O=C(N[C@@H]1CCO[C@@H]1c1ccc(Cl)c(F)c1)[C@H]1Cc2ccccc2O1',
#  'Cc1ccc([C@]2([NH3+])CC[C@@H]2C)cc1',
#  'O=C(CNC(=O)c1ccco1)OCC(=O)c1ccc2ccccc2c1',
#  'O=C(c1cc2c(F)cccc2[nH]1)N(C[C@@H]1CCCO1)c1ccncc1',
#  'Cc1cc(C)c(NC(=O)c2cc3ccccc3n2C)c(C)c1',
#  'CSc1ccccc1NC(=O)N[C@@H](CO)c1ccc(Cl)cc1',
#  'Cc1cc(Br)ccc1CNC(=O)C1CC=CC1',
#  'O=C(COC(=O)C1(c2ccccc2F)CCCC1)N1CCOCC1',
#  'C[C@@H]([C@@H](O)c1ccc2ncnn2c1)[N+](=O)[O-]',
#  'C[C@H](Oc1ccc(Cl)c(Cl)c1)C(=O)NC[C@H]1CCC[C@@H]1O',
#  'COC[C@H]1CCC[NH+](Cc2cc(C)n(Cc3ccco3)c2C)C1',
#  'Cc1ccc([C@H](C)NC(=O)CN(C)C(=O)OC(C)(C)C)cc1F',
#  'CC(=O)NCCC(=O)N1CCC[C@@H](C)C1',
#  'COc1ccc(N2CCn3c2nn(CC(N)=O)c(=O)c3=O)cc1',
#  'ClC(Cl)(Cl)c1nonc1C(Cl)(Cl)Cl',
#  'CCc1sc(C(=O)N2CCN([C@@H](C(N)=O)c3ccccc3)CC2)cc1C',
#  'C[NH+](C)Cc1cc(NC(=O)CCCC(=O)N2CCCCCC2)[nH]n1',
#  'C[C@@H](Nc1ccc(COC(C)(C)C)cc1)c1ccc(C#N)cc1',
#  'NC(=O)c1ccc(NC(=O)c2cccn(Cc3ccc(F)cc3)c2=O)cc1',
#  'Cc1cc(C(=O)N2CC[C@H](C)C[C@H]2C)c2c(C)nn(C)c2n1',
#  'Cc1c(C(=O)N2CCCC2)oc2c1-c1nn(CC(=O)N3C[C@@H](C)C[C@@H](C)C3)cc1CC2',
#  'Cc1cc(C)cc(NC(=O)CC(C)C)c1',
#  'CCn1ccnc(N2CCCC[C@@H](N3CC[NH+](C)CC3)C2)c1=O',
#  'C[C@@H]1CCC[C@](O)(c2ccc(Cl)s2)CC1',
#  'CCNc1ccc2c(OC)ccc(F)c2n1',
#  'Fc1ccc([C@@H]2C[C@@H](c3ccc(Br)cc3)Nc3ncnn32)cc1Br',
#  'COc1ccc(O)c(CNC2CC[NH+](Cc3ccccc3Cl)CC2)c1',
#  'Cc1ccc(NCc2cccc(C(=O)NCc3ccco3)c2)c(F)c1',
#  'CCOC(=O)[C@H]1CCCN(C(=O)c2cn(CCc3ccccc3)nn2)C1',
#  'C[C@@H]1[C@H](C(=O)[O-])CCN1S(=O)(=O)c1ccc(F)c(Cl)c1',
#  'CC1CCC(OC(=O)C2=NC3=C(C(=O)C[C@@H](c4ccccc4)C3)[C@H]2C)CC1',
#  'CC(C)[NH+]1CCC(N2CC[NH+](Cc3c(F)ccc(F)c3F)C[C@@H]2CCO)CC1',
#  'CC[NH2+][C@@H](C)c1cc(F)c(C)cc1N1C[C@H](C)S[C@H](C)C1',
#  'CC(C)c1nsc(NC[C@H](C2CC2)[NH+](C)C)n1',
#  'Cc1ccc(-c2nc(C[NH+]3CCCC[C@H]3c3cccnc3)c(C)o2)s1',
#  'COc1cccc(C2=C[C@H](C(=O)N3CCCCC3)N=N2)c1',
#  'O=C(Nc1ccc2[nH]c(=O)[nH]c2c1)c1cc(S(=O)(=O)NC2CC2)ccc1Br',
#  'c1ccc2c(c1)CC[C@H]([C@H]1CCCc3cccnc31)N2',
#  'Cc1ccc(NC(=S)NC(C)C)cc1C',
#  'CC(C)OC(=O)CCNC(=O)c1cnn(-c2ccc(F)cc2)n1',
#  'Cc1c([C@H](C)NC(=O)c2[nH]c3ccccc3c2Cl)cnn1C',
#  'COC(=O)CCN(Cc1cnc2ncccn12)C1CCOCC1',
#  'O=C(c1c[nH]c2ccc(F)cc12)N(CC1CC1)CC(F)(F)F',
#  'Cc1cccc(C)c1NC(=O)C[NH+]1CCC(OCc2ccc(F)cc2)CC1',
#  'C[C@H]1CCC[C@@H](C)N1C(=O)[C@@H]1COCCO1',
#  'CC(C)[C@@H](C)CC(=O)NNC(=S)NC1CCCCC1',
#  'Cc1cccc(NC(=O)CN2C(=O)/C(=C3\\SC(=S)N(Cc4ccco4)C3=O)c3ccccc32)c1',
#  'Cc1ccc(N2CC[C@H](C(=O)NC[C@@H](CC(C)C)N3CCOCC3)C2=O)cc1',
#  'COc1ccc(NC(=O)CCc2ccc3c(c2)OCCO3)cc1OC',
#  'c1cc(C[NH2+]Cc2ccco2)cc(OC2CCCC2)c1',
#  'c1cc(-c2nc3c4cn[nH]c4ncn3n2)ccc1COc1ccc2c(c1)CCC2',
#  'Cc1ccc(S(=O)(=O)N2C[C@@H](CC(=O)[O-])c3ccccc32)c(C)c1',
#  'Cc1cc(N)nc(SCC(=O)NC[C@@H](c2ccccc2)C(C)C)n1',
#  'Cn1cc(C(N)=O)c(NC(=O)c2ccc3sccc3c2)n1',
#  'COc1cc2c(cc1O)[C@H](c1cnc(-c3cccc(C)c3)nc1)CC(=O)N2',
#  'CC(=O)Nc1ccc(O[C@H](C)c2nc(C(C)(C)C)no2)cc1',
#  'O=C(c1c(-c2ccccc2)nc2sc3c(n12)CCCC3)C(F)(F)F',
#  'CC(C)CNC(=O)NC(=O)[C@@H](C)Nc1ccc(OC(C)C)cc1',
#  'C=C[C@](C)(O)CC[C@H]1C(C)=CC(=O)[C@H]2C(C)(C)CCC[C@@]21C',
#  'CC[C@H](C)Sc1nncn1-c1ccccc1C',
#  'C[C@H](Oc1cccc(Cl)c1)C(=O)Nc1ccc2ccccc2c1',
#  'Cc1cc(Br)ccc1SCC(=O)N1CCC(C(=O)c2ccc3c(c2)OCCO3)CC1',
#  'C[C@H](CN(C)C(=O)c1ccc(F)c(F)c1F)C(=O)[O-]',
#  'CC(=O)N[C@@H](CC(=O)Nc1ccnn1Cc1ccc(C)o1)c1ccccc1',
#  'CSc1nncn1/N=C\\c1cc(Cl)ccc1F',
#  'CC(C)(C)OC(=O)N1CC[C@H]2CC(=O)[C@H]2C1',
#  'C[C@@H](CCO)SCc1ccccc1OC(F)F',
#  'COc1ccccc1CNC(=O)COc1ncnc2oc(C)c(C)c12',
#  'Fc1ccc(F)c(C[NH+]2CCC(n3cc(-c4cccnc4)nn3)CC2)c1F',
#  'O=C(C[NH+]1CCC(C(=O)c2ccc(Cl)cc2)CC1)NC[C@H]1COCCO1',
#  'CCC[NH+](C)C[C@H]1CCN(C(=O)Nc2cc(NC(C)=O)ccc2C)C1',
#  'Cc1nc2ncnn2c(NCCOC2CCCCCC2)c1C',
#  'C[C@H]1CN(Cc2cnn(-c3ccccc3)n2)C[C@H](C)S1',
#  'COc1cc(OC)cc([C@@H](N[C@@H](C)c2ccc(F)cn2)c2[nH+]ccn2C)c1',
#  'CC(C)CCc1noc(C[NH+](C)[C@H]2CCC[C@@H]2S(C)(=O)=O)n1',
#  'CCc1nc2n(n1)CCC[C@H]2NC(=O)c1ccc(-n2cc(C)cn2)cc1',
#  'C[C@@H](NC(=O)c1ccccc1CSc1nc2ccccc2[nH]1)C1CC1',
#  'O=C([C@H]1CCCN1S(=O)(=O)N1CCCCC1)N1CCSCC1',
#  'Cn1c(=O)c(=O)n(CC(=O)N2CCC3(CC2)OCCO3)c2cccnc21',
#  'COc1ccc(C(=O)N(CC2=CC=C[C@@H]3N=CC=C23)C2CC2)cc1',
#  'CCc1ccc(-c2nc(N)ccc2[N+](=O)[O-])cc1',
#  'c1csc([C@@H]2CN(Cc3cnc(C4CCC4)s3)CCO2)c1',
#  'Cc1nccn1CC(=O)N1CCCC[C@@H]1CCNC(=O)c1ccccc1',
#  'COc1ccc(-n2nnc(-c3nc(-c4ccc5c(c4)OCO5)cs3)c2C)cc1OC',
#  'CN(c1ccccc1)S(=O)(=O)c1ccc2c(c1)C(C)(C)C(=O)N2',
#  'CCCc1cc(=O)n2c(n1)SC[C@@H]2CC(=O)Nc1cccc(Cl)c1Cl',
#  'Cc1ccc(NC(=O)CSc2nnc([C@@H]3CCCN3C(=O)c3cccc(C)c3)n2C)cc1',
#  'Cc1noc(C)c1CCCNC(=O)N[C@H]1CC(=O)N(C2CC2)C1',
#  'CC(C)(C)[C@@H]1CCC(=O)[C@@H](CN2CCOCC2)C1',
#  'COc1cc(/C=C2\\SC([N-]c3cccc(C(=O)[O-])c3)=NC2=O)cc(OC)c1O',
#  'C[C@H]1C[C@H]([NH+]2CC[C@H](S(=O)(=O)NC3CC3)C2)CC(C)(C)C1',
#  'CC[C@H](Sc1cc(C)c2cccc(C)c2n1)C(=O)Nc1nc2ccc(S(N)(=O)=O)cc2s1',
#  'COC(=O)[C@]1(NC2CC2)CC[C@H](Sc2ncc(C)cn2)C1',
#  'COc1ccccc1Nc1nn(CN(C)OC)c(=S)s1',
#  'Cc1cc(C)c(C)c(S(=O)(=O)/N=C(\\[O-])c2cc(C3CC3)n(C(C)(C)C)n2)c1C',
#  'CC(C)(O)C#Cc1ccc(C[NH2+][C@H]2CCCN(c3nc4ccccc4s3)C2)s1',
#  'COc1ccc(OC)c(S(=O)(=O)n2cc3c(=O)n(C)c(=O)n(C)c3n2)c1',
#  'Cc1nnsc1C(=O)Nc1nnc(-c2ccc(Br)cc2)o1',
#  'CCN(Cc1ccc(OC)c(OC)c1)C(=O)C[NH+]1CC[C@@H](C)[C@H](O)C1',
#  'O=C([O-])[C@H]1CCCCN1C(=O)CSCc1ccccc1',
#  'Cc1cccc([C@H](O)C[C@@H]2CCCCC[NH2+]2)c1',
#  'CCO[C@@H]1C[C@@H]([NH+](C)C[C@@H]2CCCN(S(C)(=O)=O)C2)C12CCCCC2',
#  'CCn1c(=O)c(=O)[nH]c2cc(C(=O)NN3C(=O)N[C@](C)(c4ccccc4)C3=O)ccc21',
#  'COc1cc(OC)cc([C@@H](NC(=O)N(C)C2CCCCC2)c2nccn2C)c1',
#  'O=C1[C@H]2[C@@H]3C=C[C@@H](C3)[C@H]2C(=O)N1CN(C(=O)C(F)(F)F)c1cccc(C(F)(F)F)c1',
#  'CCNc1ncc(COc2cccc3ccccc23)s1',
#  'Cc1noc(C)c1CCCNC(=O)c1c(C)nn(Cc2ccccc2)c1C',
#  'C[C@H]1CC([NH2+][C@@H](C)c2c[nH]c3cc(F)ccc23)C[C@H](C)O1',
#  'C/C(=C1/SC(=O)N(c2ccc(Cl)cc2)C1=O)c1ccc(Br)cc1',
#  'Cc1ccc(NC(=O)C[C@H]2SC([N-]c3ccc(N(C)C)cc3)=NC2=O)c(C)c1',
#  'CO[C@H]1CCCC[C@H]1NC(=O)NC[C@H](c1cccc(F)c1)[NH+](C)C',
#  'Cc1cc(=O)[nH]c(SCC(=O)N2C[C@]3(C)C[C@H]2CC(C)(C)C3)n1',
#  'Cc1nnc(SCC(=O)c2cc(C)n(CC(F)(F)F)c2C)s1',
#  'CC(C)CN(CCC#N)C(=O)NC[C@@H]1CC[C@H](C(=O)[O-])O1',
#  'CCNC(=O)c1cccc(NC(=O)NCCCSC)c1',
#  'Cn1c(-c2cccc3ccccc23)nn(CN2CCOCC2)c1=S',
#  'CCCCCN1C(=O)/C(=C/c2ccc(O)c(OCC)c2)SC1=S',
#  'N#CCCN(Cc1ccccc1)C(=S)NC(=O)c1cccc(Cl)c1',
#  'CNC(=O)CN1c2ccccc2C(=O)N(C)[C@H]1c1ccccc1O',
#  'CC(=O)N[C@H](C)C(=O)Nc1ccc(Sc2nncs2)c(Cl)c1',
#  'CC[n+]1c(N)n(CCOc2ccc(Cl)cc2Cl)c2ccccc21',
#  'COC(=O)CCCc1nnc(NC(=O)N2CCC[C@@H]3CCC[C@@H]32)s1',
#  'O=C(CCOc1ccccc1)NNC(=O)CC1(O)CCCC1',
#  'C=CCN(CC(=O)[O-])C(=O)[C@@H](C[NH3+])C(C)C',
#  'O=C(CCn1ccccc1=O)NCC1(c2ccccc2)CC1',
#  'COc1cc(C)c([C@@H](C)NC(=O)CSC2CCCC2)cc1OC',
#  'C=CCNC(=O)Nc1ccc(F)c(NC(=O)OC)c1',
#  'Oc1ccccc1/C=[NH+]/CCC/[NH+]=C/c1ccccc1O',
#  'Cn1cccc1Cc1nnc(SCC(=O)Nc2ccc3c(c2)OCCO3)n1C',
#  'C[C@@H](C#N)CNC(=O)c1cccc(Oc2cccc(C(F)(F)F)c2)c1',
#  'CCc1cccc(CC)c1NC(=O)NC1CC1',
#  'CCCCn1nc(C)c(C[NH2+]C[C@@H](C)O)c1Cl',
#  'C/C=C/C=C/C(=O)N1C[C@@H](C(=O)OC)[C@@H](C)C1',
#  'COc1cccc(OC)c1OC1CC[NH+](Cc2ccc([C@H]3C[C@@H]3C)o2)CC1',
#  'CCOc1ccc2cc(C(=O)NCc3ccccc3)c(=[NH2+])oc2c1',
#  'O[C@H]1CCN(c2ccnc(N3CCc4[nH]c5ccc(Cl)cc5c4C3)n2)C1',
#  'O=S(=O)(NC[C@H](O)c1ccc(C(F)(F)F)cc1)c1cc(F)ccc1F',
#  'Cc1ccc(C)c(NC(=S)NCCc2cccs2)c1',
#  'CNc1ncc(F)c(-c2cccc(Cl)c2)n1',
#  'CCN(CC)C(=O)c1ccccc1OC(C)=O',
#  'Cc1ccc(-c2nc(-c3ccc(OCC(F)(F)F)nc3)no2)cc1',
#  'COc1ccc([C@@H](CNc2nc3ccccc3o2)N2CCOCC2)cc1',
#  'CNC(=O)[C@H]1CCCC[C@H]1[NH2+][C@H](C)c1cc(C)cc(C)c1',
#  'Cn1ncc2c(NCc3ccco3)nc(CCc3ccccc3)nc21',
#  'Cn1cc[nH+]c1C[C@H]1CCC[NH+](Cc2ncc(-c3ccccc3Cl)o2)C1',
#  'Cc1cc(N2CC[C@H](C)[C@H](O)C2)nc(C)[nH+]1',
#  'Cc1nnc(CCC[NH+]2CCC(CC[NH+]3CCCC[C@@H]3C)CC2)o1',
#  'CCc1nn(C)cc1CNC(=O)C1(CC)CCC1',
#  'COc1ccc(N2/C(=N/C(=O)CCCC(=O)[O-])S[C@@H]3CS(=O)(=O)C[C@H]32)cc1Cl',
#  'CC(=O)C1=C([O-])C(=O)N(CCC2=c3ccccc3=[NH+][C@H]2C)[C@H]1c1ccccc1F',
#  'COc1cc(C)c(C(=O)N[C@H]2C[C@H](C)N(c3ccccc3)C2)cc1OC',
#  'CN(C[C@@H]1CCCN(C(=O)NCCc2ccc(F)cc2)C1)C(=O)OC(C)(C)C',
#  'COc1cc(Cl)c(C)cc1NC(=O)[C@H](C)N1CCN(S(=O)(=O)c2c(C)noc2C)CC1',
#  'Cc1nc(-c2ccc(Cl)s2)sc1C(=O)N[C@H]1C[C@H]1C',
#  'COc1cc(F)c([C@H]([NH3+])c2ccc(SC)cc2)cc1OC',
#  'Cc1ccc(-n2ccnc2SCC(=O)N(CC(N)=O)C(C)C)cc1C',
#  'Cc1cccc(/C=C2\\SC(=S)N(c3c(C)cccc3C)C2=O)c1',
#  'CC1=C(C(=O)OC(C)C)[C@H](C)N=C1C(=O)Nc1ncc(C)s1',
#  'COC(=O)c1cccc(C(=O)N2C[C@@H](c3ccc(F)cc3)C[C@H]2C)c1',
#  'O=C(NCCCn1ncccc1=O)[C@@H]1CC(=O)N(c2ccccc2)C1',
#  'CCC(=O)N1CCCN(C(=O)N[C@@H]2CCc3ccccc32)CC1',
#  'Cc1cc(NN)c2cccc(OC(F)(F)F)c2[nH+]1',
#  'C[C@H]1CCC[C@@H](C(=O)Nc2cccc(OCCc3ccccc3)c2)[NH2+]1',
#  'Cn1ncnc1CCNC(=O)[C@H]1C[C@@H]1c1cc(Cl)cc(Cl)c1',
#  'CCOc1ccc(S(=O)(=O)N2CCC(c3nnc(C4CC4)o3)CC2)cc1',
#  'Cc1cc2nc(C)c(CCC(=O)NC[C@@H](c3ccccc3)N3CCOCC3)c(C)n2n1',
#  'COc1ccc(N2C(=O)CS[C@H]2c2ccc(Cl)cc2)cc1Cl',
#  'CS(=O)(=O)c1ccc(NC(=O)N2CCC[C@H]2CC2CCCCC2)cc1',
#  'COc1ccc(C(=O)OCc2nc3ccccc3s2)cn1',
#  'COc1ccc(S(=O)(=O)Nc2ccccc2-n2nc(C)cc2C)cc1NC(C)=O',
#  'N#C/C(C(=O)NC1CCCC1)=C(/[O-])Cc1cnn(-c2ccccc2)c1',
#  'NC(=O)[C@H](Nc1cccc(Oc2ccccc2)c1)c1ccc(F)cc1',
#  'CCN(C[C@@H]1CCOC1)C(=O)Nc1cc2c(cc1Cl)OCCO2',
#  'CCCCc1nnc(NC(=O)C2CCN(S(=O)(=O)c3ccc(C)cc3)CC2)s1',
#  'CC[C@@H](NC(=O)c1ccc(Br)o1)C(=O)N1CCOCC1',
#  'CC[C@]1(c2ccccc2)NC(=O)N(CCOc2ccc(Cl)cc2Cl)C1=O',
#  'COc1ccc(OC)c(NC(=O)c2ccc3c(c2)C(=O)N(c2cc(C)on2)C3=O)c1',
#  'Cc1ccc(OCC(=O)NC(=S)NC[C@H]2CCCO2)cc1',
#  'CN(C(=O)CCOc1cccc(C(N)=O)c1)[C@H]1CCC[NH+](C)C1',
#  'COC(=O)c1ccc(NC(=O)c2c(C)sc3ncnc(N4CCC[C@H](C)C4)c23)cc1',
#  'Cn1ncc2c1CC/C(=C\\c1ccc(-n3cncn3)c(F)c1)C2=O',
#  'C=CCOc1ccc(CNc2ccc(OC)cc2)cc1',
#  'C[C@H]1N=C(CCNC(=O)CCC2=c3ccccc3=[NH+]C2)CS1',
#  'COC(=O)c1cc(NC(=O)[C@@H]2CCO[C@H]2C)ccc1C',
#  'COc1ccccc1[C@@H](C)NC(=O)c1cnc2c(C)cccn2c1=O',
#  'CC[C@@H](C)NS(=O)(=O)c1cc(N2C(=O)[C@@H](C)CS2(=O)=O)ccc1OC',
#  'COCCCNC(=O)[C@H]1CN(C(=O)c2cccs2)CC12CCCCC2',
#  'CC[S@](=O)[C@H]1CCCC[C@@H]1NC(=O)NC[C@H](O)c1ccco1',
#  'Cc1ccccc1OCC(=O)O[C@@H](C)c1nccs1',
#  'C[C@H](C(=O)N1CCOCC1)[NH+]1CCN(Cc2ccc3c(c2)OCO3)CC1',
#  'CCN(C(=O)[C@@H]1Cc2ccccc2S1)[C@H]1CCC[C@@H]1C[NH3+]',
#  'Cc1cc(Br)ccc1NC(=O)[C@@H](C)[NH+](C)Cc1cccs1',
#  'COC(=O)[C@H]1CCC[C@H]1NC(=O)Nc1ccc(C)cc1C',
#  'CC(C)NS(=O)(=O)c1ccc(C(=O)N[C@H](C)c2ccccc2Br)cc1',
#  'CC(C)OCCN1CCN(C(=O)Nc2ccccc2C(F)(F)F)CC1',
#  'COC[C@@H](C)NC(=O)C(=O)Nc1cc(-c2ccccc2)nn1C(C)C',
#  'C#CCOc1ccccc1CN1CCN(C2=[NH+]C[C@@H](C)S2)CC1',
#  'COCCNC(=O)[C@H]1CCCN1S(=O)(=O)c1ccc(Br)cc1',
#  'C=CCn1c(=O)c2c(nc3n2[C@H](C)C(C)=NN3C)n(C)c1=O',
#  'C[C@H]1CCCC[C@H]1NC(=O)c1cc(S(=O)(=O)N2CCOCC2)ccc1Cl',
#  'COCCn1ccc2ccc(NC(=O)NCCc3ccccn3)cc21',
#  'O=C(CSc1nnnn1C1CC1)N[C@H](CO)C(=O)[O-]',
#  'O=C(COc1ccc(Br)cc1)N[C@H]1CCS(=O)(=O)C1',
#  'CCc1nnc(NC(=O)c2ccccc2N)s1',
#  'N#Cc1ccc(OC2CCC(NC(=O)c3ccc[nH]3)CC2)nc1',
#  'Cc1cc(NC(=O)c2cccc([N+](=O)[O-])c2C)n(-c2ccccc2F)n1',
#  'CCC(=O)N1CCCC[C@@H]1C(=O)NCCc1ccc(F)cc1C',
#  'Cc1ccc(S(=O)(=O)N2C(N)=C(C#N)[C@H](c3ccc(Cl)cc3)[C@H]2C(=O)c2ccccc2)cc1',
#  'C[NH+](C)[C@@H]1CC[C@H](NC(=O)[C@@H]2CCCc3[nH]ncc32)C1',
#  'CCOCCS(=O)(=O)[N-]c1cc(Br)ccc1O',
#  'NC1=NC(=O)[C@H](CC(=O)N2CC[C@H](c3ccccc3)C2)S1',
#  'Cc1ccc(OC(=O)c2cccc(C(=O)Oc3ccc(C)cn3)n2)nc1',
#  'CN(CC1CCCC1)C(=O)C(=O)Nc1cccc(SC(F)F)c1',
#  'O=C(c1cc(=O)[nH]c2ccccc12)N1CCC([C@H](O)c2ccccc2)CC1',
#  'CCO[C@@H]1C[C@@H]([NH3+])[C@@H]1Nc1ncc(Cl)cc1F',
#  'CC(=O)Nc1ccc(NC(=O)c2ccc3c(c2)Cc2ccccc2-3)cc1',
#  'COCCOC[C@H]1CC[NH+](C2C[C@@H](C)O[C@H](C)C2)C1',
#  'O=C1OC(c2ccccc2OC(F)F)=N/C1=C\\c1cccc(F)c1',
#  'COc1ccccc1CNC(=O)c1cc2sccc2n1Cc1cccc(F)c1',
#  'CCOC(=O)C1(NCc2nnc(-c3cc(C)oc3C)o2)CCCC1',
#  'Cc1cc(NC(=O)N[C@@H](Cc2ccccc2)c2ccccc2F)n(C)n1',
#  'O=C(NCCOc1ccc2c(c1)OCO2)c1cc(C2CC2)on1',
#  'N#CCC[NH2+]C1(C(=O)[O-])CC1',
#  'CC[C@@H](Oc1ccccc1OC)C(=O)NCc1ccccn1',
#  'Cc1nc(C[C@@H](N)[C@]2([NH+](C)C)CCC[C@H](C)C2)cs1',
#  'CC(C)Cn1cc[nH+]c1CN[C@@H](c1ccccc1)C(C)C',
#  'Cc1c(C[NH+]2CCC[C@H]2c2ccc3c(c2)OCO3)cc(C#N)n1C',
#  'O=C(CBr)c1cnc2ccc(Cl)cn12',
#  'COc1ccc(F)cc1NC(=O)c1sccc1S(=O)(=O)N(C)C',
#  'COc1ccc(Br)cc1/C=C1/C(=O)NN(c2ccc(C)c(C)c2)C1=O',
#  'CC(C)(C)c1ccc(C(=O)N[C@H]2CCN3CCCc4cccc2c43)cc1',
#  'CC[NH+]1CCC[C@@]2(CC1)C[NH+]=C(N)N2c1ccc(C)cc1',
#  'CN(C)c1ccc(/C=C(/C#N)C(=O)c2cccc(C#N)c2)cc1',
#  'CCCC[C@@H](NC(N)=O)C(=O)Nc1cc(OC)ccc1F',
#  'C[C@@H](NC(=O)CSc1ccc2c(c1)OCCCO2)c1ccc2ccccc2c1',
#  'CCN1CCN(S(=O)(=O)c2cc(-c3csc(C)n3)ccc2C)CC1',
#  'Cc1nccn1Cc1ccc(NC(=O)c2cccc(-n3cccc3)c2)cc1',
#  'Cc1cccc([S@@](=O)Cc2ccc(N)c(F)c2)c1',
#  'CC1=NC(SCC(=O)Nc2ccccc2C(F)(F)F)=NC(=O)[C@H]1Cc1ccccc1',
#  'COc1cccc(C[NH2+]Cc2cccc(Br)c2OC)c1OC',
#  'CCc1noc(CN(CC)C(=O)C(C)(C)NC(=O)c2cccs2)n1',
#  'CC(C)C[C@](C)(O)CNC(=O)CC[C@H](C)O',
#  'CC1(C)CCC[C@H]1N1C(=O)c2cccc(N)c2C1=O',
#  'CCCNC(=O)NC(=O)CN1C(=O)N[C@](Cc2ccccc2)(c2ccccc2)C1=O',
#  'O=C(COc1cc(Cl)c(Cl)cc1Cl)N1CCN(C(=O)Nc2ccccc2)CC1',
#  'CCCn1c(S[C@H](C(N)=O)c2ccccc2)nc2sc(CC)cc2c1=O',
#  'COc1cccc(CCNC(=O)CN2CCN(c3ccccc3O)CC2)c1',
#  'c1ccc2c(NCc3nnc(C4CCC4)o3)cccc2c1',
#  'CC1=C(C(=O)C2=C([O-])C(=O)N(CC[NH+](C)C)[C@H]2c2cccc(Cl)c2)[C@H](C)N=N1',
#  'CCOc1ccc([C@@H]2Nc3ccc(C(=O)N(C)C)cc3[C@H]3C=CC[C@H]32)cc1',
#  'COc1ccc(Cc2sc(NC(=O)[C@H]3COc4ccccc4O3)nc2C)cc1',
#  'Cc1cnc2nc(C[C@H](O)C(F)(F)F)[nH]c2c1',
#  'CCN(CC(C)(C)O)C(=O)COCc1ccccc1Cl',
#  'O=C(Nc1cccc2ccccc12)NC1CC[NH+](CC(F)F)CC1',
#  'O=C1C(=O)N(CC[NH+]2CCOCC2)[C@@H](c2cccc([N+](=O)[O-])c2)/C1=C(\\O)c1cccs1',
#  'Cc1cc(C)c(C(=O)Cn2nc(N)n(Nc3cccs3)c2=S)c(C)c1',
#  'C[C@H]1CN(C(=O)CC[C@H](C)c2ccccc2)C(C)(C)CO1',
#  'CN(C)c1nc2c(c(-c3ccc(S(C)(=O)=O)cc3)n1)CCCC2',
#  'CC(C)c1ccc(CNC(N)=[NH2+])cc1',
#  'CN(C)N1C(N)=C(C#N)[C@@H](c2cccs2)C2=C1CCCC2=O',
#  'COC[C@H](NC(=O)c1cc(-c2ccccc2)c(C)[nH]c1=O)C(N)=O',
#  'O[C@H]1CCCCC[C@H]1n1cc(-c2ccccc2Cl)cn1',
#  'CC1=C[C@@H](C)[C@H]2C(=O)N([C@H](Cc3ccccc3)C(=O)[O-])C(=O)[C@H]2C1',
#  'CCCCNS(=O)(=O)Cc1ccc([N+](=O)[O-])cc1',
#  'COc1ccc(CC[C@H]2C[C@@H](C(C)(C)C)CCC2=O)cc1',
#  'C[C@H]1CN(CC(=O)Nc2nc(-c3ccccc3Cl)cs2)CCO1',
#  'Cc1cc(Cl)cc(Cl)c1CNC(=O)c1cccs1',
#  'CC(C)(C)OC(=O)NC1CCN(CC(=O)c2nccs2)CC1',
#  'COc1ccc(C)cc1[C@@H](C)NC[C@@H]1CN(C2CC2)CCO1',
#  'O=C1N(C[NH+]2CCN(c3ccccc3)CC2)c2ccccc2C12O[C@@H]1CCCC[C@H]1O2',
#  'C1=C[C@H]2C[C@@H]1C[C@H]2CN1CC[NH+](C2CCCCCC2)CC1',
#  'O=C1C=C(c2cccs2)C[C@H](c2cccs2)[C@@H]1n1cnc([N+](=O)[O-])n1',
#  'C[NH2+]C1CCC([NH+](C)CC(=O)N[C@H](C)c2ccco2)CC1',
#  'CC(C)c1nc2n(n1)CCC[C@H]2[NH2+]C[C@@H]1CCC[C@H](C)C1',
#  'CCCOC(=O)c1ccc(NC(=O)c2ccc[n+]([O-])c2)cc1',
#  'CCOc1cc(CO)cc(Br)c1OCc1ccccc1F',
#  'O=C(Cn1nnn(-c2cccs2)c1=O)NC[C@@H]1CN(Cc2ccccc2)CCO1',
#  'CC(C)[C@H](O)CCNC(=O)C(=O)Nc1ccn(-c2ncccc2Cl)n1',
#  'Cc1cccc(C(=O)NCCS(=O)(=O)NCC2CCC2)c1C',
#  'O=C(N[C@H](NC(=S)Nc1ccccc1)C(Cl)(Cl)Cl)c1cccc(Br)c1',
#  'CCN(Cc1ccccc1)C(=O)c1cc(NC(=O)Cc2ccccc2)n(C)n1',
#  'CC(C)CC(=O)N1CCN(C(=O)c2cnc3c(c2)NC(=O)CO3)CC1',
#  'O=C(Cc1csc(NC(=O)Nc2ccc(Cl)cc2)n1)NCCc1ccc(Cl)cc1',
#  'Cc1ccc2c(c1)C[C@@H](C[C@@H](C[NH3+])c1ccc(F)cc1)O2',
#  'CC1=C(C(=O)OC(C)C)[C@@H](c2ccc(C)s2)NC(=O)N1C',
#  'COc1cc(F)c([N+](=O)[O-])c(NC[C@@H](O)c2cnn(C)c2)c1',
#  'COc1ccc(C(=O)N2CCC([C@@]3(C)NC(=O)N(C4Cc5ccccc5C4)C3=O)CC2)cc1',
#  'CCc1cnc(NC(=O)c2cc(C)n(C(C)C)c2C)s1',
#  'COc1ccccc1-c1nc(C[NH+](C)Cc2ccc(C#N)cc2)cs1',
#  'COc1ccc(-c2noc(-c3cc(-c4ccc(Cl)cc4)n[nH]3)n2)cc1OC',
#  'CC[C@H](NC(=O)CN1C(=O)c2ccccc2N2C(=O)CC[C@]12C)c1ccc(C)cc1',
#  'Cc1ccc(CNC(=O)NCc2ccnc(OC(C)(C)C)c2)cn1',
#  'Cc1cccc(-c2nn(C[NH+]3CCCCC3)c(=S)n2-c2ccccc2)c1',
#  'C[NH2+][C@@H](C1CCCC1)[C@@H]1CCc2cccnc21',
#  'Cc1ccc(-c2cccc(F)c2C(=O)[O-])c(C)c1',
#  'CN(C)C(=O)[C@@H](Sc1nnc2n(C)c3ccccc3n12)c1ccccc1',
#  'Cc1ccc(C(=O)NNC(=O)c2ccc(SC[C@H]3CCCO3)c([N+](=O)[O-])c2)cc1',
#  'CCCn1/c(=N/C(=O)[C@@H](CCSC)NC(N)=O)[nH]c2ccccc21',
#  'Cn1/c(=N/C(=O)c2sccc2S(=O)(=O)N2CCOCC2)sc2ccccc21',
#  'COc1ccccc1N1C[C@@H](C(=O)NN2C(=O)NC3(CCCCC3)C2=O)CC1=O',
#  'COc1cc(OC)cc(C(=O)Nc2ccccc2C(=O)NC(C)(C)C)c1',
#  'C[C@H](Nc1nc(-c2ccncc2)nc2ccccc12)c1ccccn1',
#  'CCOc1ccc(C[NH+]2CCC[C@H]([C@H](O)c3nccn3C)C2)cc1OC',
#  'O=C([O-])c1ccc([S@@](=O)Cc2ccc(O)cc2)cc1',
#  'CCc1nn(C)cc1CNC(=O)NCC(C)(C)Cc1ccccc1',
#  'COC(=C(C#N)C#N)c1cccs1',
#  'O=C(NCc1ccnc(OCC(F)F)c1)NCc1cscn1',
#  'C[C@@H](C(=O)N1CCCC1)N1CCN(C(=O)NCc2ccco2)CC1',
#  'CC(C)c1ccc(CN(C)C(=O)NCCCn2cccn2)cc1',
#  'COc1ccccc1N1CC[NH+]([C@@H](C)C(=O)Nc2ccc(F)cc2)CC1',
#  'CN1C[NH+](C)CC2=C1NCNS2(=O)=O',
#  'CNC(=O)c1ccc(O[C@@H]2CCC[C@H]([NH3+])C2)nn1',
#  'COc1ccc(C(=O)O[C@@H](C)[C@@H]2CCCO2)cc1OC(F)F',
#  'CCc1cccc(S(=O)(=O)Nc2cccc(-c3nnnn3C)c2)c1',
#  'Cc1ccc(C(=O)NC2CC[NH+](Cc3nc(-c4ccccc4)cs3)CC2)s1',
#  'CCOc1ccc(F)c(C(=O)OC[C@H]2CCCCO2)c1F',
#  'O=C(NC[C@@H](O)CN1CCCC1=O)Nc1cccc(F)c1',
#  'CC[NH+]1CCC[C@H](NC(=O)c2ccc(OC)c(O)c2)C1',
#  'O=C(CSCC(F)(F)F)N1CCN(c2ccc(Cl)cn2)CC1',
#  'COc1ccc(Cl)cc1S(=O)(=O)N[C@H](C)C(=O)NCc1ccc2c(c1)OCO2',
#  'Clc1ccc([C@H](NCCc2nnc3ccccn23)C2CC2)cc1Cl',
#  'Clc1ccc(OCCCCSc2ncccn2)cc1Cl',
#  'Cn1nnc2cc(C(=O)N[C@@H](C#N)c3ccc(Cl)c(Cl)c3)ccc21',
#  'Cc1cc(C)cc(-c2nnc(Sc3nc(C(C)C)ns3)o2)c1',
#  'C/C(=C/c1ccc(F)cc1)C(=O)NCc1cccc(OCC(F)F)n1',
#  'CC(C)Nc1cccc(CNC(=O)N[C@@H]2CC[NH+](CC3CC3)C2)c1',
#  'Cc1ccc(-n2nc3c(c2NC(=O)C(C)C)C[S@@](=O)C3)cc1',
#  'COc1nc(Oc2ccc3ccccc3c2)ccc1N',
#  'CC(C)c1nc(CSCc2ccnn2C)no1',
#  'O=C(C1CCC1)N1CCC[C@H]1c1nc2cc(-c3ccccc3)ccc2o1',
#  'O=C(CC[C@@H]1NC(=O)NC1=O)NC1CCN(c2ccccc2F)CC1',
#  'Cc1ccc(-n2nc3c(c2NC(=O)c2ccc(Br)o2)CSC3)cc1C',
#  'C=CCn1c(SCc2nnc([S-])n2-c2ccccc2)nnc1-c1ccccc1',
#  'c1nnn(C23C[C@H]4C[C@H](CC(c5nc6c7cn[nH]c7ncn6n5)(C4)C2)C3)n1',
#  'CCCn1ncnc1COc1ccc(C)nc1C[C@H](C)[NH3+]',
#  'CCSc1ccc(C(=O)N2CC[C@H](C)[C@H](O)C2)cn1',
#  'COc1ccccc1NC(=O)CSc1nnc(C)c(=O)n1N',
#  'COc1ccccc1[C@@H](C)NC(=O)[C@@H](C)Oc1cccc(F)c1',
#  'CC[C@@H](Oc1ccccc1/C=C1\\S/C(=N\\c2cccc(O)c2)N(CC)C1=O)C(=O)[O-]',
#  'C[C@@H]([NH2+]C[C@H]1CC[C@H](C(N)=O)O1)c1ccc2c(c1)OCCCO2',
#  'Cc1ccccc1Nc1nc(N)nc(COc2ccc(F)c(Cl)c2)n1',
#  'CC(=O)Nc1ccc(OC(=O)/C=C/c2ccc(C(N)=O)cc2)cc1',
#  'O=C([O-])c1ccc(-c2ccncc2)cn1',
#  'O[C@H](c1c(F)c(F)c(F)c(F)c1F)C(Cl)(Cl)Cl',
#  'COc1ccc(/C=N/NC(=O)CNc2ccc3ccccc3c2)cc1OC',
#  'O=C(NCCCS(=O)(=O)c1ccccc1)c1n[nH]c2ccccc12',
#  'C1=C(CC[NH2+]Cc2ccco2)CCCC1',
#  'Cc1ccc(NC(=O)[C@H](C)[NH+](C)Cc2nnc(C3CC3)n2C)c(C)c1',
#  'Cc1nsnc1Cn1nnc(C(=O)NC(C)C)c1C',
#  '[NH3+]CC1CCC(c2nc3ccc(Cl)cc3s2)CC1',
#  'CCSc1nc2ccccc2c(=O)n1CCc1ccccc1',
#  'COc1ccc([C@@H](CNC(=O)c2ccc([N+](=O)[O-])o2)[NH+](C)C)cc1',
#  'CC[C@H](NC(=O)c1ccc(C#N)cn1)C(=O)N1CCOCC1',
#  'CCc1ccc([C@H](O)C2(C[NH3+])CCCC2)cc1',
#  'COc1ccc(CNC(=O)N2CCc3c([nH]c4ccccc34)[C@H]2C)cc1OC',
#  'COc1ccc([C@@H]2C(C#N)=C(N)Oc3cc(C)n(CCN4CCOCC4)c(=O)c32)cc1OC',
#  'O=c1[nH]nc([O-])n1/N=C/c1ccco1',
#  'C[C@H](Oc1cccc(Cl)c1)C(=O)N1CCC(Cc2ccccc2)CC1',
#  'COc1cc([C@@H]2C(C(=O)Nc3ccc(F)cc3)=C(C)Nc3nc(C)nn32)cc(OC)c1OC',
#  'CC[C@@H](C)[C@@H](O)C[NH2+][C@@H](c1cccs1)C1CC1',
#  'CSc1cc(-c2cccs2)oc(=O)c1C#N',
#  'CC(C)[C@@H](NC(=O)c1ccc(NS(C)(=O)=O)cc1)C(=O)[O-]',
#  '[NH3+][C@H](CO)c1ccc(N2CCOCC2)c(Cl)c1Cl',
#  'CCCn1cc(NC(=O)c2cc3nc(-c4ccccc4)cc(-c4ccccc4)n3n2)cn1',
#  'Cc1ccc(S(=O)(=O)N2CCC(C(=O)N3CCCc4ccccc43)CC2)cc1C',
#  'C=CCN(CC=C)C(=O)C1CCN(C(=O)C(C)(C)C)CC1',
#  'C[C@H]1CCCC[NH+]1C[C@@H]1CCC(C)(C)[C@@H]1[NH3+]',
#  'COc1ccc(S(=O)(=O)N2CCOCC2)cc1NC(=O)/C=C/c1ccc(F)c(Cl)c1',
#  'Cc1ccc(F)c(C[NH+]2CCC(C(=O)NC(C)C)CC2)c1',
#  'CCn1nc(C)c(CNC(=O)[C@H]2[NH+]=c3ccccc3=C2NC(=O)c2cccc(C)c2)c1C',
#  'COc1ccc(C(=O)N2CCC[C@H](C(=O)Nc3cc(Cl)ccc3F)C2)c2ccccc12',
#  'CCc1ccc(/C=C(\\C#N)C(N)=O)s1',
#  'COc1cccc(N2C(=O)Nc3ccccc3[C@]2(O)C(=O)NCc2ccccc2)c1',
#  'COC(=O)c1sccc1NC(=O)[C@@H]1CC[NH2+][C@@H]1C',
#  'C/[NH+]=C(/NCc1ccc([N+]2=CCCC2)cc1)N[C@H]1CC[C@@H](SC)C1',
#  'N#Cc1csc(C(=O)N2CC[C@H]3CCCC[C@@H]32)c1',
#  'CNS(=O)(=O)c1cccc([C@H](C)NC(=O)c2ccc(Cn3cccn3)cc2)c1',
#  'CC[NH2+][C@@]1(C(=O)OC)CCC[C@@H](Oc2ccccc2)C1',
#  'COCCCn1c(C)c(C)c(C#N)c1NC(=O)C[NH+]1CC(C)(C)C1(C)C',
#  'C[C@H]1CCC[C@@H](C)N1C(=O)[C@H]1C[C@H]1c1ccccc1Cl',
#  'Cc1c(F)cc(N)cc1S(=O)(=O)NCC(N)=O',
#  'CC1(C)[C@@H]2CC[C@@]1(CS(=O)(=O)NCCCO)C(=O)C2',
#  'COc1ccc(-n2ccc(CNC(=O)c3cc(Cl)ccc3[N+](=O)[O-])n2)cc1',
#  'CN(CC[NH+](C)C)C(=O)C[C@H]1COCCN1C(=O)c1ccc2[nH]nnc2c1',
#  'CC[C@H](c1ccc(F)cc1)N(C)C(=O)Cn1nnc(-c2ccccc2)n1',
#  'O=C(Cn1cccc1-c1nc(-c2ccc(OC(F)(F)F)cc2)no1)Nc1nccs1',
#  'CCc1nsc(Nc2ccc(CC(=O)N3CC[NH+](CC)CC3)cc2)n1',
#  'CS[C@@H]1CC[C@H](NC(=O)/C=C(/C)c2ccccc2)C1',
#  'Cc1ccc([N+](=O)[O-])cc1NCC(=O)N[C@](C)(C#N)C1CC1',
#  'O=C(C1CCCC1)N1CCC[C@@H]([NH+]2CCC(CO)CC2)C1',
#  'COC(=O)CNC(=O)c1sc2ncn(CC(=O)N3CCCCC3)c(=O)c2c1C',
#  'CC(C)CCNC(=O)[C@@H](C)Oc1ccc(N)cc1C(=O)[O-]',
#  'COc1ccc(-c2nnc(SCC(=O)c3ccc(Br)cc3)o2)cc1OC',
#  'C[C@]1(O)[C@](C)(O)[C@@H](CO)O[C@](C)(Oc2c[nH]c3ccc(Br)c(Cl)c23)[C@]1(C)O',
#  'Cn1nc(NC(=O)c2cccc(F)c2)c2c1NC(=O)C[C@@H]2c1ccccc1',
#  'C[C@@H]1CCN(C(=O)Nc2ccc(O[C@@H]3CCOC3)cc2)[C@H](C)C1',
#  'CC[C@H](C)[C@H](C)[NH2+]Cc1ncccc1F',
#  'C#CC(C)(C)NC(=O)c1ccc(OC)c(O)c1',
#  'COc1cc([N+](=O)[O-])ccc1OCc1nc(-c2cccs2)no1',
#  'CC1CCN(C(=O)C[NH+]2CCC[C@@H](c3nc4ccccc4o3)C2)CC1',
#  'C[C@H]1CCC[C@H](NC(=O)Cc2c[nH]c3ccccc23)[C@@H]1C',
#  'CC[NH2+]C[C@H](Cc1cscn1)c1cccc(F)c1',
#  'CCCCS(=O)(=O)N1CCN(c2ccc(-n3ccnc3C)nn2)CC1',
#  'O=C(c1cc2ccccc2o1)N(C[C@H]1CCCO1)c1nc2c(F)cccc2s1',
#  'C[C@H](CC#N)Sc1ccccc1NC(=O)c1ccc(Cl)nc1Cl',
#  'Cc1cnn(CC(=O)[C@@H](C#N)c2nc([O-])c3ccc(Cl)cc3n2)c1',
#  'CC[NH+]1CCC2(CC1)OC[C@H](C(=O)[O-])N2C(=O)c1ccc(F)cc1',
#  'Cc1ccc2c(c1)N(C(=O)C[C@H](O)c1ccc(Cl)cc1)CC2',
#  'C[C@H](Nc1ccc(S(=O)(=O)N2CCCCC2)cn1)[C@@H](C)CO',
#  'Fc1ccc(Oc2ccnc(Sc3nnc(-c4cccs4)o3)n2)cc1',
#  'CC[C@@H](C)n1nccc1NC(=O)C(=O)N1CCc2cc(F)ccc2C1',
#  'Cc1ccc(-c2cnc(CCC(=O)N(C)C3CCOCC3)o2)cc1',
#  'CCOC(=O)c1c(NC(=O)[C@H]2CCCN2S(C)(=O)=O)sc2ccccc12',
#  'Cc1ccc(C(=O)Cc2cccc(O)c2)cc1',
#  'Cc1ccccc1-c1nn(CN2CCCc3ccc(S(C)(=O)=O)cc32)c(=S)o1',
#  'CCOc1cccc([C@H](C)NC[C@@](C)(O)c2ccc(F)cc2F)c1',
#  'CC[C@@H]1CCCCCN1C(=O)c1cnc2sc(C)cn2c1=O',
#  'O=C(Nc1ccccc1)NC1CCN(C(=O)[C@H]2CCCC[C@H]2C(F)(F)F)CC1',
#  'C#CCN(Cc1cc(Br)cc(OC)c1O)[C@@H]1CCS(=O)(=O)C1',
#  'Cc1ccc(-c2nc3nc(CN4CC[NH+](C)CC4)cc([O-])n3n2)cc1',
#  'C[C@@](O)(CNC(=O)C1CCCC1)c1cccs1',
#  'O[C@H](CSc1nnc(-c2c[nH]c3ccccc23)n1C1CC1)CN1CCOCC1',
#  'C[C@@H]1CCC/C(=N/[NH+]=C(/[S-])NCc2ccccc2)C1',
#  'O=C(c1cc2ccc(Cl)cc2[nH]1)N1CCC[C@@H]1Cn1nnc(-c2cccs2)n1',
#  'COc1ccc(S(=O)(=O)Oc2ccc(C(C)=O)cc2OC)cc1',
#  'O=C(C1CC1)N1CCC[C@H](Cn2cc[nH+]c2-c2cc3n(n2)CC[NH2+]C3)C1',
#  'O=C(CCNc1ccccc1[N+](=O)[O-])N1CCC[C@@H]([NH+]2CCCC2)C1',
#  'Cc1ccc2c(c1)-c1onc(C(=O)N3C[C@@H](C)C[C@H](C)C3)c1CO2',
#  'CCC[C@@H]1C[C@H]1NC(=O)C1(c2ccc(F)cc2F)CCOCC1',
#  'CCOC(=O)C1CCC(NC(=O)[C@@](C)([NH3+])CC)CC1',
#  'CC[C@@H](O)C(=O)NCc1cccnc1Oc1ccccc1OC',
#  'C[C@@H](Sc1nnc(-c2cccs2)n1-c1ccccc1)C(=O)N1CC(=O)Nc2ccccc21',
#  'C[C@H](NC(=O)NCCC[S@](C)=O)c1ccc(Cl)s1',
#  'O=C(Cn1c(=O)c(=O)n(Cc2ccncc2)c2ncccc21)NCCc1ccccc1',
#  'CCCCOc1ccccc1/C=C1\\SC(N2CCC(C)CC2)=NC1=O',
#  'CC(C)[C@@H](CNC(=O)N1CCc2ccc(Cl)cc2C1)c1cccnc1',
#  'CCCOc1ncnc(Nc2cc(Cl)cc(Cl)c2)c1N',
#  'CC(=O)Nc1ccc(NC(=O)c2nnn(-c3ccc(C)c(C)c3)c2C)cc1',
#  'IC[C@@H]1Cn2c(nnc2-c2ccncc2)S1',
#  'CCOc1ccc([C@H]2CCCN2C(=O)c2[nH]c(C)c(C(C)=O)c2C)cc1',
#  'CC(C)CONc1ncnc2sc3c(c12)CCC3',
#  'CC(C)[C@@H](ON1C(=O)c2ccccc2C1=O)C(=O)[O-]',
#  'COC[C@H](O)C[NH+]1CCC(C)(C)C1',
#  'O=C(Nc1nc2ccc(F)cc2s1)c1cc(-c2ccccc2O)[nH]n1',
#  'Cc1cc(F)ccc1CCNC(=O)Cc1c[nH]c2c(C)cccc12',
#  'COc1ccccc1N1CCN(c2ccc(=O)n(CC(=O)NC3CC3)n2)CC1',
#  'C/C(=C/C(=O)N[C@@H](C)c1c(C)noc1C)c1ccccc1OC(F)F',
#  'COCCn1nc(C)c(NC(=O)N2CC[C@H](Cc3ccccc3)C2)c1C',
#  'Cc1ccsc1C[NH+](Cc1nc2ccccc2n1C(C)C)C[C@H](C)O',
#  'Cc1cccc(CNC(=O)C[C@H]2Oc3ccc(C)cc3NC2=O)c1',
#  'C[C@@H](c1ccc([S@](C)=O)cc1)N(C)C(=O)c1cc2cccc(F)c2o1',
#  'COc1cc(OC)c(C(C)=O)cc1CSc1nnnn1-c1ccccc1',
#  'CC[C@@H]1CCCCN1C(=S)NC(=O)c1ccc(C)cc1',
#  'CCC[C@H](C)C(=O)N[C@H](C)c1cccc(Br)c1',
#  'COc1cccc([C@H]2CCCN2C(=O)c2ccccc2I)c1',
#  'C[C@H](NC(=O)N1CCCC[C@@H]1C1OCCO1)c1cccc(-n2ccnc2)c1',
#  'CS(=O)(=O)N1CCC[C@@H](C[NH+]2CCC[C@H](CO)C2)C1',
#  'CCN(C(=O)Cn1nc2n(c1=O)CCCCC2)[C@H]1CCS(=O)(=O)C1',
#  'COc1ccccc1NC[C@H]1CCCN(S(C)(=O)=O)C1',
#  'O=C(CNc1ccc(Cl)cc1NC(=O)c1ccco1)Nc1ccc(F)c(Cl)c1',
#  'Cc1nn(C)cc1[C@@H](C)NC(=O)C(=O)Nc1ccc(OCC2CCCCC2)cc1',
#  'COC[C@H](NC(=O)Nc1cn[nH]c1)c1ccc(F)c(F)c1',
#  'C[C@@H]1CS(=O)(=O)N(c2ccc(S(=O)(=O)Nc3ccccc3C(F)(F)F)cc2)C1=O',
#  'CC[C@@H](C)C(=O)NCC(=O)N(C)[C@@H](C)c1cc(F)ccc1F',
#  'CO/N=C\\C(C#N)=C/c1cccnc1',
#  'CO[C@H](c1ccc(Cl)cc1)[C@@H](C)NC(=O)C(=O)Nc1ccccc1C',
#  'Cc1nc(Br)ccc1NC(=O)NCc1cnn(C)c1',
#  'COc1c(C)cnc(CNC(=O)Nc2ccc(N(C)C)cc2)c1C',
#  'COc1ccc2cc(COC(=O)COc3ccccc3C#N)ccc2c1',
#  'CCS(=O)(=O)CCN(C)Cc1c[nH]nc1-c1ccc(C)cc1',
#  'O=C1CC[C@@H](NC(=O)COc2ccc(Cl)c(Cl)c2)CN1',
#  'Cc1noc(C)c1COc1ccc(C[NH2+]C[C@H]2CCCO2)cc1',
#  'N#Cc1cnn2c1N[C@@H](c1ccccc1)C[C@@H]2C(F)F',
#  'C[C@@H]1Cc2ccccc2N1C(=O)[C@H]1CCCN(C(=O)NC2CC2)C1',
#  'COCc1nc(C(=O)OCC2=CC[C@H]3C[C@@H]2C3(C)C)cs1',
#  'CCN(Cc1ccc(Br)s1)C(=O)C[NH+](C)CC(=O)[O-]',
#  'O=C([O-])[C@H]1CCCN(c2ccc([O-])nn2)C1',
#  'COc1ccc(CCCC(=O)Nc2cccc(S(N)(=O)=O)c2)cc1F',
#  'Fc1ccccc1[C@@H](c1nnnn1C1CCCCC1)[NH+]1CCN(c2ccccc2)CC1',
#  'C[C@H]([NH2+]CC(=O)N(C)C)c1ccc(Cl)s1',
#  'Cc1ccc(C)c(S(=O)(=O)N2CCN([C@H](C)c3nc(N)nc(Nc4ccccc4)n3)CC2)c1',
#  'Cc1cccc(C)c1-n1nnnc1CSCc1nnc(C)n1C',
#  'COc1cccc(C(=O)N[C@@](C)(C(N)=O)c2cccc(Cl)c2)c1',
#  'CCc1ccsc1-c1cnc(C[NH3+])o1',
#  'CC(C)C[C@@H]([NH3+])C(=O)N1CC[C@H](C(=O)[O-])[C@@H]1C',
#  'CC[C@H](C)Cn1c(CCCl)nc2c(C)nn(C)c21',
#  'Cc1csc([C@H](C)NC(=O)CCC[NH+]2CCCCC2)n1',
#  'CCC(=O)NN/C(C)=C/C(=O)NCC(C)(C)C',
#  'CCC(=O)N1CCC([NH+](C)Cc2ccc(SC)c(OC)c2)CC1',
#  'C[C@H](c1nc(C(C)(C)C)no1)[S@](=O)Cc1ncn(-c2ccccc2)n1',
#  'Cn1cnn(C[NH+](Cc2ccc(F)cc2)C2CC2)c1=S',
#  'C#CC(C)(C)NC[C@H]1CN(C)CCO1',
#  'C[C@H](NC(=O)[C@H]1CCCN1S(C)(=O)=O)c1ccc2c(c1)OCO2',
#  'O=C(Nc1ccc2ncccc2c1)C(=O)NC1CCC(O)CC1',
#  'CC(C)[C@H]([NH2+]CC1CCN(C(=O)OC(C)(C)C)CC1)c1cccnc1',
#  'O=C(Nc1cccc(N2CCCNC2=O)c1)C(=O)N1CCc2cc(F)ccc2C1',
#  'O=C(COc1ccc(Br)cc1)NOCc1ccccc1',
#  'CC(=O)C[C@]1(O)C(=O)N(Cc2ccc(C)cc2)c2c(C)cccc21',
#  'C[C@@H](Sc1cc(Cl)ccc1Cl)C(=O)N1CCC[C@H](CCC(N)=O)C1',
#  'Oc1cccc([C@@H]2CN(c3nccc(Oc4ccc(F)cc4)n3)CCO2)c1',
#  'COc1ccc([C@H](CNC(=O)c2cccc3ccccc23)[NH+]2CCCC2)cc1',
#  'CC1(C)[C@@H]2CC[C@@]1(C)[C@H](NC(=O)COc1ccc(C3SCCCS3)cc1)C2',
#  'Cc1c(C)n(-c2ccccc2)c2nc(C(=O)Nc3ccc(F)cc3)nc(N3CCCCC3)c12',
#  'CC(C)C(=O)Nc1cccc(NC(=O)C(=O)NCC[C@H]2C[C@H]3CC[C@@H]2C3)c1',
#  'CCNc1ncc(COCC2CCCCC2)s1',
#  'CC[C@H](C)C(=O)Nc1ccccn1',
#  'Fc1ccc(C[NH2+]C[C@@H]([C@H]2CCOC2)N2CCOCC2)c(F)c1',
#  'CCc1cc(Cn2cc(N)nn2)n(C)n1',
#  'O=C(NCc1ccc([N+](=O)[O-])cc1)N[C@@H]1CCCC[C@H]1CO',
#  'C[C@H](NC(=O)NC[C@H](C)C[C@@H](C)O)c1ccc(S(C)(=O)=O)cc1',
#  'CC(C)Oc1ccc(NC(=O)NC[C@H](C)N2CCOCC2)c(F)c1',
#  'CC(=O)O[C@H]1CC[C@H]2[C@H]3C[C@H](OC(C)=O)[C@]45C[C@H]4CC[C@]5(C)[C@@H]3CC[C@]12C',
#  'CC1=C(C(=O)OCC(C)C)[C@H](c2cccc(F)c2)c2c(n(C)c(=O)n(C)c2=O)N1',
#  'Cc1cc(C)c2c(-c3ccccc3)nc(SCC(=O)NC3CC3)n2n1',
#  'COc1cc2c(cc1OC)[C@H](C(=O)[O-])[C@H](c1cccc(Cl)c1)N(C)C2=O',
#  'COCCN1C(=O)CC[C@@H]2C[NH+](Cc3cc(C)ccc3C)CC[C@@H]21',
#  'CNC(=O)c1ccc(NC(=O)c2csc(-c3ccccc3)n2)cc1',
#  'CNc1nc(C2CCN(C(=O)Cc3ccccn3)CC2)[nH+]c2c1CN(C(C)=O)CC2',
#  'Cc1cc(C)n(C[C@@H](C)CNC(=O)NCc2cc3ccccc3o2)n1',
#  'Cc1nc2n(n1)C[C@H]([NH2+]C[C@@H](O)CN(C)Cc1ccccc1)CC2',
#  'c1ccc(Cn2c(SCc3ncon3)nnc2-c2cccs2)cc1',
#  'COc1ccc(OC)c(/C=C/C(=O)OCC(C)C)c1',
#  'Cc1ccccc1[C@@H]1C[C@H](C)N(C(=O)[C@@H](C)Sc2ccccn2)C1',
#  'Cc1occc1C(=O)/C(C#N)=C/c1ccc([C@@H]2C[C@H]2C)o1',
#  'CC[C@](C)(C[NH3+])[C@H](O)c1ccc2c(c1)OCO2',
#  'CC(=O)Nc1ccc(CN2CC[NH+](C3CCCC3)[C@H](CCO)C2)cc1',
#  'COc1ccc([C@H](O)[C@@H](C)NC(=O)[C@@H](C)SC)cc1',
#  'CCC(=O)N1CCC[C@@H]1c1cc(C(F)(F)F)c2c(=O)n(C)c(=O)n(C)c2n1',
#  'C[C@H]([NH3+])[C@@H](CC(=O)[O-])c1ccccc1',
#  'Cc1ccc([C@H]2C3=C(NC(=O)N2C)c2ccccc2C3=O)cc1',
#  'Cc1cc(C)cc(O[C@H]2CCCC(C)(C)[C@@H]2O)c1',
#  'COc1cc([C@H]2C(C(=O)Nc3ccccn3)=C(C)NC3=C2C(=O)CCC3)ccc1OCc1ccccc1',
#  'C[C@@H]1CCC[C@@H](NS(=O)(=O)Cc2cccc(N)c2)C1',
#  'CC(C)C[C@@H](NC(=O)[C@@H]1C[C@@H]1c1cccc(Cl)c1Cl)C(=O)Nc1cc[nH]n1',
#  'Cc1nc(CCC[NH+]2CCC[C@H]2C(N)=O)cs1',
#  'NC(=O)COc1cccc(CNC(=O)c2cc3cc(Cl)ccc3[nH]2)c1',
#  'COc1ccc(CNC(=O)c2cc(=O)c3ccc(Br)cc3o2)cc1',
#  'CC[C@@H](C)c1ccccc1N1C[C@H](C(=O)N2CCN(C)CC2)CC1=O',
#  'CC[NH2+][C@H](Cc1ccccc1Cl)[C@H]1C[NH+](C)CCN1C',
#  'C[NH+]1CCC(N[C@@H]2CC(=O)N(CCc3cccc(Cl)c3)C2)CC1',
#  'O=C(COc1ncnc2ccc(Br)cc12)Nc1ccccc1Cl',
#  'Cc1ccc(N2C(=O)[C@@H](Cc3cccc(C)c3)S/C2=C(/C#N)C(N)=O)cc1',
#  'CC(C)CN(C(=O)NCc1ccc(C(F)(F)F)cc1)C1CC1',
#  'ClCCc1nc2cccnc2n1CCn1cccn1',
#  'Cc1ccc(NC(=O)c2cc3ccccc3oc2=O)c([N+](=O)[O-])c1',
#  '[NH3+][C@@H](CSCc1nccs1)C(=O)[O-]',
#  'COc1ccc(C(=O)Nc2ccc(N3CCOCC3)cc2)c(O)c1',
#  'CC[C@@H](CSC)NC(=O)NCc1cccc(OC)c1',
#  'Cc1ccccc1NC(=O)COC(=O)c1ccc(Br)o1',
#  'COc1ccc2nc(Nc3ccc4c(c3)CCC4)sc2c1',
#  'C[C@H]([NH2+][C@H](C)CC(=O)N(C)Cc1cccc(Cl)c1)C1CCC1',
#  'CC1(C)CCCC[C@H]1[NH2+]Cc1c[nH]cn1',
#  'O=C(CSc1nnc(-c2ccco2)n1-c1ccccc1)c1ccc[nH]1',
#  'COc1ccc(Cc2nn(C[NH+]3CCCC3)c(=S)o2)cc1',
#  'COc1ccc2c(c1)CCN(C(=O)[C@H](C)n1nc(-c3ccccc3)ccc1=O)C2',
#  'CC(C)(C)c1nc(CC[NH2+]C2CCN(Cc3cccnc3)CC2)cs1',
#  'CCn1nnnc1/N=C/c1ccccc1OC',
#  'C/C(=C\\c1ccc2c(c1)CCO2)C[NH3+]',
#  'COc1ccc2oc(=O)c(C(=O)Nc3cc(OC)c(Cl)cc3OC)cc2c1',
#  'O=C(Nc1ccc(Cl)cc1)c1cc(S(=O)(=O)N2CCOCC2)c(Cl)cc1Cl',
#  'C#CCOc1ccc(/C=C2\\SC(=O)N(Cc3ccc(F)cc3)C2=O)cc1',
#  'CC1=C(C(=O)Nc2ccccc2Cl)[C@H](c2ccccc2Cl)NC(=S)N1',
#  'CN1C2=C(C#N)C(=O)CCN2c2ccccc21',
#  'COc1ccc(-n2c(C)cc(/C=C3\\C(=N)N4N=C(SC)SC4=NC3=O)c2C)cc1Cl',
#  'COC(=O)/C(C#N)=C\\Nc1ccc(S(=O)(=O)NC(C)C)cc1',
#  'O=C(OCCOc1cccc(Br)c1)c1cc(=O)c2ccccc2o1',
#  'Cc1cccc([C@@H](C[NH3+])S[C@H](C)CCO)c1',
#  'CCCN(CC(=O)NC)C(=O)Cc1cccc(Cl)c1',
#  'C[C@H](C#N)CNC(=O)C(=O)Nc1ccc2nc(C3CC3)oc2c1',
#  'CCc1ccc([C@H](CNC(=O)N2CCC[C@@H]2c2ccc3c(c2)OCCO3)[NH+](C)C)cc1',
#  'CC[NH+](C)CCNC(=O)N1CCC(CC(=O)[O-])CC1',
#  'CC1(C)CSC[C@H]([NH2+]CCC(=O)[O-])C1',
#  'COc1ccc(O[C@H](C)C(=O)N(C)[C@@H](C)Cc2cccs2)cc1',
#  'O=C(CNC(=O)c1ccccc1)N[C@@H](CO)Cc1c[nH]c2ccccc12',
#  'CC[NH2+][C@]1(C(=O)[O-])CC[C@@H](N2C[C@H](C)O[C@H](C)C2)C1',
#  'O=S(=O)(CC1CCC1)N[C@H](c1cccc(F)c1)c1ccccn1',
#  'CCC1(CO)CC[NH+](Cc2cc(OC)c(O)cc2Br)CC1',
#  'Cc1cc(=O)c(OCC(=O)Nc2nc(-c3cccnc3)cs2)c[nH]1',
#  'C[C@H]1CC[C@H](C(=O)[O-])[C@H]([NH+]2CCN3CCC[C@@H]3C2)C1',
#  'COc1ccc([C@@H]2CC(=O)C3=C(C2)N[C@@H]2N=NC(O)=C2[C@H]3c2ccc(Cl)c(Cl)c2)cc1OC',
#  'Cc1ccoc1C[NH+]1CC[C@@H](C)[C@H](C)C1',
#  'C[C@H](c1cccc(F)c1)N1CCN(C(=O)C[C@H]2CCOc3ccccc32)CC1',
#  'Cc1cccc(NC(=O)[C@@H](C)[NH+]2CCC[C@H](c3nncn3C3CC3)C2)c1',
#  'COc1ccccc1CN1CCO[C@H](c2cccc(OC(F)F)c2)C1',
#  'Cc1ncccc1NC(=O)C(=O)NCC[NH+](C)C(C)C',
#  'Cc1ccc(C)c([C@@](C)(O)[C@@H]2CCCc3cccnc32)c1',
#  'CC[S@](=O)[C@@H]1CCC[C@H]([NH2+][C@@H]2CCc3c(Br)cccc32)C1',
#  'Cc1cccc(CSC2=NC(=O)[C@H]3C(=N2)NC(=O)C[C@H]3C(=O)Nc2ccc(F)c(Cl)c2)c1',
#  'O=C1C[C@H](c2ccccc2C(F)(F)F)[C@H]2C(=O)N=C(c3ccccc3)N=C2N1',
#  'C[C@H](NC(=O)c1cc(-c2ccco2)[nH]n1)c1ccc(Cl)s1',
#  'C[C@H]1CCCCN1c1ncnc(N(Cc2ccccc2)Cc2ccccc2)c1N',
#  'Cc1nc(C2CCCC2)sc1-c1nc(-c2ccc(C#N)cn2)no1',
#  'Cc1ccc(-n2ncc(C(=O)N3CC[C@@H](C)[C@H](O)C3)c2C2CC2)cc1Cl',
#  'NC(=O)c1c(F)cccc1Nc1cccc(N)c1',
#  'CC1(C)Cc2occc2[C@@H]([NH2+]Cc2ccc(COC3CCOCC3)cc2)C1',
#  'CN(c1ncncc1N)[C@H]1CCSC1',
#  'CC[C@H](C#N)NCCCC(=O)NC1CC1',
#  'CC1CCN(C(=O)c2cccc(NC(=O)c3ccccc3OC(C)C)c2)CC1',
#  'CS(=O)(=O)Oc1ccc(CN(C[C@H]2CCCO2)C(=O)Nc2cccc(F)c2)cc1',
#  'O=C([O-])C1([C@@H]2CCCC[C@H]2O)CCOCC1',
#  'COCCN1CCN(C(=O)N[C@@H]2CCN(c3ccc(Cl)c(F)c3)C2)CC1=O',
#  'Cc1cscc1C[NH2+]C[C@@H](O)C[NH+]1CCCC1',
#  'CC(C)c1ccc(OC(=O)C[C@H]2CCCO2)cc1',
#  'C[NH+](C)CCN(C(=O)c1ccco1)c1nc2ccc(S(C)(=O)=O)cc2s1',
#  'CC[C@H](C)[NH2+]CCc1n[nH]c(-c2ccco2)n1',
#  'C[C@H](Oc1ccc(Br)cc1)C(=O)NCCc1c[nH]c2ccccc12',
#  'CCN(Cc1cc(Cl)ccn1)c1ccccc1F',
#  'COc1ccc(C)cc1[C@H](C)[NH2+]Cc1cccc(C(N)=O)c1',
#  'CCn1c([O-])c(C(=O)C[C@@H]2NCCc3ccccc32)c(=O)n(CC)c1=S',
#  'O=C1COc2cc(OCc3c(F)cccc3Cl)ccc21',
#  '[NH3+][C@@H](CSc1ccccc1F)[C@@H]1CCc2cccnc21',
#  'CN1CCN(S(=O)(=O)c2cc(C(=O)Nc3ccc(Cl)c(Cl)c3)ccc2F)CC1',
#  'CS(=O)(=O)N1CCC(NC(=O)c2ccc(C(F)(F)F)nc2)CC1',
#  'CC(=O)N[C@@H](C(=O)Nc1ccc(NCc2ccccc2)c(Cl)c1)C1CCCC1',
#  'CCC(CC)[C@H](CNC(=O)c1cnc2c(C)cccn2c1=O)[NH+](C)C',
#  'C=CCOC(=O)C1=C(C)Nc2c(c(=O)n(C)c(=O)n2C)[C@@H]1c1ccc(OC)cc1OC',
#  'Cc1cccc(O[C@H](C)C(=O)N[C@@]2(C)CCS(=O)(=O)C2)c1',
#  'CCCCN1C(=O)/C(=N\\NC(=O)COc2cccc3ccccc23)c2ccccc21',
#  'C[C@@H](CS(C)(=O)=O)NC(=O)CCN1C(=O)CCc2ccccc21',
#  'CCC[NH2+][C@H]1[C@H](S(=O)(=O)C(C)C)CCC1(C)C',
#  'Cc1ccc(CCNC(=O)c2cc(C)c3c(=O)[nH]c([O-])nc3n2)cc1',
#  'CC(C)NS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)cc2)cc1',
#  'CC[S@@](=O)[C@@H]1CCCC[C@@H]1NC(=O)c1ccc(-n2cncn2)c(F)c1',
#  'CCC1(CC)C(=O)NC(=NNC(N)=S)NC1=O',
#  'CC[C@H](NC(=O)N[C@H](c1ccccc1)C(C)(C)C)c1c(C)nn(C)c1C',
#  'COc1cccc(N[C@@H]2CCS(=O)(=O)C2)c1',
#  'COC(=O)c1ccc([C@@H]2Nc3ccc([N+](=O)[O-])cc3[C@@H]3C=CC[C@H]32)cc1',
#  'O=C(NCc1ncc(-c2ccccc2)o1)N[C@@H]1CCC[C@@H]1CO',
#  'C[NH2+][C@H](c1ccc(OC)c(C)c1)[C@@]1(C)CCCO1',
#  'FC(F)(F)c1[nH]nc2c1CN(Cc1ccccc1)CC2',
#  'CC(C)(C)c1ccc(C(=O)N/N=C/c2ccc3c(c2)OCO3)cc1',
#  'CCc1ccc(S(=O)(=O)NCC2([NH+](C)C)CCOCC2)s1',
#  'COc1c(C)cccc1CN1CCO[C@@H](c2cc(C(=O)N(C)CCO)c3ccccc3n2)C1',
#  'O=C(CS(=O)(=O)C1CCCC1)NCc1cc(F)cc(F)c1',
#  'C[C@H]1CCOCCN1C(=O)NCc1ccc(-n2ccnc2)nc1',
#  'Cc1cc(Br)ccc1N1C[C@H](C)CS1(=O)=O',
#  'Cc1nc(NC(=O)c2nn(-c3ccc(Cl)cc3)ccc2=O)sc1C(=O)OCC(C)C',
#  'O=C(N[C@H]1C[C@@H]2CCCc3cccc1c32)c1ccccn1',
#  'CC(C)[C@@H]1C(=O)NCC[NH+]1Cc1cc(F)cc(F)c1',
#  'CC[C@H](C)NC(=O)c1sc(C)cc1OC',
#  'C=CCN(C(=O)c1cccc(NC(C)=O)c1)c1nc(-c2ccccc2)cs1',
#  'Cc1ccc(Oc2cccc(C(=O)Nc3nccs3)c2)nn1',
#  'CC(=O)Oc1ccc(C(=O)NNC(=O)c2cccnc2)cc1',
#  'Cc1c(F)cccc1NC(=O)NCCCC[NH+]1CCC[C@@H](C)C1',
#  'Cc1cn2c([nH+]1)CC[C@H](NS(=O)(=O)N1CCO[C@H](C)C1)C2',
#  'NC(=O)c1ccsc1NC(=O)COC(=O)c1cccc(-n2cccc2)c1',
#  'Cc1cc(C(=O)NCC2CCN(C(=O)Cc3cccs3)CC2)no1',
#  'N#Cc1cccc(NS(=O)(=O)c2ccccc2F)c1',
#  'CC(C)C(=O)Nc1ccc(S(=O)(=O)NCC2CCN(c3ncccc3C#N)CC2)cc1',
#  'CNC(=O)CN1CCN(C(=O)c2nc(C)n[nH]2)CC1',
#  'CC(C)c1ccc([C@H]2C[C@@H]2C(=O)N2CCN(CC(N)=O)CC2)cc1',
#  'Cc1ccc(C)c(N2C[C@@H](C(=O)Nc3nnc(CCNC(=O)c4ccccc4Cl)s3)CC2=O)c1',
#  'COc1ccc(NC(=O)C2CCN(S(C)(=O)=O)CC2)c(OC)c1',
#  'Cc1cccc(NC(=O)Nc2cc(NC(=O)Nc3cccc(C)c3)c(C)nc2C)c1',
#  'COCC[N+]1=C(C)C[C@@H](C(=O)CSc2nccc([O-])n2)[C@H]1C',
#  'CC(C)[NH+]1CCC(N2CCN(CC3=c4ccccc4=[NH+]C3)C[C@@H]2CCO)CC1',
#  'CNC(=O)Cn1ccc2ccc(NC(=O)Cc3cccc([N+](=O)[O-])c3)cc21',
#  'Cc1ccc(CCN2C[C@]34C=C[C@H](O3)[C@H](C(=O)N3CC(O)C3)[C@H]4C2=O)cc1',
#  'CCn1nc(C)cc1C(=O)Nc1nc(-c2ccco2)cs1',
#  'O=C(c1ccc(-c2ccccc2)cc1)N1CCN=C1SCc1cccc(F)c1',
#  'CCn1c(CC[NH3+])nnc1Sc1ncnc2ccc(F)cc12',
#  'Cn1ncnc1NC(=O)NCCCC[NH+]1CCCC1',
#  'C[C@H](Nc1cc(F)cc(F)c1)c1cc(F)ccc1O',
#  'C=CCNC(=O)/C(C#N)=C\\c1ccc(OCC)cc1',
#  'CC(C)[C@H](NC(=O)c1cccs1)C(=O)NN1CCOCC1',
#  'C[C@H]1COC2(CCN(Cc3cc4ccccc4s3)CC2)O1',
#  'Cc1cc(CCl)cnc1N(C)c1ccccc1',
#  'CC[NH2+]Cc1ccc(OCC(=O)Nc2ccccc2)cc1',
#  'CN(c1cc(C[NH3+])ccn1)C1CCCC1',
#  'C=C1c2ccccc2C(=O)N1CC(=O)Nc1cccc(C(=O)NCCC)c1',
#  'CC(C)NC(=O)CCNC(=O)[C@@H]1C[C@@H]1c1cccc2ccccc12',
#  'C[C@H]1CC(N)=C(C#N)C1(C#N)C#N',
#  'CC(=O)N[C@@H](CC(=O)N[C@H](C(N)=O)C(C)(C)C)c1c(F)cccc1F',
#  'O=C(Cc1ccc2ccccc2c1)N(Cc1ccccc1)[C@H]1CCS(=O)(=O)C1',
#  'C[C@H]1CCC[C@H](NC(=O)CN2CC[NH+](C/C=C/c3ccco3)CC2)C1',
#  'Cc1cnn(CCCNC(=O)N2CCCC[C@H](N3CC[NH+](C)CC3)C2)c1',
#  'Cc1ccc(S(=O)(=O)N2CCC[C@@H]2C(=O)N(C)Cc2cccc(Cl)c2)cc1',
#  'CC(C)CC[C@@H](C)NC(=O)Nc1ccc([S@@](C)=O)c(F)c1',
#  'Fc1cccc(Oc2nc(-c3ccncc3)nc3c2CCC3)c1F',
#  'COc1cccc(CNC(=O)CSc2nnc(-c3ccc4[nH]c(C)c(C)c4c3)o2)c1',
#  'NC(=O)c1c(NC(=O)c2cc([N+](=O)[O-])ccc2N2CCOCC2)sc2c1CCC2',
#  'CC1(C)O[C@@H]2O[C@@H]3OC(C)(C)O[C@H]3[C@@H]2O1',
#  'CN(C)/C=C/C(=O)Oc1ccc(Cl)cc1',
#  'COC(=O)c1sc(NC(=O)Cc2csc(C(C)C)n2)nc1C1CC1',
#  'Cc1ccc2nc(NC(=O)c3ccc(N4CCCC4)c([N+](=O)[O-])c3)sc2c1',
#  'Cc1ccsc1[C@@H](C)[NH2+]CC1CCC(C(N)=O)CC1',
#  'Cc1ccc(C[NH+]2CCN(c3nc4c(c(=O)[nH]c(=O)n4C)n3Cc3cccc(C)c3)CC2)cc1',
#  'O=C(COC(=O)c1ccnnc1)Nc1ccc(C(F)(F)F)cc1',
#  'CC(C)CNC(=O)CNC(=O)[C@H]1CCC[NH+]1Cc1ccc(F)cc1',
#  'CC(=O)NNC(=O)c1ccsc1NC(=O)c1ccc([N+](=O)[O-])cc1',
#  'CCC[C@@H](C(=O)Nc1ccc(C)nc1C)/C(N)=N/O',
#  'C[C@H](C#N)Sc1nc(-c2ccccc2)cs1',
#  'C[C@H](Oc1ccc(F)cc1)C(=O)NCc1ccccn1',
#  'Cc1ccoc1[C@@H](C)[NH2+]C1CCN([C@@H](C)c2ccncc2)CC1',
#  'O=C(c1ccccc1Nc1cccc(C(F)(F)F)c1)N1CCCCC1',
#  'O=S(=O)(N[C@@H]1CCCOc2ccc(F)cc21)c1ccc2c(c1)OCCCO2',
#  'CC(C)Oc1ccccc1NC(=O)C(=O)NCc1ccncc1',
#  'CCC(=O)Nc1cc(C(=O)OCC(=O)c2cccs2)ccc1C',
#  'CCS[C@@H]1CC[C@@H](NC(=O)C(=O)Nc2cc(C)nn2C)C1',
#  'CCCCOc1ccc(C(=O)NCc2ccccc2Cl)cc1',
#  'CCc1nsc(N2C[C@@H](C)C[C@@H]2c2ccccc2F)n1',
#  'CC1(C)[C@H]2CC[C@]1(CS(=O)(=O)NCc1ccccc1N1CCOCC1)C(=O)C2',
#  'COc1cccc([C@H]2CCCN2C(=O)Nc2ccc(N3CCCC3=O)cc2)c1',
#  'C=CCN1C(=O)/C(=C/c2cccc(C)c2)S/C1=N/c1nnc(C)s1',
#  'O=C(CCc1nc2ccccc2[nH]1)NCCC(=O)N[C@@H]1CCS(=O)(=O)C1',
#  'c1ccc(-c2csc3ncnc(Nc4ccc5c(c4)OCCO5)c23)cc1',
#  'Cc1csc(C2([NH2+]Cc3cnc(-c4ccsc4)s3)CCCC2)n1',
#  'Cc1cccc(N2CCN(C(=O)c3cc(C4CC4)on3)CC2)c1',
#  'Cc1nc(Nc2ccc(OCC3CCOCC3)cc2)c2cc[nH]c2n1',
#  'CCSC1(CNC(=O)Nc2cc(-c3ccccc3)on2)CCOCC1',
#  'C[C@H](Cn1ccnc1)NS(C)(=O)=O',
#  'CCc1cccc(C)c1NC(=O)C[C@H]1C[NH2+]CCO1',
#  'COc1cccc(C[NH+]2CCC[C@H](C(=O)c3ccc(SC)cc3)C2)c1OC',
#  'NNC(=O)[C@@H]1CC[C@H](CSc2cccc(F)c2)O1',
#  'CSc1ncc2c(-c3ccccc3)n[nH]c2n1',
#  'CC[C@@H]1Oc2ccc(NC(=O)OCc3ccccc3)cc2CN([C@H](C)CC)C1=O',
#  'O=C(CCC(=O)N1CCN(c2cccc(Cl)c2)CC1)Nc1ccc2[nH]ccc2c1',
#  'C#CCOc1c(Cl)cc(/C=C2/C(=O)N(c3ccc(F)cc3)C(=O)N=C2[O-])cc1OC',
#  'COc1ccc([C@H](C)NC(=O)CC(C)(C)C)cc1OC',
#  'O=C(NCCCn1nc(C(F)(F)F)cc1C1CC1)c1ccc(Br)o1',
#  'CCCN[C@@]1(C#N)CC[C@@H](n2cc[nH+]c2CCC)C1',
#  'CN(C(=O)c1ccc(CN2CC[NH+](C)CC2)cc1)[C@@H]1CCc2ccccc21',
#  'COCCNC(=O)CSc1nc2c(c(=O)n1-c1ccc(F)cc1)S[C@@H](C)C2',
#  'CNC(=S)NNc1ccc(Br)cc1',
#  'O=C(NC[C@@H]1CCC[NH+](CC2=c3ccccc3=[NH+]C2)C1)[C@H]1NN=C2C=CC=C[C@H]21',
#  'COc1cccc([C@@H](NC(=O)[C@@H](C)c2ccsc2)c2nccn2C)c1',
#  'CC(=O)NCCNC(=O)c1cnn(-c2ccc(C)c(Cl)c2)c1C1CC1',
#  'Cc1ccc(C(=O)N(C)C)cc1OCC(=O)NCc1ccc(Cl)cc1',
#  'Cc1ccc2cc(C(=O)NCCCCC(N)=O)[nH]c2c1',
#  '[NH3+]CCCN(C(=O)N1CCCC1)c1ccc(F)cc1',
#  'CCN(CC)c1ccc(N)c(N)[nH+]1',
#  'Cc1cc(NC(=O)C(=O)Nc2cn[nH]c2)n(-c2ccccc2C)n1',
#  'Cc1nc(C2CCN(C(=O)N[C@H]3CCCN(c4cnn(C)c4)C3)CC2)no1',
#  'COC(=O)[C@H](NCC(F)(F)F)c1cncn1C1CC1',
#  'COc1ccc(-c2nc(CNC(=O)N[C@@H]3C[C@](C)(OC)C3(C)C)n[nH]2)cc1',
#  'CCC[NH+](CCO)C[C@H]1[C@H](N)C(C)(C)OC1(C)C',
#  'O=C(NCc1ccccc1-n1ccnc1)C(=O)Nc1ccc2[nH]ccc2c1',
#  'Cc1ccc(O[C@H](C)CNC(=O)[C@H]2CS[C@@]3(C)CCC(=O)N23)cc1',
#  'Cc1nc(-c2ccc(F)cc2)sc1C(=O)NNC(=O)C(C)(C)C',
#  'O=C(COc1ccc(Cl)cc1Cl)Nc1nnc(-c2ccc(C(F)(F)F)cc2)o1',
#  'COc1ccc(N2C(=O)/C(=C/c3c(C(=O)[O-])[nH]c4cc(OC)ccc34)SC2=S)cc1',
#  'CCCC[C@H](CC)CNC(=O)Nc1ccc(C#N)cc1',
#  'CCOc1ccccc1-c1cccc(C(=O)N(C)CCC(F)(F)F)c1',
#  'Cc1cc(Br)cc(C)c1NC(=O)c1nnn[n-]1',
#  'CCCN(C(=O)c1cccc2c(=O)c(C)c(-c3ccccc3)oc12)[C@@H]1CCS(=O)(=O)C1',
#  'NC(=O)c1cccc(CNC(=O)[C@@H]2C[C@H]3CC[C@@H]2O3)c1',
#  'C/C(=C\\c1ccccc1)C(=O)Nc1ccc([N+](=O)[O-])cc1C',
#  'COc1ccc([C@@H]2c3c(-c4ccc(Cl)cc4)n[nH]c3C(=O)N2C2CCCC2)cc1OC',
#  'Cc1cc2cc(CCNC(=O)c3ccccc3[N+](=O)[O-])c(=O)[nH]c2cc1C',
#  'C[C@H]1CN(C(=O)[C@@H]2CCS(=O)(=O)C2)C[C@H](C)O1',
#  'COc1ccc(-n2c(C)cn3c4c(=O)n(CC(C)=O)c(=O)n(C)c4nc23)cc1',
#  'CC(=O)N[C@H](Cc1c[nH]c2ccccc12)C(=O)N1CCN(C(=O)c2cccc(F)c2)CC1',
#  'C[C@@H](Oc1cccc(Cl)c1Cl)C(=O)N1CCC(CN(C)C(=O)OC(C)(C)C)CC1',
#  'COc1cccc(CNC(=O)c2ccc([N+](=O)[O-])cc2F)c1',
#  'O=C(Cc1cc(F)ccc1F)N1CCO[C@@H](c2ccc(Cl)cc2)C1',
#  'Cc1ccc([C@@H]2CSCCN2C(=O)N[C@@H]2[C@@H]3CCO[C@@H]3C2(C)C)o1',
#  'O=C(CCc1nnc2ccc(NCc3ccccc3Cl)nn12)Nc1ccc2c(c1)OCCO2',
#  'Cc1ccc(NC(=O)NC(=O)[C@H](C)N2C[C@H](C)O[C@H](C)C2)cc1',
#  'CCOC(=O)c1c(C)[nH]c(C(=O)/C(C#N)=C/c2cccc(F)c2)c1C',
#  'O=C(Nc1cccnc1)N1CCN(C[C@H](O)c2ccccc2)CC1',
#  'CCCCC(=O)N1CCN(c2nc3cccnc3s2)CC1',
#  'Cc1ccccc1Cc1noc(CSc2ncnc3nc[nH]c23)n1',
#  'COc1ccc([C@@H](C)[NH2+][C@@H](C)c2ccc(F)cn2)c(OC)c1',
#  'Fc1ccc([C@H]2Oc3ccc(Cl)cc3C3=C2[C@H](c2cccnc2)N2NC=NC2=N3)cc1',
#  'Cc1cc(=O)n(C)cc1NC(=O)[C@H](C)Oc1ccc(F)c(F)c1',
#  'CC(C)N(C)C(=O)NCc1ccnc(OC(C)(C)C)c1',
#  'COc1ccccc1[C@H](C)NC(=O)C[NH+](C)C1CCS(=O)(=O)CC1',
#  'Cn1cnnc1C[NH+]1CC[C@]2(CCCN(C3CCCC3)C2=O)C1',
#  'CN1CCc2cc([C@H](CNC(=O)C(=O)Nc3ccccc3F)[NH+](C)C)ccc21',
#  'C[C@H]1CN(c2ccccc2C#N)C(=O)CN1C(=O)CCc1cc([O-])no1',
#  'COc1ccccc1[C@H]1CCCN1C(=O)Nc1ccc(C(=O)NCC(C)C)cc1',
#  'CCn1ncc(Br)c1C(=O)N[C@@H]1C(=O)N2C(C(=O)NCC(C)C)=C(C)CS[C@@H]12',
#  'O=C(NC1CCCCC1)[C@H]1SC(=S)n2c1nc(=O)c1cc3c(cc12)OCO3',
#  'Brc1cccc(-c2csc(Nc3cccnc3)n2)c1',
#  'Cc1cccc(C)c1-n1nnnc1CS(=O)(=O)[C@@H](C)c1c(F)cccc1F',
#  'C[C@@H](C[C@@H]1CCCCC[NH2+]1)[NH2+]CC(C)(C)C',
#  'CCOC(=O)c1ccc(N[C@H]2c3ccccc3C(=O)N2Cc2ccc3c(c2)OCO3)cc1',
#  'Cc1nn(C)c(C)c1[C@H](C)NCCc1nc2c(F)cccc2n1C',
#  'CCC[C@@H](CC(=O)OC)NC(=O)[C@@H]1OCC[C@H]1C',
#  'COCCOc1cccc(C[NH+]2CCC2(C)C)c1',
#  'Cc1noc(C)c1[C@H]1CCCN1C(=O)CCc1nc(-c2ccccc2)no1',
#  'Cn1cc(C(=O)N[C@H]2C[C@H]3CC[C@@H]2O3)c(-c2ccccc2)n1',
#  'Cc1cnc2nc(Cc3ccsc3)[nH]c2c1',
#  'Cc1ccc([N+](=O)[O-])cc1-n1c(C)cc(/C=C2/C(=N)N3N=C(c4ccccc4)SC3=NC2=O)c1C',
#  'c1ccc(-n2nnnc2NC[C@@H]2CCOC2)cc1',
#  'CCN(C(=O)CNC(=O)NCC1CCCC1)c1nc(C)cs1',
#  'O=Cc1ccc(-c2cc(C(F)(F)F)cc(Cl)n2)cc1',
#  'C[C@H]1CN(c2oc(-c3ccccc3)nc2S(=O)(=O)c2ccc3c(c2)OCCO3)C[C@@H](C)O1',
#  'C[C@@H]1Cc2ccccc2N1S(=O)(=O)CCNC(=O)[C@H]1CC(=O)N(c2cccc(F)c2)C1',
#  'C[C@@H](NCc1nnc(-c2ccccc2)s1)c1ccc(-c2ccccc2)o1',
#  'CCOCCn1c(C(C)(C)C)cn2c3c(=O)n(C)c(=O)n(C)c3nc12',
#  'CCc1ccc(C(=O)CCC(=O)Nc2ccc(N3CCSCC3)cc2C)cc1',
#  'CS(=O)(=O)N1CCCN(S(=O)(=O)c2ccc(F)c(F)c2)CC1',
#  'Cc1nnc(CN(C)Cc2cc(Cl)ccc2F)n1C',
#  'COc1ccc(Br)cc1C(=O)NC(=S)Nc1cc(C)cc(C)c1',
#  'COC[C@H](C)Cc1nnc(C[NH3+])o1',
#  'O=C(Nc1ccc2c(c1)COC2)C(=O)N[C@@H]1CCOC2(CCCCC2)C1',
#  'CC(C)(C)[C@@H](CS)C[NH+]1CCN(c2ccccc2Cl)CC1',
#  'CC1=[N+](c2ccc(C)cc2)C(SCC(=O)Nc2cccc(C(F)(F)F)c2)=NC(C)(C)C1',
#  'O=C(NCCN1CCOCC1)C1=Cc2ccccc2OC1',
#  'Cc1ccccc1CS(=O)(=O)N1CCC[C@@H](C(=O)Nc2ccc(Br)cc2F)C1',
#  'Cc1ccc(-[n+]2cc(-c3ccc(Br)cc3)n3c2CCC3)cc1',
#  'Cc1nc(-c2ccccc2)c2c(n1)[C@@]1(C)CC[C@@H]2C1(C)C',
#  'Cc1noc(C)c1COc1ccc(C(=O)N[C@@H](C)c2c(C)noc2C)cc1',
#  'O=C(Nc1cccc(SC(F)F)c1)C1(O)Cc2ccccc2C1',
#  'CC1CCN(c2ccc([N+](=O)[O-])cc2C(=O)NCc2ccc3c(c2)OCCO3)CC1',
#  'NC(=O)[C@]1([NH2+]C2CC2)CC[C@H](Oc2cc(F)cc(F)c2)C1',
#  'COc1ccc([C@@H](Cc2ccccc2C)NS(C)(=O)=O)cc1OC',
#  'O=C(N[C@H]1C[NH+](C(CO)CO)C[C@@H]1C1CC1)c1ccsc1',
#  'C[C@@H]1CCCC[C@H]1[NH+]1CCC([NH2+][C@@H]2CCCCC[C@@H]2CO)CC1',
#  'CCC[NH+](C)C[C@@H]1CCN(Cc2cc(Br)ccc2[N+](=O)[O-])C1',
#  'Cc1cccc([C@H]2CCCC[NH+]2Cc2noc(C3CC3)n2)c1C',
#  'CC(C)C/C([O-])=N/S(=O)(=O)Cc1ccc([N+](=O)[O-])cc1',
#  'Clc1ccnc(-c2cccc(C3CC3)c2)n1',
#  'CC[C@H](CC(=O)N1CCOC[C@H]1C(N)=O)c1ccccc1',
#  'C[C@@H](C(=O)NCc1ccccc1F)C1CCN(C(=O)c2ccc3nc(-c4ccccc4)oc3c2)CC1',
#  'Cc1ccn2c(=O)c(C(=O)Nc3n[n-]c(C(F)(F)F)n3)cnc2c1',
#  'CC(C)Nc1ncnc(NNC(=O)c2ccco2)c1[N+](=O)[O-]',
#  'C=C(Br)CN1CCN(c2cc(C)[nH+]c(C)n2)CC1',
#  'Cc1cc([C@](C)(O)CNC(=O)[C@H]2CCCN2C(=O)CC(C)(C)C)c(C)o1',
#  'SCCCCn1cc[nH+]c1',
#  'CC(C)(C)OC(=O)[C@@H]1N[C@H](C(=O)[O-])C(C)(C)S1',
#  'C[NH2+][C@H](Cc1c(F)cccc1Cl)c1cscc1Br',
#  'O=C(NCC(=O)N1CC=C(c2ccccc2)CC1)NCc1ccccc1',
#  'Cc1ccc(-c2cccc(C[C@@]3(C(=O)NC(C)C)CCN(C(=O)C4CC4)C3)c2)cc1',
#  'CCSc1ccc([C@H](C)NC(=O)NCc2ncoc2C)cc1',
#  'O=C(Nc1cccc(NC(=O)N2CCC[C@H]2c2cccc(F)c2)c1)C1CC1',
#  'C[C@H](Cn1cccn1)[NH2+]CC(=O)N1C[C@H](C(N)=O)Oc2ccccc21',
#  'COc1cc(/C=C/c2cc(C(=O)[O-])c3ccccc3n2)ccc1OCC(=O)[O-]',
#  'O=C(CCC(=O)c1ccccc1)Nc1ccn(-c2ncccc2Cl)n1',
#  'Cc1nc(CCNC(=O)c2ccc(OCC(F)F)nc2)cs1',
#  'COc1cccc2cc([C@@H](C)NC(=O)N3CCC(CC[NH+](C)C)CC3)oc12',
#  'C[C@@H]1Cc2ccccc2N1C(=O)NCc1ccc[nH+]c1N1CCOCC1',
#  'C[C@H](CCc1ccccc1F)[NH2+]CCc1nc2cc(F)ccc2n1C',
#  '[NH3+]C[C@H]1CCC[C@H]1N1CCOCC1',
#  'COc1ncnc(N2CC[NH2+][C@H](C)C2)c1[N+](=O)[O-]',
#  ...]

# %%
# Task 2: Get the SMILES of the generated molecules from the pre-trained model

### YOUR CODE #####
from rdkit import Chem

smiles_generated = []
for i in range(0,len(generated_molecules)):
  smiles = Chem.MolToSmiles(generated_molecules[i])
  smiles_generated.append(smiles)

smiles_generated
# Out:
# ['COC1(C=CC2CCCCC2)CCCCN1',
#  'O=C(NCC1CCCC1)Nc1ccccc1Cl',
#  'Clc1ccncc1C1CCCCCS1',
#  'O=C1NNC(=O)C(c2ccccc2Br)[C@H](CCCO)N1',
#  'C#CC[C@@H](O)C=Cc1ccccc1',
#  'CC[NH+](C(=O)N(C)CC(C)C)C1CCCC(N)C1',
#  'O=C1CCC(CC2CCCC2)CO[C@H]1C1Cc2ccccc21',
#  'c1ccc(CC2CCc3ccccc3[NH+]C2)cc1',
#  'COc1conc1Nc1ccccc1C(=O)NCC=O',
#  'CC(C)c1cc(C(=O)NC(N)C(=O)c2ccccc2)cc(Br)c1N',
#  'O=Cc1ncccc1CCNCc1ccccc1Cl',
#  'CCOC1=CC=C(C)C=CN(CC(=O)Nc2c(C)cncc2COC)C1=O',
#  'CN1CC[C@@H]([NH2+]Cc2ccc([SH](C)(N)=O)cc2)CC(Oc2ccccc2)C1',
#  'CC1CCCCc2ccc(Cl)cc21',
#  'CC(C)(C)[NH2+]CC1(Cc2ccccc2)CC1',
#  'CC1CCC(S(=O)(=O)NC(C)C)C1',
#  'CSc1cccc(NCc2ccccc2Cl)c1',
#  'CC(C(=O)NC1CCCC1)c1ccccc1CCc1ncccn1',
#  'COc1ccccc1CCNc1ccc(N)cc1',
#  'COc1ccccc1CNC(=O)SCCOC1CCCO1',
#  'NC(=O)C1=C(C2CCN(Cc3ncccc3Oc3ccccc3)CC2)NC1=O',
#  'COC(CNC(=O)CN(C)C1CCCCN1)c1cccc(C)c1',
#  'Cc1ccc(F)cc1CCNC(=O)NCC1CCCC1',
#  'CCCCCC(=O)NNc1ccccc1Cl',
#  'c1ccc(OCCCCNc2ccnnc2-c2ccccc2-c2ccccc2)cc1',
#  'CCCCCNc1ccccc1CN[C@@H](C)COC',
#  '[NH3+]C1=CCC2CCCC[NH+]2CCCC1',
#  'CC1C(=O)NCCOc2ccccc2C=CN1CCOc1ccc[nH]1',
#  'C=C(CC(=O)OC)c1cccc2ccccc12',
#  'O=C(Sc1cccs1)c1ncc2ccocc1-2',
#  'C1CCC(CNC2CCOCC2)CC1',
#  'COc1ccc(C(=O)NCCN2CCCC2)cc1',
#  '[NH3+]CCC1CCCCC1C([NH3+])O',
#  'O=C(CC=C1N=C2C=CC=CC=C12)c1ccccc1CCCCO',
#  'Cc1nccnc1CCNc1cccc(-c2ccncn2)c1',
#  'COc1cc(O)cc([N+]CNC(=O)C(=O)NC(C)(C)C)c1',
#  'CCC1CCCC[C@@H]1OCN1Cc2ncccc2CC1C',
#  'O=C(COc1ccccc1-c1ccccc1)NO',
#  'O=C(Cc1ccccc1)NCNc1ccncc1',
#  'CC1C[C@H](CCO)N=C1NC(=O)SCC1Cc2ccccc2C(=O)N1',
#  'O=C1[NH2+]CCC1CCSc1ccccc1',
#  'CCOC(=O)NCCCNC1CCCCCCC1',
#  'CC(=O)C(C)(C)C(=O)N(C)CNC(C)CC(N)=O',
#  'c1ccc2c(c1)CC[NH+](CCC1CCCOC1)C2',
#  'CC(C(=O)Nc1ccccc1)C(=O)Nc1cccc(=S)c(N)c1',
#  'CC(C#N)C[NH2+]C(=O)c1ccc(F)cc1CNCC1CCCCC1',
#  'O=C(C[NH+]1CCc2ccccc2C1)NCCc1ccccc1C=C1CCC1',
#  'CCC(O)C(C)(C)C1CCC1([NH2+]C)C(=O)F',
#  'Cc1cccc(CCCNC(=O)CN2CCOCS2)c1',
#  'COc1ccccc1CNCc1ccccc1OCc1cccnn1',
#  'CC(Oc1ccccc1N(C)C1CCC1)C(=O)Nc1ccccc1',
#  'CCN(C)C(NCCc1ccns1)c1ccnnc1C',
#  'C1=CC2=CC(=C2OCCOc2ccccc2N2CCOCC2)C=C1',
#  'O=C(C1CCCCC1)[NH+]1CCCN(Cc2nccs2)C1',
#  'c1csc(CCCc2cccnc2OCCC2CCCC2)c1',
#  'N=c1c(Cc2ccc(O)cc2)ncc2cccnn12',
#  'CCOc1ccccc1[CH]c1ccccc1NCC=O',
#  'C1=C(CCN2C=c3ccccc3=NN2)[NH+]Cc2ccccc21',
#  'CSc1cc(Cl)cc2c1N(C)CCC(C)N(Cl)C2=O',
#  'c1nc(CC2COCC3COCCC32)no1',
#  'CC1CCCNCC[NH+]1Cc1ccccc1Oc1nccs1',
#  'CC1CN(CC(=O)NC(Cc2ccccc2)C(=O)Nc2ccccc2)C(=O)CC1(C)C',
#  'O=C1CC(C[NH+]2CCSC2)=C(CCCCC2CCCC2)N1',
#  'C1CCC2C[C@H](CC1)CCCCO2',
#  'CC(NC(=O)c1cnccn1)Nc1ccc([SH](C)(N)=O)cc1',
#  'CC(C)CNS(=O)(=O)C(C(=O)Nc1cccs1)c1ccc(N2CCCCC2)cc1',
#  'CC(C)(C)C(C(=O)Nc1ccccc1Br)C(=O)N1CCCCC1',
#  'N#Cc1nccc(C(=O)NC2CCCC2C[NH+]2CCCC2)n1',
#  'COCCOc1ccccc1C[CH-]CCC(C)C',
#  'COC(COC(=O)c1ccccc1)NC(=O)C1C[NH+](C)CCCC1C',
#  'COCCNc1ccc(NC(=O)C[NH+]2CCCC(c3ccccc3)C2)cc1',
#  'CC(=O)c1cc(C)sc1CC(C)[NH2+]CC(N)=O',
#  'O=C(COc1ccccc1-c1ccccc1)[NH+]1CCNCC1',
#  'CC1CCN(C(=O)NC(=O)c2cc(F)cc(Cl)c2)C1',
#  'O=C1C=C(C2CNCCOC2)C1c1ccccc1',
#  'Cc1ccc(NCCCN2CCCCCC2C)cc1F',
#  'CC(NC(C(=O)N1CCC[NH+](C)C1)c1ccccc1)C1CC1',
#  'Cc1ccccc1NC(=O)C(C)C1C=CCC1',
#  'c1ccc(CN2CCCC2)c(CCCCC2CCCCC2)c1',
#  'CC=CCNC(=O)c1ccc(C2NC2CCC)c(F)c1',
#  'O=C(NCCCc1ccsc1[C@H]1CCCNC1=O)c1ccccc1',
#  'CN(C(=O)C(N)CC(=O)[O-])c1ccc(C(C)(C)F)cc1',
#  'O=C1CCC1Oc1ccccc1F',
#  'CC(CCC1CCC(C2(O)C[NH2+]CCC2=O)NC1)Cc1ccccc1',
#  'CC(C)CCOc1cccc(C[NH+]2CCCCCC2)c1',
#  'CC(C(N)=O)c1ccc(C(=O)N2CCN(C)C2)cc1',
#  'COC1(C)CCN(C(=O)C(C)NC(=O)C(=O)c2cccc(NN3CCCCCC3)c2)C1',
#  'CC[NH+]=C[C@H]1CCC[SH]1Oc1ccccc1C',
#  'COc1cc(OC(=O)N2CCC2)ccc1OC(C)[SH](C)(=O)c1ccccc1',
#  'CCCCC1[NH+]CCC1COc1ccccc1NC(=O)N1CCCCC1',
#  'C[NH2+]C(C)c1c[nH]c(C(C(=O)N(C)C2CC2)c2cccc(Cl)c2)c1',
#  'Clc1ccccc1',
#  'CC1CCSCC1CC1NCCNC(=O)C1[NH-]',
#  'COCCN1CCCN1CCOCCOc1ccccc1O',
#  'COc1cccc2nc(NC(=O)C(C)C(C)C)nc-2c1',
#  'CC(=O)Nc1ccccc1C',
#  'C[C@H]1CCCOC[NH2+]1',
#  'c1ccc(NCC[NH+]2CCC3CCC2CC3)cc1',
#  'c1ccc(CC[NH2+]CC2CCC[NH+]2Cc2nccnn2)cc1',
#  'CC(C)CNC(=O)[C@H]1NS1(=O)=NS',
#  'CCc1cccc(Br)c1',
#  'CC(=NCc1ccccc1)NCCN(C)C1CCOCN(C)C1',
#  'CN(C(=O)NC1CCCC1)c1cccc(F)c1F',
#  'C1CCCC(CCCC2CCCC2)[NH2+]CC1',
#  'CCCCNC(=O)CCc1nn(C)nc1NC[C@H]1CCC[C@@H]1C',
#  'CNC(C(=O)Nc1ccccc1)[NH+]1CCCCC1',
#  'COc1cc(NC(=O)C(=O)C(N2CCCC2)C2(Br)CCC2)cc(C)c1OC',
#  'COC(=O)N1CCC(c2ccccc2Cl)C1',
#  'CCOC(C)C(CC)C(=O)Nc1ccc(C)cc1',
#  'CCC(=O)N1CC[NH+](C(=O)c2ccncc2)[C@H]1CC(=O)OC',
#  'CC(=NC(=O)N1CCOCC1)C(C(N)=O)C1CCN1C(C)(C)C',
#  'Cc1ccccc1[C@H]1SCC[NH+]1c1ccccc1',
#  'O=S(=O)(CN1CCCCC1)C(NCCc1ccc(Cl)cc1)c1ccccc1',
#  'OC=Cc1ccccc1Cl',
#  'CN1CCN(C(CC(N)=O)NC(=[NH+]O)C2C=C3C=CC(=O)C=C32)C1',
#  'CN(CC1CCCC1)C(=O)c1cccc2ccccc12',
#  'CC(=O)N1CCCN1C(=O)C(C(=O)Nc1c(C)noc1C)C(C)c1ccccc1',
#  'c1ccc(OCCOc2ccc3ccccc3n2)cc1',
#  'CCN1CCCC(C(C)N[NH2+]c2ccccc2)C(=O)N(NC2CCO2)C(C)C1=O',
#  'c1ccc(CSc2ccccc2CCOCCN2CCCCCC2)cc1',
#  'CC(C)(NC(=O)N1CCCCC1SCc1cccc(F)c1)c1ccccc1',
#  'NC(=O)NC(C(=O)N(C1CCCCC1)[NH+]1C[C]CCC1)C1CCC1',
#  'CCOC1CCCN1CCCc1ccccc1NC(=O)CN1CCCCC1',
#  'CC(C)(C)NC(=O)c1ccc(C(=O)OCC=CCc2ccc(O)cc2)cc1',
#  'COc1ccc(C2(C)CC(=O)NC2NC(=O)CC2CCC(C(=O)Nc3ccc(F)cc3)C2)c(O)c1',
#  'Cc1nc(Cl)no1',
#  'CC(=O)C(C(N)=O)C1CCN(C(N=N)C(=O)NCCc2ccccc2)CC1',
#  'O=NCCc1cc2ccccc2[n-]1',
#  'CC[NH+](C)CCCN1CCN(c2cccnc2)CS1',
#  'O=S(=O)(NCc1ccccc1-c1ccnnn1)c1ccccc1OCOc1cccnc1',
#  'CC1CCN(C(=S)NC2=CCc3ccccc32)CC1',
#  'CC1CCCCNC1',
#  'C[C@@H](NS(C)(=O)=O)[NH2+]CCc1c[nH+]ccc1F',
#  'CC(C)(CN1OCCOc2ccccc21)NCc1ccccc1',
#  'COCCCNC1CCCCC1O',
#  'CCOCCC1CCCN2C(C(=O)ON)=C12',
#  'CC(C)C1=C(Cl)C(C(=O)NC2=C(C(F)(F)F)N=N2)C=CC=CC=C1',
#  'c1ccc(Oc2ccccc2NC2CCCCCC2)cc1',
#  'CNCC[NH+]1CC[C@@H](c2cnccc2C)CC[NH+]1C',
#  'CC1CNC(=O)N[C@@H](C)CC[NH+]1CCc1ncccn1',
#  'CC(C(=O)Oc1ccccc1)=C1[C@H](C#N)CN1[C@H](O)CS',
#  'CC[N+]([O-])(C(C)(C)C)C(C)(C)C(=O)NCCc1ccccn1',
#  'CC1(C)CCCC1NC1CCC(O)C(NC(=O)NC(=O)C2CCC2)C1',
#  'O=C(CNC(=O)c1ncco1)NCc1ccccc1C1CCCCC1',
#  'CCc1ccccc1NC(=O)NS(=O)(=O)c1ccccc1',
#  'Cc1cocc1-c1ccccc1Cc1ncco1',
#  'CC1CCC1NC(=O)CCN(C)C',
#  'Cc1ccccc1C=[NH+]CC1CC1C(=O)NCC1CCS1',
#  'CN(CC(=O)N=NC1CC1C(OC(=O)[O-])C(C)(C)C)C(C)(C)C',
#  'COC1CCN(C(Cc2ccccc2)N(C(=O)C2CC2)C(=O)N2CCCO2)C1',
#  'CNC(=O)c1ccco1',
#  'O=C1C[NH2+][SH](F)[CH]CC[C@H](O)Oc2ccccc2N1',
#  'COCc1ccccc1C(=O)NCCOn1ccnc1',
#  'Fc1ccccc1[NH+]C1NCCC(c2ccc(-c3ccccc3)cc2)NCc2ccc1cc2',
#  'OCCNCCNCc1nccnc1Cc1ccccn1',
#  'N#Cc1[nH]nnc1CCNc1cccc(F)c1',
#  'Fc1ccccc1/C=C/NCc1ncncc1Br',
#  'Clc1ccccc1OC1CCCSC1',
#  'CC(=O)NC1(C)NC1CC(NCc1ccccc1)C(=O)Nc1ccccn1',
#  'CN1CCS[NH+](c2ccccc2-c2ncccn2)CC1',
#  'O=[N+]([O-])c1ccc(C(F)(F)F)cc1NC1CCCC1',
#  'c1ccc(OCCCCc2ccccc2-c2ccccc2)cc1',
#  'C=S(=O)(C(=O)[O-])N1CCC(Cc2ccccc2)C1',
#  'CN1CCCC(CNC(=O)NC(=O)C2CCCC2Oc2ccccc2)CC1',
#  'OCC1OCCCN1CCC1CC[NH2+]C1',
#  'COC(COc1ccccc1)C(N)=O',
#  'CC(=O)Nc1ccccc1NC(C)C(C)C(N)=O',
#  'CC(=O)C(C)(C)NC(N)C[NH+]1CCCCC1',
#  'C1=[NH+]CN2CCC[C@H]3[NH+]=Nc4cccc3c4C12',
#  'CC(C)(C(=O)NCc1ncco1)c1ccccc1',
#  'O=C(NCCCCC1CCCCC1)c1ccccc1',
#  'CC[C@H]1CN(C(=O)Nc2ccccc2)CC[C@@H]1C(=O)NC',
#  'Cc1cc(Cl)cc(Cl)c1CNC(=O)NC(=O)CN(C)C',
#  'CC1C=CC1CCN1CCCCN1CN1CCCOCC1',
#  'C[NH2+]C1CCCCCCSCCC2CCC(C2)N1',
#  'CCOCC1OCCCC1c1cc2ccccc2cc1C',
#  'c1ccc(CNCCC[NH+]Cc2ccccc2C2CCC2)cc1',
#  'C1=CC=C2SC=NC(=C1)[C@H]2CNc1ccccc1',
#  'CCC1CCNCC[NH+]1Cc1ccccc1OC',
#  'CNC(=O)C(Nc1cc(Cl)n(C(=O)[O-])c1Cl)C(C)C',
#  'CSC(NC(=O)Nc1cccc(F)c1)C1CCC(N2CCCCC2)C1',
#  'C[C@H](Cc1ccccc1Cl)NCc1ccccc1',
#  'CCSc1ccccc1NC(=O)CNC1CCC(C)C[NH+]C1',
#  'Cc1ocnc1C(NC(C)Br)C(=O)[O-]',
#  'CC1CCCCCC1(O)c1nc(-c2ccc(F)cc2F)cs1',
#  'CC(C)CCC(=O)N1CCCN(C(=O)c2ccc(F)cc2)CC1',
#  'Cc1ccccc1NC(=O)N=[SH]Cc1cnccc1Br',
#  'CCOC(=O)N1CN(C(=O)COC)[NH+](Cc2ccccc2)CC[C@H]2CCC21',
#  'CC[NH+](C)C(=O)C(C)NCc1ccc([NH+](C)C)cc1',
#  'COc1ccccc1NC(=O)C1CCCCC(C(N)NCCC(=O)c2ccccc2)C1',
#  'Cc1ccc2c(NCc3ccccc3)ccc-2nn1',
#  'CC[C@@H]1CCC[NH+](Cc2ccccc2)C1',
#  'O=C(CN=Cc1ccco1)N(CC1CCC1)c1ccccc1',
#  'C=Nc1cc(C(N)=O)cc(Cl)c1[N+](=O)[O-]',
#  'CCC(C)NC(=O)N(C)C(=O)c1cccc(CC(C)(C)C)c1',
#  'Clc1ccc(C=CNc2ncc(Cl)nn2)cc1',
#  'CC1COC2(CCC(C)C2[NH3+])C1',
#  'Cc1ccccc1NC(=O)NCc1cccc(C(=O)N2CCCC2O)c1',
#  'CCN1C=C(C(=O)NC(=O)CC2CCC2)CCC1C',
#  'OCCOc1ccccc1C1=CC=c2cnccc2=CC=C1',
#  'CCN=Cc1ccccc1Cl',
#  '[O-]C1=CN=Nc2cc1c(OCCCOc1ccncc1)cn2',
#  'O=C1CCCCN1',
#  'CON(C)C1C=CC=C(F)C=C1C(=O)NCC1CC1',
#  'c1ccc(CCCNc2cc(C3CCS3)ncn2)cc1',
#  'CC[N+]([O-])(C(=O)Oc1cccc(-c2ccc(C)cc2)c1)N1CCCCC1',
#  'CC1CCC(CO)C1',
#  'CC1CCC1CCN1CCCOCC1',
#  'CC1CC([NH2+]C(=O)C(=O)n2[nH]c3ccccc32)C1',
#  'CC(C)CC(=O)[NH+]C1CCCC1[C@@H](F)C(=O)NC(C)(C)C',
#  'c1ccc(OCCCOCCN2CCC2C2CC3CCCCC32)nc1',
#  '[CH]1C=CC=C2C1=CC=CN1[C@@H](Oc3ccccc3-n3cccc3)[C@H](C3CCCCCC3)N21',
#  'COc1c(CNCc2ccccc2)nnc2ccnnc12',
#  'CN1CCC(CCCCO)N(C(=O)CC2CCC2)C1',
#  'O=C([O-])C(=O)Nc1ccc(C2CCCCC2)cc1',
#  'Cc1sncc1C(=O)NC1CN(c2ccccc2)CCCC(=O)N1',
#  'COc1cccc([NH+](NS(=O)(=O)C(SC)C(C)C)C(C)(C)C)c1',
#  'O=C(NCc1ccc2ccccc2c1)C1C[NH+]1Cc1ccccc1',
#  'c1ccc(C2CCC2OCCC2CCCN2Cc2nccs2)cc1',
#  'CC(NC(=O)c1cc(NC(=O)CCS)co1)C(=O)c1ccccc1',
#  'O=C(NC(Cc1ccccc1S)C[NH+]1CCCCC1)c1cccs1',
#  'O=C1NC2N(C3CCc4ccccc4CNc4ccccc43)CC1S2(=O)=O',
#  'c1ccc2c(CN3CCCC3CC3CC3)occ2c1',
#  'CC(NC(=O)C1CCCS(=O)CC1)C(C)(C)C',
#  'O=C1Oc2ccc(cc2)N1NCCc1ccccc1',
#  'C=C1CCCC(NC(=O)C2CCC(=O)C(C)N2)O1',
#  'CC(=O)Nc1ccccc1OCc1ccccc1Cl',
#  'CNC(=O)N1CC[CH][C@H](CNC(=O)C[C@@H]2CCCC[C@H]2C)C1',
#  '[NH3+]N=C1CNC1C(=O)Nc1ccc(Cl)cc1',
#  'CC1C(O)CCCCCN1S(=O)(=O)CC1(CC(N)=O)CC1',
#  'CC(NC(=O)N1CCC[C@@H](C[NH2+]CCc2cccs2)C1)C1CC1',
#  'CC(NC(=O)C1CC(=O)OC1=O)c1ccccc1',
#  'c1ccc(OCCN2CCN(c3ccccc3)c3ccccc32)cc1',
#  'Fc1ccncc1OCCCCOc1cccs1',
#  'O=C(Cc1ncon1)Nc1cccc(Cc2cnccc2O)c1',
#  'Cc1ccccc1CCNC(=O)N1C[C@H]2CCCC[C@@H]2O1',
#  'COC(C(=O)N(C)CC1CON(C2(OC)CCN(C(=O)C(C)C)CC2)C1)c1cccc(C)c1',
#  'CCN(CN[C@H](C)[NH+]CCc1ccccc1)Cc1ccccn1',
#  'O=C(COCc1ccoc1)NC1CCCCSC1',
#  'CCCCC(C)NC(=O)N1CCCC(C)C1',
#  'C[C@H]1CC([NH+](C)Cc2ccccc2CCCO)C(=O)S1',
#  'O=C(NC1Cc2ccccc2CN1c1c(Cl)cccc1Cl)c1ccccc1',
#  'CCC(C)OC(=O)NC(=O)NC(=O)c1cccc2ccccc12',
#  'COc1ccc(CNC(=O)c2ccccc2C)cc1',
#  'C=C(C[NH+]1CCCCC1C)C1CCCN(C)C1',
#  'O=C(Nc1cn(Cl)cc1Br)C1CC1',
#  'c1ccc(CNC2CCSC2)cc1',
#  'CC(C)NC(=O)NC(=O)C(C(C)C)C([O-])c1cccc(F)c1',
#  'Cc1ccccc1C(=O)Nc1cccc(Br)c1',
#  'CC1(C)NC(=O)CNC(=O)N2CCN(C(=O)NC(=O)Nc3ccccc3)C=C21',
#  'COCCc1cc2cc[nH]c2nc1CCNCC1CCOC1',
#  'c1ccc2c(c1)CN1CCN(CCCCC2=C2CSC2)C1',
#  'C=CCCc1cccc(NC(=O)OCC)c1',
#  'CCc1ccccc1CNC(=O)[C@@H]1CCOc2ccccc21',
#  'c1cnc(N2CCNCCCS2)c(C2CCC2)c1',
#  'Cc1ccc(N=O)cc1S(=O)(F)(c1ccncc1)N(C)C',
#  'O=C(CF)Nc1ccccc1CCCC[NH2+]C1CCCC1',
#  'CN(C)C(=O)NCc1oc2ccccc2c1C(=O)NC(C)(C)C',
#  'CCc1ccc(CC[NH2+]C(C)C2CCCO2)s1',
#  'CCC(C=C(N)C(=O)N1CCCCC1)[NH+](C)C',
#  'CCC(C)(C)Br',
#  'COc1cc(NC(=O)C2Oc3nc(C4=C(SC)C=N4)c2cc3Cl)ccc1C',
#  'O=C(c1ccccc1)C1CSCC1Oc1ncccn1',
#  'COCC(C1CC(C)C(NC(=O)CC2CCCCC2)N1)N1CCCCS1',
#  'CCC(=O)[NH+](C)CCC1CN(C(=O)Nc2cc(C(C)C(C)C)c[nH]2)C1',
#  'CCC(C#N)NC(=O)C1CCC(CC2CCCCO2)C1',
#  'O=C1CC2CCCC(C2)CC1NCCCC1CCC1',
#  'Cc1cc2ccccc2cc1CCCCC[NH+]1CCCN1c1ccccc1F',
#  'CC(C)C(=O)N(C)C(C)c1ccccc1N1CCOCC1',
#  'c1ccc2c(c1)CCOC2',
#  'CC(=O)C(C)(Cc1ccccc1)NCC(=O)N1CC[NH+](C)CC1',
#  'CC1=C2C=CC(CCCC[NH+]3CCCCCC3)=C2N1',
#  'Cc1ccccc1COC1CCCCCC(C(=O)N(C)C)C1Cc1ccccc1',
#  'N[NH+]1C2=NN=C1C(=O)CNCN(Cc1ccccc1)CC2',
#  'CC(=O)N(C)[C@@H](C(=O)NC([N-])(CO)C(=O)C(C)(C)C)c1ccccc1',
#  'Cc1cccc(Cl)c1CCC1C(C)CC2C[NH+]CN1C2',
#  'CCN1CN(C2=CCCCC2)CCCO1',
#  'COc1ccc([C@H]2C[CH]CN2c2cccs2)cc1Sc1ccncc1',
#  'CCSc1cccn1SC[NH2+]CCc1ccccc1OCCO',
#  'CC(=O)N1CCC[C@H](C(=O)N(C)c2cccc(Cl)c2)CC1',
#  'CC(C)CN(CCC1CN(C)C1=O)Cc1cccc(Cl)c1',
#  'CCC1CCN(CCC(CC2CC2)NCCNC2CCCCC2)C1',
#  'CC1CCCC(C[NH2+]C2CCCc3ccncc3O2)C1',
#  'CC(=O)C1C[NH+]2CC[C@@H]2NC1=CC(=O)N(C)CCc1ccccc1F',
#  'CC[CH]NCc1ccc2ccccc2n1',
#  'c1cnnc(C2CCCN(CC3CCC3)C2)c1',
#  'c1ccc(OCC2CCCC2)cc1',
#  'N=C1CCC[NH+](NCCCOc2ccccc2Br)C1',
#  'CCC1CCC1CCC1CN(c2ccccc2)CCN1',
#  'CCNC(=O)c1cccc(NC(=O)Cc2ccc(F)cc2)c1',
#  'Cc1ncnnc1Cc1cccc(C2CCCCN2)c1',
#  'CC1CCCCC(NC(=O)NCCc2ccccc2)C1',
#  'CC(O)(C[NH2+]CC(C)(C)C(C)(C)C)C(N)=O',
#  'CC1=[NH+]C1CC[NH+]1CCOC[C@@H]1c1ccccc1-c1ccccc1',
#  'CCC(=O)C(NC1CC1)=C(NC(=O)C(=O)N1CCN(CC)C1)c1ccccc1',
#  'COCCCOC1CC1C(CO)CCC[S+]',
#  'OCc1cccnc1NC1CCCN(Cc2cncs2)C1',
#  'O=C(COc1ccccc1)c1ccccc1-n1cnnn1',
#  'COC(=O)C(NC(=O)CN(C)Cn1c(C(F)(F)F)cccc1=O)C(=O)NC(C)C',
#  'CNC(=O)c1sccc1CNc1cccs1',
#  'C1=C2Cc3ccccc3C[C]2CCC1',
#  'C[C@H]1N=[NH+]C=C1Cc1ncco1',
#  'Cc1ccc(C(CS(=O)(=O)N2CCCCC2)NC(=O)C(C)C)cc1',
#  'CC(C)CNC(=O)[C@@H]1C=CC=NC=C1C(F)(F)F',
#  'Fc1ccccc1OCCN1CCCCCCN1Cc1ccccc1',
#  'O=C(c1ccccc1)N1CCCCCc2cn[nH]c21',
#  'CC(NC(=O)C(=O)C1NN(Cc2ccccc2)C(=O)c2ccc1cc2)C1CCCCC1',
#  'Cc1ccccc1CC=C1NCCCN1Cc1ccccc1CO',
#  'Clc1ccccc1C1CCCCC(N2CCc3ccccc3C2)C1',
#  'Cn1c(C(=O)NC2Cc3ccccc3C2)ccc2cccc1-2',
#  'CC(C)S(=O)(=O)N1CCC[C@H](C)OC(=S)N(C)CC1',
#  'NC(=O)C(c1nnc2ccccc2n1)N1CCOCC1',
#  'O=C(NCCC[NH+]1CCCCCC1)c1cncc2ccccc12',
#  'Cc1ccccc1NC(CC1CC1)NC(=O)c1ccccc1',
#  'Cc1ccc(N2CCCC2=O)c(NS(=O)(=O)c2ccccc2C)n1',
#  'CC1CCCCN(C)S(=O)(=O)C(C2c3ccc(Br)cc32)O1',
#  'O=S(=O)(c1ccccc1)N1CCN(CCC=S)C[SH]=C1NC1CC1',
#  'c1ccc2nc(CN3CCCCCC3)c(CC3CCCCC3)nc2c1',
#  'CC(=O)N(C)c1ccccc1-n1nc2ccccc2c1Nc1ccccc1',
#  'CC(NCC(=O)C1CCN(C(=O)C2CCCC2=O)C1)N(C)C(N)=O',
#  'CC1(CC(=O)NC(=O)C2CCCCCC2)CCc2ccccc2OCNC1',
#  'COCOc1ccccc1CC1=CC2=NC=CC=CN2C=C1',
#  'c1ccc(N2CCOCC2)nc1',
#  'Cc1ccc(N2CCCN(C(=O)Nc3ccccc3F)CC2)cc1',
#  'CC(C)C(C)Oc1ccc(N(C)NCc2ccccc2)cc1',
#  'C1CCC(CCNC2CCCO2)CC1',
#  'COCCC(=O)Nc1ccccc1[C@@H]1SCCCN1CCO',
#  'c1ncc2ccc3ncsc3c2n1',
#  'CN(CCc1ccccc1)CC(=O)NC1CCN(c2ccccc2)C(=O)C1',
#  'CN(NC(=O)C1CCC(C)(C)C1)C(=O)c1ccccc1F',
#  'CCCCNC(=O)C(C)NC(=O)N1CCC([NH+](C)C)CC1',
#  'CCC(C(=O)NC(C)(C)C(N)=O)C(C)(C)O',
#  '[O-]CC1CCCc2ccccc21',
#  'c1cc(CCC2CNN2CCC2CCCC2)ccn1',
#  'CCCC(C)(C)N1CCC1(C)Cc1cc2[nH]ccc2nc1C(=O)N1CCCC1',
#  'CCN1C(=O)[SH](CN(C(N)=O)C(C)(C)C)CCC1C(=O)NCc1ccccc1',
#  'C[NH+]CCCC1CCC[C@@H]1Cc1ccccc1OCn1cccn1',
#  'COCc1cccc(NC(=O)NCc2ccccn2)c1',
#  'COc1ccc(OCCNC(=O)NC2CCCC2)c(C)c1',
#  'CC(SC1CCCC(=S)CC1)C(=O)[O-]',
#  'CC(C)CNC(=O)C(=O)NC(c1ccccc1)C1NCCC1=O',
#  'CC(c1cc(-c2ccccc2)[nH]n1)N1CCCCC1',
#  'O=C(NCc1ccccc1Cc1ccccc1)C1=NC(=O)N(c2ccco2)CC1',
#  'O=[N+]([O-])c1ccccc1C1CC[NH+]2CCN1CC2',
#  'CCC(C)(Cc1ccco1)NC(=O)NC(=O)Cc1ccccc1',
#  'O=C1CCC2(CCc3ccccc32)CS1',
#  'COC1C[SH]2[NH+]=CC(=O)C12[SH]1CCCCC1',
#  'CC(=O)N(c1c(-c2ccccc2)[nH]n1CC(C#N)c1ccccc1)C1CCCC1',
#  'CS(=O)(=O)c1ccnnc1S(=O)NCc1ccc(Cl)cc1',
#  'O=S(Cc1ccccc1CCOCc1ncncn1)c1ccccc1',
#  '[NH3+]C1CCCCC1CC[NH+]1CC2CCCC21',
#  'O=[SH](CCc1ccccc1)(NCc1ccccc1)c1ccccc1',
#  'COCCN1CCn2cccc2-c2ccccc2N[C@H](C)CC1=O',
#  'CN(COc1ccc(C(=O)NCc2ccccc2)cc1)C1CCOC1',
#  'CC1CCCCCN1Cc1cccnc1O',
#  'CC[NH2+]CCC1C[NH+](Cc2cccnc2)CNCO1',
#  'O=C(NCC(O)c1ccccc1)C1CCCC1',
#  'CC(C)CC1NC(=O)C(Nc2ccccc2)C(C)(C)N(C(=O)CC#N)CC(=O)C1C',
#  'N#Cc1ccccc1[NH+]1CCCCC1',
#  'O=C1NCCCOc2cc(Cl)ccc21',
#  'CNC(NC(=O)OC(C)C)C(=O)NC1CCC1O',
#  'CON1CCC(Cc2ccn[nH]2)CC1',
#  'CNC[NH+]1CCCC(OCN2CCC(C)NC2=O)C1',
#  'c1ccc(OCC[NH+]2CCCC2)c(CC2CCOCO2)c1',
#  'CCC(C)C(=O)NCc1ccc(OC(C)C)cc1',
#  'CC1C=C(F)C=Cc2[nH]c(=O)c(=O)ccc2CNC2=NCCCCC2OC1=O',
#  'CC(CCSc1ccccc1)N=Cc1ccccn1',
#  'O=CCOc1ccccc1OCCC1CCCC1',
#  'CC(C)N(C)C(=O)c1cccc(-c2ccc([N+](=O)[O-])cc2)c1',
#  'CCc1ccc(C2CC[NH+](c3ccc(OC)cc3)C2)cc1',
#  'CC[NH2+][C@H](c1ccccc1)[C@H]1COCCO1',
#  'CCOCC[NH+]1CCCC[C@H]1C[C@@H]1NCCOCCc2ccccc2O1',
#  'CC(=NNN(C(=O)c1cc(F)cc(Cl)c1)[N+](=O)[O-])C(C)C',
#  'CN1CN[C@H](CCO)C[C@H]1Cc1ccccc1[N-]',
#  'CC1CCCCN1C(=O)C(=O)N1CCCC(C(=O)N(C)CC2CC2)C1',
#  'C1COCC(C[NH2+]C2CCC2)C1',
#  'CCCC(C)N(C)CC1CCCC1',
#  'CC1CCCCC(C)(O)N1C(C)(C)C(=O)NC(C)(C)C',
#  'Cc1cc(O)ccc1C(Br)CC[NH+]C1CCC1',
#  'CCN(C)S(=O)(=O)C(C)NCn1cccc1',
#  'Cc1oc(CCCc2ccnc(Br)c2)cc1F',
#  'CC(NS(=O)(=O)c1ccc(C(C)(C)C)cc1)N1CCCCCC1',
#  'CSc1ccc(C)cc1C=O',
#  'CCCC=CC[C@H]1CCC1CCCCCO',
#  'Cc1c(Cl)cccc1NC(O)CCc1ccccc1',
#  'Cc1cnccc1C[NH2+]CC(=O)c1cccc2ccccc12',
#  'Cc1cc(-c2ccccc2)ccc1C1=CC(=O)CN(c2cn(S(C)(=O)=O)nn2)C=C1',
#  'CC(N)NC(=Cc1ccccc1)c1ccccc1',
#  'C=CCN1CC(=O)N(Cc2ccccc2CC)C(=O)[NH+](CC)CCCNC1=O',
#  'C[NH+]C(C)CSc1ccccc1OC(=O)C(C)(C)OC',
#  'CN1CCCC(Oc2ccccc2)C1',
#  'O=C(NCC1CCCCCOc2ccccc21)c1ccc2ccccc2c1',
#  'Cc1ccccc1OC[NH+]1CCCCO1',
#  'CC1CCC([NH+]2CCCCc3ncccc3C2)C1',
#  'CCSc1ccc(Cc2cnc3ccccc3n2)cc1',
#  'COc1ccc(C(NC(=O)NCc2ccccc2F)C(F)(F)F)cc1',
#  'c1ccc(CNCc2c[nH+]cnc2N2CCCCC2)nc1',
#  'CC(C)Nc1ccccc1SCOCc1ccccc1',
#  'CCC([NH2+]CCc1ccccc1Cl)c1ccccc1',
#  'CCC(CN(Cc1cccc(OC)c1)CC1CC1)[NH2+]C',
#  'Fc1ccc(-c2cccnc2[CH][NH2+]C[NH+]2CCCCC2)cc1',
#  '[O-]CCCOCCC1COC2CC[C@H]3[CH]CC3=[NH+]CCC12',
#  'c1nc(-c2cscn2)cs1',
#  'O=C(NCCCNC(=O)c1ccc(-c2ccccc2)cc1)NC1CC1',
#  'CC(C(=O)Nc1cccs1)C(=O)NC(CC(=O)[O-])[NH+]1CCC1',
#  'CC1CCC[NH+](C)C(COc2ccc(F)cc2)C1',
#  'CCc1ccccc1OC(C)([NH2+]C(C1CCCCC1)C(C)(C)F)C1CCCC1',
#  'CC(=O)OCC(c1ccccc1O)[NH+](CC1CCC1)C(=O)[O-]',
#  'CC(C)OC1CCCCNC[NH+]1CCC1CCCCCCO1',
#  'CC(C)(C)N1CCCCN(c2ccccc2)CCC1',
#  'CCC1CC(=NC#N)[NH+]1CCc1ccncc1',
#  'c1coc(-c2ccn(C3CCOC[NH2+]C3)n2)c1',
#  'Cc1ccccc1CNC(=O)C1CCCNCC1=O',
#  'O=C1CN(C(=O)CNC(=O)C(=O)N2CCCC2)CC(c2ccccc2Cl)=N1',
#  '[NH3+]C1COCCCC[NH+]1CC1CCC1COc1ccccc1',
#  'COC1(C)CN(CCC(=O)c2cnc(NC(C)C)c(C)c2)C(=O)NNC(=O)C1C',
#  'OCCC1OCCCC1C1CCC(O)C1',
#  'Cc1nnnn1CCC1CCC(=O)c2ccccc21',
#  'COc1ccc(Br)c(OCC(=O)N2CCOCC2)c1C',
#  'Cc1sccc1C1CCC(CC[C@@H]2CCOC2O)[NH+]1C',
#  'CC1CC(C(=O)NC(C(=O)C(=O)N2CCOCC2)c2ccccc2)C(=O)CN1',
#  'O=C(CC1CCCC1)Nc1cccc(N2CCCC2)c1',
#  'CCC(CN1CC[NH+]1CCc1ccccn1)C1CCCC(=O)C1',
#  'COC1CCC(CNC(C)=O)C[NH+](C)C1',
#  'CCOC[NH+]1CCC[C@@H]1Cc1ccc(OC)cc1OC[C@@H]1CCCOC1=O',
#  'CC1CCC[C@H]1C[C@@H](C)OCCNCCc1ccccc1O',
#  'Cc1cc(F)ccc1NC(=O)SCC(=O)NC1CCCC1',
#  'O=C(NCNCc1ccccc1)c1ccccc1',
#  'c1ccn2cc(CNCC3CCCCCC3)nc2c1',
#  'OCC(COCc1scc2c(Cl)cccc12)CN1CCCC1',
#  'O=C(CSc1ccccc1)NNC(=O)c1ccc(CN2CCCCC2)cc1F',
#  'COC1(C(=O)N(C)CC(=O)CC(C)(C)C)CCC1([NH3+])C(C)(C)C',
#  'CCSCCC1CCC1OCCC[NH+]1CCCCC1',
#  'CCC(NC(=O)NS(=O)CCCOc1ccco1)c1cccs1',
#  'Cc1ccccc1C=CN1CC1C(=O)NCC(C)C(C)[NH+](C)C',
#  'CCOCC1CCC1OC1CCCCN1Cc1ccc(OC)cc1',
#  'N#Cc1ccccc1C1CNC(CCCO)C1',
#  'Cc1ccc(SCC(=O)N2CCCCC2)cc1',
#  'CC1(C)CCOC(=O)C(CCS(C)(=O)=O)N1',
#  'CC(C(=O)NC(NC(=O)C1CCCC1)C(=O)N1CCCC1)S(=O)c1nccs1',
#  'CCCCc1cc(F)cc(OC(=O)C2CCN(c3ccco3)C2)c1',
#  'CCCNC(=O)NC(=O)CC(c1ccccc1)N1CCC1',
#  'C=CCCc1ccccc1-c1n[nH]c2ccccc12',
#  'Fc1cc2c3cccc(c3n1)CCNC2',
#  'CSC(CNC(=O)C(=O)N1CCC1)c1ccc(-c2noc(C(N)=O)n2)c(C)n1',
#  'CCC(Cc1scc2c(C)cccc12)C1=C(NC(C)OCOC)C1',
#  'COC(=O)C1(CN2CCNC2)CC(C)C(C)(C)C1',
#  'O=C(F)CCN1Cc2sccc2Oc2ccccc21',
#  'CC(CNC(=O)OCC1=CCN1c1ccccc1)C1CCCCC1',
#  'O=C(C1CCCS1)N1CCCC(CCN2CCOCC2)C1',
#  'CCC[NH2+]C(CC1CCCC1)NCCn1cnnc1C',
#  'CCC(C)C(=O)N(CC(F)(F)F)C(=O)NCC1=C2C=CC=CC=C2NC=C1',
#  'CC1CCCC[NH+](Cc2cc3ccccc3s2)c2ccccc2N1',
#  'C1=CC=C2CCC[NH+](C2)N(CC2CCCCC2Cn2ncnn2)C=C1',
#  'O=C1Nc2ncncc2[SH]1CCOc1ccccc1OCCO',
#  'CCOCN1CCC([NH2+]CCC2CCCCCC2)C1',
#  'CC[NH+](Sc1ccccc1COc1ccccc1)c1ccccc1C1CCC1',
#  'C1=Cc2cnc(nc2OCCOc2ccccc2CN2CCOCC2)C=N1',
#  'COc1ccc(N(C)C(=O)c2ccc(CNC(C)C)cc2)cc1',
#  'CCCN(C1=CC=CCC1=O)C1CC[NH+](C(C)(C)C(=O)Nc2ccc[nH+]c2)C1',
#  'CC[C@H](Nc1ccc(C(=O)NOC)cc1)c1ccccc1F',
#  'FCCc1nccc2c1NCCC2',
#  'C#CC[C@@H](C)CNc1ccccc1C(N)=O',
#  'COC(NC(=O)CC(C)(C)C)C1CCO1',
#  'C=C[C@@H](Nc1snnc1-c1nccn[nH+]1)C1CC1',
#  'OCc1cccnc1-c1ccc2nccn2c1',
#  'CC(=O)OC(C)(C)C(=O)N(CC(C)(C)C)C(=O)[O-]',
#  'c1ccc(OCCCn2cc(CCN3CCCC3)cn2)cc1',
#  'Nc1ccc(NC(=S)c2ccccc2)cc1',
#  'CCCc1ccccc1C1CN(C)CN1C(=O)N1CCN(c2ccnc(-c3ccccn3)n2)C1',
#  'CC(=S)CN[SH]1(=O)CC2CCC(CCCN1C(=O)[O-])C2',
#  'O=S(=O)(c1ccc(NN2CCc3ccccc32)cc1)C1CCCC1',
#  'CCN(C)CCNC(=O)C1=Cc2c(NC3CCCO3)n[nH]c21',
#  'CCC(C)(C)C(CNc1ccccn1)Nc1ccccc1C#N',
#  'CCCSC(Nc1ccccc1)C(=O)C[NH2+]CC1CCCC1',
#  'CSc1ccc(C2CCCC2)nn1',
#  'COC1=CC2=C(C)NNC(=O)CCC(C2)SC[N-]C=C1',
#  'CC1(NC2CCC2)CC(N)CC(CO)C1=O',
#  'CC1CCN(C(O)CC(=O)N2CCC2)C1',
#  'CCOCOc1ccccc1C[C@H]1NCCC[NH+]1C',
#  'CCc1cc(C)ccc1Sc1ccoc2nncc1-2',
#  'CC(c1ccccc1)N(c1n[nH]c2ccccc12)C(C)(C)O',
#  'c1ccc(C2CCC3CCCCC32)cc1',
#  'O=C(C(CC1CCOC1)NC1CCCC1)C1COC(=O)N1CCc1ccccc1',
#  'O=C(NCCc1ccccc1)C1CCCCC1',
#  'CCC(C)(C)[NH2+]CCC(=O)Nc1ccccc1C',
#  'COCCNCCc1ccc(F)c(F)c1',
#  'COc1ccc(-c2cc([NH2+]CCC3CC3)nc(C)n2)cc1',
#  'CC[NH+](C)CC(C(=O)N(C)CC1CCC1)C(C)N1CCCC1',
#  'CC(O)CC1CN(CC(C)c2ccccc2)C(=O)N1',
#  'CC(C)NC(=O)C(=O)CCn1c2cccccc-2c1NC(C)C',
#  'CC(C)NC(=O)C1C[NH+](CN2CCCC2)NCC(C)(C)C1',
#  'CC(=O)N1CCC[C@H](Cc2ccncn2)CC1',
#  'COC(=O)C(CC1CCCC1)NC1CCCC[NH2+]C1',
#  'CC1CCNC(=O)CC1NC1CCSC1',
#  'CSc1ccccc1CCC1CCCC2CCC1O2',
#  'c1ccc(C2CCc3ccccc3SN2)cc1',
#  'CCC1CN(C(=O)N(C)CC(C)[NH2+]C)CCC1[NH+](C)C',
#  'C1CCC2C(C1)CCC2CN1CCOCC1',
#  'COc1ccc(OCN2CCCC2)c(C)c1',
#  'CC1CCC(C(=O)C2CCCCC2)C(=O)[C@H](CO)NC1',
#  'O=C([O-])C1CCC1C(=O)Nc1ccsc1-c1ccccc1',
#  'CC1CC1NCc1ccccc1NCCc1cc2nccn2cn1',
#  'Cc1ccc2c(n1)-c1ccccc1CCC2',
#  'O=C([O-])[NH+](C1CCCC1)C1CCCCCN1CC1CCC(O)C1',
#  'CCCN(C)CC(=O)NCCOc1ccccc1-c1ccccc1',
#  'CCCN1C=C(C(=O)NCc2ccccc2Cl)N(C(=O)CC)CC1',
#  'O=C([O-])c1ccccc1OCCCNCc1cccnc1Cl',
#  'CS[C@H](CC[NH2+]C(=O)[O-])c1ccccc1',
#  'O=C([O-])NOCCOc1ccccc1[N+](=O)[O-]',
#  'CC#Cc1ccccc1S(=O)COc1ccccc1Oc1ccccc1-c1ccccc1',
#  'O=Cc1ncccc1NCC1CCC=CCC1',
#  'CC(CN1CCN(c2ccccc2)CC1)C[NH+](C)CC1CCC1',
#  'c1ccc(OCCN2CCCC2SC2CCCCC[NH2+]2)cc1',
#  'COc1cccc(NCCC(=O)NCC(C)(C)C(C)C)c1',
#  'CN1CC[NH+]2CCCC[C@@H]2C[C@H]1Cc1ccccc1Cl',
#  'CC[NH+][C@@H]1CCS(=O)C[C@@H]1c1ccccc1',
#  'O=C(F)[C@H](Cc1cnno1)C1CCC1',
#  'CCC(=O)Nc1ccccc1NC(=O)NCc1occ2ccccc12',
#  'O=C(Nc1ccccn1)c1ccccc1-c1ccccc1CNC1CCOCC1',
#  'CCOC[C@H]1CC[NH+](C)[C@H]1Cc1cccnc1Oc1ccccc1O',
#  'CCC(C)(C)N(NC)C(=O)c1cc(C(=O)N(C)C)c(Br)s1',
#  'c1cc(SCC2CCN(c3cncnn3)CC2)ccn1',
#  'CCC[C@H](C)NC(=O)N[C@@H]1COc2ccccc21',
#  'OCCCCCC1=C2C=NC2C=CC=C1',
#  'c1c[nH]c(CCCN2CCCCSCC2)c1',
#  'O=[N+]([O-])c1cccc(-c2ccc[nH]2)c1',
#  'CC1CCCCC(CNC(OC2CCC2)c2c[nH]nn2)C1',
#  'c1ccc(CC2[NH2+]NCCC2CCNCCC2CCCCC2)cc1',
#  'N#CC[NH2+]CC[C@@H]1CCS(=O)(=O)C1',
#  'COc1ccc(C(=O)C(=O)N2CC(Nc3cc(C)cc(C)c3)C(C)NC2C)cc1',
#  'CCCCCC1=NC2=C(c3ccccc3)C=NN1C=CC=C2',
#  'CCC1(C)CCNCC1CCNC1CCC1',
#  'CC(C)Cc1ccccc1OC=Cc1ccccc1',
#  'CC1CCN(C(=O)NC(=O)Nc2ccccc2)C(=O)C1C(=O)NCC(=O)N1CC(C(C)(C)C)C1',
#  'CCC(=O)OC(C(=O)NC(=O)C1CCC(O)N1)C(=O)OC(C)(C)c1ccc(C(C)C(=O)[O-])cc1',
#  'N=C1CCN(CC2CCCCC2)CC1',
#  'CCCC(C)N1CC[NH+](C(=O)N2CCCCC2)CC1',
#  'O=C(CNCCC1CCCCC1)NC1CCCCC1',
#  'CC(CCC1CCC1(C)C)C(=O)[O-]',
#  'CNC(=O)C(C#N)C(C)(C)CCNC(=O)Cc1ccccc1',
#  'CCNC1CCC([NH2+]CCN(C)c2ccc(OC)cc2OC)C1',
#  'CC1CCC(CNC(C)S(=O)(=O)N=C2Cc3ccccc32)CO1',
#  'Cc1cccc(C[C@H](C)CNCc2ccccc2)c1',
#  'CCN1CCCCC(C[NH2+]C(C)C)CC1',
#  'c1ccc(SC2CNNCC2OCc2ccccn2)cc1',
#  'O=C(CCc1ccccc1)NC1CSC(=CNc2ccccc2)C1',
#  'Cc1cnc(CCC[NH2+]Cc2ccccc2Cl)nc1',
#  'C[NH+]1CCC1c1ccccc1CO[C@@H]1CC[C@@H]2CCC[NH+]2C1',
#  'Cc1nc(C(=O)C(C)C(=O)NC(C)C)sc1C1CCC1(C)O',
#  'CCNC(=O)C[C@H]1CCC[NH2+][C@H]1c1ccccc1',
#  'Fc1ccccc1NCCC(C1CCOCC1)[NH+]1CCCCC1',
#  'O=C(NCCn1nc2ccncn21)c1cccc(Br)c1',
#  'C1CCC(NCCC2CCCOC2)CC1',
#  'CC(NC(=O)NC1CCCO1)C(C)c1ccc(Cl)c[nH+]1',
#  'Cc1ccc(CNC(=O)C(=O)CCc2ccccn2)cc1',
#  'Cc1ccccc1C(=O)NSCc1ccc(F)cc1',
#  'CON1CCCCc2nccnc2SCCC1',
#  'Cc1ccccc1NC(=O)NC(=O)c1ccccc1Cl',
#  'COc1ccc(C(=O)NC(=O)C2CCCC2)c(C)c1',
#  'O=C(O)CC(=O)N1CCC2CCN(CC2)CC1',
#  'CN(C)C(=O)Nc1cc(-c2ccccc2)sc1C(=O)Nc1ccc(F)cc1',
#  'O=C1CCCC(NC(=O)C2CCCCC2)CN1',
#  'CCOCC(=O)N1CCCC(OCCC#N)C1',
#  'O=c1cc(Br)ccn1-c1cccc(CN2C[C@@H]3CCC[C]32)c1',
#  'O=C(NCc1ccccc1)C1CN(CCCNc2ncccn2)C[NH+]1',
#  'C(=Cc1ccccc1COc1ccccc1OCC1CCCC1)C1=Nc2ccccc21',
#  'c1ccc(NC2Cc3ccccc3CCS2)nc1',
#  'CCN(CCOC)CCc1ccccc1OCc1cccnn1',
#  'CC(=O)Cc1ccccc1NC(=O)NC(C)C1CCOCC1',
#  'O=C1CNCCN2CCC[NH+]2CC1CCc1ncco1',
#  'C1=Cc2ccccc2Nc2ncccc2CC(n2ccnc2)=C1',
#  'Cc1ccc(C(=O)N2CCNC(=O)CC2=O)c(N)c1',
#  'Brn1cnnc1CCNCC1CCCC[NH2+]CC1',
#  'c1ccc(CSc2ccccc2)cc1',
#  'CCC(C)(C)S(=O)(=O)NC(=O)NCc1ccccc1O[C@H](F)c1ccccc1',
#  'CSCCCC(NCc1cc[nH]n1)C(C)C',
#  'Cc1cc(NC2CCN2CCC[NH+](C[NH3+])CC(C)C)c(F)cc1F',
#  'CO[C@@H](C(=O)NCC(=O)N(C)c1cc([N+](=O)[O-])ccc1Cl)c1ccccc1',
#  'CCC(N)(C[NH+](C)C(C)Cc1ccco1)c1cccc(Cl)c1',
#  'C[NH+]1CCCC(C(=O)CCC2NC(N3CCC3)C(=O)O2)C1',
#  'CC(=O)C1CCN(C(C)COC2CCCC2)CC1',
#  'O=C1CCCN1C(NCC[NH+]1CCCCC1)C1CCCO1',
#  'CC1CC(C)C(C)Cc2nccnc2N1',
#  'c1ccc(C2CC[NH+]3CCCC3CCOc3ccccc32)cc1',
#  'c1ccc(-c2cc(CCCCCNC3CCCO3)sn2)nc1',
#  'c1ccc(N2CCCCC(CC3CCCCCC3)NCCC2)nc1',
#  'CCC(N1CCC(=O)CC1)C(C)(C)[C@@H]([NH3+])C(C)N(C)c1ccccc1',
#  'CC(CC(=O)NCCc1ccc(Cl)nc1)NC(=O)COC(=O)c1ccccc1',
#  'CCC(NC(C)=O)c1ccc(C(=O)N2CCCC2)cc1',
#  'CC(=O)Nc1ccccc1NCc1cccc(Br)c1',
#  'N=C1NCCCC1CCc1ccccc1OCCN1CCCCC1',
#  'CCN(C)C(=O)C(=O)NC1CCC[C@H]2CCN3C(=O)[C@](O)(CC2)CC[NH+]3C1',
#  'Clc1cccnc1N[C@H]1CC[C@@H]2CC2C1',
#  'CC1=NOC(=O)C(N2CCCC2C(=O)NC2CCCC2)CC1',
#  'CC(CC(C)(C)C)=NO[C@H]1COCC(=O)N(C)C1',
#  'CCC(=O)NC1(NC(C)NC(=O)c2ccc(C)cc2)CCC(OC)C1',
#  'Cc1ccccc1C(=O)N(C)CCC1CCCSCC1',
#  'c1ccc(OCc2cccc3ncccc23)c(OCOn2cccn2)c1',
#  'CC1c2ccc[nH+]c2CCC1[NH2+]C1CCCCC1',
#  'O=C([O-])c1ccccc1CNC(=O)C1CCCC1',
#  'CCCc1ccc(NC(=O)C2(N)C(=O)[SH](=O)([O-])NC[C@H]2C)cc1',
#  'C1=CC=C2C=CC=CC2(CC=Cc2occc2OC[C]2Cc3ccccc3OCO2)C=C1',
#  'O=S(=O)(NC(c1ccccc1)C1CCCOC1)c1cccc(F)c1',
#  'CCC[NH2+]CS[C@H]1C[C@@H]2CCCCC[C@H]2[C@@H]1C',
#  'CCCc1nonc1C',
#  'COn1ccc(C(=O)C(=O)CNC2CCN(c3cscn3)C2)n1',
#  'O=C(NCC1CCCCN(C(=O)CSCc2ccccc2)C1)c1ccccc1',
#  'O=C1CCCC1NC(=O)C1CCCCO1',
#  'C#CN(C)C(=O)[NH+]1CCC(C)CCC1CC(Cc1cncs1)NC(=O)C1CCN1',
#  'CC1OCC(NC(=O)NC(=O)C2CCCC2)C1C1CCCC1',
#  'c1ccc(C2CCC[NH+](CCCCN3CCCCOCC3)CC2)cc1',
#  'O=C(NCC(=O)N1CCCC(c2ccccc2)CC1)C1CCc2ccccc21',
#  'CNC(=O)CNC(C)C(C[NH+]1CCCC1)NC1CCCC1',
#  'CC(CC(C)NC(=O)OC(C)(C)C)NC(N)=O',
#  'CCC[SH](=O)=O',
#  'C1=C(N2CCCC2)CCCOc2ccccc2N1',
#  'CC(F)(F)CNC(=O)NCC(=O)NC1CCCC1',
#  'COc1ccccc1CNC1CC[NH+](C2CCC2C)CC1',
#  'CCN(CC)CS(=O)(=O)C1CCCOC1',
#  'CC(C)c1ccccc1OCCOc1ccccc1N',
#  'CC(=O)c1ccccc1[IH]NCc1ccccc1Oc1ccncn1',
#  'CCC1CCCC1NC(=O)c1c[nH]c(-c2ccccc2)n1',
#  'O=C(C=Cc1ccccc1)NCc1ccccc1F',
#  'CC1CCN(C(=O)NC(=O)C2CCC2C(=O)N(C)C)C1',
#  'Cc1cccc(OC(=O)COCc2cc[nH]c2C)c1',
#  'C(=Cc1ccccc1N1CCN2CCC[C@@H]2C1)c1ccco1',
#  'Cc1ccccc1C[NH+]1CCCOCC1Oc1ccccc1-c1ccccc1',
#  'Cc1ccc(C(C)NC(=O)OC2CCOC3=CC=C4CCCC4N3CCN(C)C2)cc1',
#  'CC(CN1CCCCCC1)[NH2+]Cc1ccccc1',
#  'Clc1ccccc1[NH+]1CCN1CCCCC1CCCOC1',
#  'Cc1c(N)nc(NC(=O)CSCC(=O)NC(C)F)c(Br)c1C',
#  'CCCC[NH+]1CCC1N[SH](=O)(CC)C1CCC1',
#  'c1ccc(OCC2CCCCC2)cc1',
#  'CC1CC(C(C)NC(=O)N2CCC(C(=O)c3cc(N)cc(Br)c3)CC2)CC1CO',
#  'CC(=O)NN(C)C(=O)c1ccccc1N1CC[C@H](C)C1',
#  'CCn1cc(CN2CCCCC2C)nn1',
#  'O=C1Cc2ccccc2CCC1CCCCCO',
#  'c1ccc(C2CCCC(Oc3cccn[nH+]3)CNN2)nc1',
#  'C1=CN=C2C(=CN=C3C=CC=CN32)C=C1',
#  'CN1CCCN(CN2CCOCC2)Cc2ccccc21',
#  'C1COC(CCN2CCCC3NCC[NH+]3CCC2)C1',
#  'CC(C)(C)[NH2+]Cc1cc(C(F)(F)F)nc2ccsc12',
#  'O=C(OCCc1ccccc1Cl)N1CCCCC1',
#  'C[SH]1CCCN(Sc2ncccn2)C1',
#  'N#Cc1ccccc1N1CCCC1',
#  'CCNC(C)c1cccc(C(=O)NC(=O)C(=O)NCC(C)(C)C)c1',
#  'c1ccc(CCCSC2CCCNCC2)cc1',
#  'CCOC(C)(C)c1ccc(CNC(=O)Nc2ccccc2C)cc1',
#  'Cc1noc2nncc-2c1CC1CCN2CCO[C]2C1',
#  'C[C@@H]1CCC1NC(=O)NCCOc1ccccc1Cl',
#  'c1ccc(COCCc2ccccc2-c2ccccn2)cc1',
#  'Fc1ccccc1CN1CCN[CH]SCC1',
#  'CC(O)C(C)C[NH+]1CCCCCC1CCC[NH+]1CC1C',
#  'CO[C@@H](C)[C@H]1CCN1Cc1cccnc1',
#  'Cc1ccccc1OCC[C@H]1CC=CCC1',
#  'CC[NH+]C1CCCCC[NH+]1c1ccc(C)cc1F',
#  'Cc1ccccc1C=C(Nc1ccccc1N1CCOC1)[NH+]1CCCCCC1',
#  'Cc1ccccc1Cn1cnnc1C',
#  'BrCCCC1CCN2CCOCC12',
#  'CCC1=C(NC(=O)C(=O)COc2ccc(N)o2)CN(C(=O)C[NH+](C)C)C1',
#  'O=C(Cc1cccnc1)Nc1cccc2cccn1OCCO2',
#  'CCN(CCc1ccccc1)C(C)C(=O)Nc1ccc(Cl)cc1',
#  'CCCCN(Cc1ccccc1O)C1CCNc2ccccc2C1',
#  'Cc1cn(NC(CC2CCCC2)C(=O)F)c(C)n1',
#  'c1ccc2c(c1)CC[NH+](CCN1CCCC1)O2',
#  'CCC(NCc1ccccc1)c1ccccc1C#N',
#  'CC(C)N[C@@H]1CCNC(=O)c2cccnc21',
#  'Cc1cnccc1C1=CC=Cc2ccccc2[NH+]1C',
#  'CCCNC(=O)Nc1cc(N2CCCC2)ccc1F',
#  'CC(CC1CCCC1)NC(=O)C1CNc2ccc(cc2)C1',
#  'COC([NH2+]C1CCC(=O)C(C)(C)C1)C(C)CC(C)(C)C',
#  'CCCCC(=O)NC(=O)N1CCOC(C)(C(C)C)C1',
#  'CCC1CN(Cn2ccnc2)CC(=O)C2NCCC12',
#  'NC1CCCC(CCNC(=O)NCc2ccccc2F)CC1',
#  'c1cncc(CCCN2CCCCCC2)c1',
#  'C[NH+]1CCCCC1NC(c1ccco1)C1CC=CCC1',
#  'CC1CCC1C[NH+]1CCC[NH2+]C1CCC1CCCCOC1',
#  'O=C(Nc1ccccc1SC1CCCC1)N1CCC1',
#  'CC(C1CC(C(=O)Nc2cccc(-n3cccc3)c2)C1)C(C)(C)Cl',
#  'CC(N)CNC(=O)N1CN(CCC(C)(C)O)C(=O)C1C',
#  'CC(C)CC(C(=O)N1CCCN(c2ccccc2)C1)C(C)(C)C',
#  'Fc1ccc(OCCNCc2ccccc2)c(Cl)c1',
#  'CC(C)C1(O)C(=O)CC1CC[NH3+]',
#  'CNC1CC(C)(C(=O)Nc2ccccc2C#N)C1',
#  'CC1CCCC1NC(=O)n1ccc(-c2ccncc2Cl)n1',
#  'CC(O)C(=O)c1ccc([N+][O-])c(C(=O)[O-])c1',
#  'CC1=C(Cl)C(Cl)=C2OC3=C1C=C2C(=O)NCCCN(C(=O)CO)N3',
#  'CN1CCCC(=O)N1CC1CCN(C(=O)C2CCCCC2)C1',
#  'C1=CN=CC2NCCC(c3cnccn3)C2=C1',
#  'c1ccc(N2CCCC(C[NH2+]CN3CCCCC3)C2)cc1',
#  'FC(F)(F)c1ccc(CN2CCNCC2)cc1',
#  'CN1CCC(NC(=O)NC=[NH+]Cc2ccccc2)CNC1=S',
#  'CCN1CCCC2CCC21',
#  'CCCC(O)CCC1CCN(C)CC(=O)N1',
#  'CN(CCOc1ccccc1)C1COc2ccccc2O1',
#  'CC1NC(=O)C(N2CCCc3ccccc3C2)[NH+](C=S)C=C2CCCC21',
#  'CCc1cccnc1SCCCC1CCCC1S',
#  'Cc1snnc1CCC1CCON1C(=O)c1ccccc1',
#  'c1ccc([C@@H]2COCCN2)c(Oc2ccncc2)c1',
#  'COCc1nc(NCc2ccccc2)nnc1Cl',
#  'Cc1ccc(CN2CCCC3C(CC(=O)N4CCCC4)C(=O)C3NC2=O)cc1',
#  'CN1C(=O)NCC(C(C)(C)O)CCC1Cc1ccccc1Cl',
#  'O=C1C=CC(C2CCCCC2)C(N2CC[NH+]2CC2CCOC2)c2ccccc2N1',
#  'C(=CCc1ccccc1-c1ccc(-c2ccccc2)o1)Cc1ccccc1',
#  'COCCCOc1ccccc1OC1CCCCCC1',
#  'COCCc1ccccc1C(C)C(=O)NC1CCc2ccccc2O1',
#  'CC[NH2+]Cc1ncc(F)cn1',
#  'CC1=NC(c2nc(NC(C)C(C)C(C)(C)C)c(C)cc2C)=C1',
#  'CCC(C)COc1ccccc1NCCn1ncnn1',
#  'OCCOc1cccc(C2CCC2)c1',
#  'CN1C[C@@H](O)CN(CC(=O)OC(=O)NCc2ccccc2)C1=O',
#  'CC(O)C(C)CNC(=O)C(C)N1CCS(=O)CN(C2CN(c3ccccc3)CCO2)C1',
#  'CCC(C)(CNc1ccccc1)N(C(=O)c1ccccc1)C(C)C',
#  'CCCC1COCCCC1C[NH+](C)Cc1ccccc1',
#  'CC(=O)CC(C)CCCOC1CC=CN1',
#  'CC(NCC(=O)C(=O)NCc1ccc(F)cc1)C(=O)N(C)C',
#  'CCOC(Cl)[NH2+]CCCc1ccccc1-c1ccccc1',
#  'NC(=O)C1CCCCN1Cc1ccccc1Cl',
#  'c1ccc2c(c1)CCOC1CCC(CCC[NH+]C1)O2',
#  'CCCC(NC(=O)C(=O)Nc1cccc([N+]=O)c1)C1CCC1',
#  'CC1CN(C2CCCCC2)C(=O)CC(=O)N2CCC2C1=O',
#  'COCOc1ccc(C(=O)NC(C)C#N)cc1',
#  'CC(C(=O)NC(=O)Nc1ccc(F)c(F)c1)C(Cl)NCc1cccs1',
#  'O=C(CCCOc1ccccc1)N1CCCCN1Cc1ccccc1',
#  'C[C@H]1CCC[C@H]1OCC[NH2+]C1CCC[C@@H]1Cc1ccon1',
#  'c1cncc(CCNCCc2ccc(N3CCCNCC3)cc2)c1',
#  'c1ccc(CCN2C(CNC3CCC3)CC2[NH+]2CCCN(Cc3ccccc3)CC2)cc1',
#  'O=S(NCC1CCC1c1ccccn1)c1ncc(Br)cc1F',
#  'Cc1cnccc1C(C)(C)NC(=O)C(COc1ccccc1)C1CC1',
#  'c1ccc(OCCCSc2ccc(C3CC3)cn2)cc1',
#  'C#CC1CCC(NC(=O)NCCNC2CCC(N)C2)C1',
#  'CCOc1cc(OCCCNC(=O)Cc2cccc[nH+]2)ccc1C',
#  'Cc1ccc(C(Cl)NC(=O)C2CCN(C(=O)c3ccncc3)C2)cc1',
#  'Cc1cnccc1C(=O)N1CCCCNC(=O)C1',
#  'Clc1ccccc1CCC[NH2+]CC1CCC[NH2+]C1',
#  'CCNC(=O)NC(=O)N(CC(=O)C(C)CC)c1ccccc1F',
#  'CCCSC(C)C(=O)N1CCCC[NH+]1Cc1cccnc1',
#  'O=C(c1ccccc1)c1ccccc1NCc1ccco1',
#  'CCCC(Nc1ccccc1)C1CCCCC1',
#  'CC(C)C(C)[NH2+]CC(C)(C)C(C)(C)C(C)(C)O',
#  'c1ccc(C[NH+]2CCCCN(C3CCCC3c3ncon3)C2)cc1',
#  'CCc1ccccc1/C=N/NC=Cc1ccccc1Oc1cccc(Br)c1',
#  'c1cc(C[NH+]2CCCCC2)c(CCCN2CCCC2)c[nH+]1',
#  'CCN(C1CCCCC1)C1CCN(CC[NH+]2CCC(COC)C2)C1',
#  'c1cc(N2CCCC(CC3CCCCCO3)CC2)ccn1',
#  'CCOCCc1nc2cnccc2nc1CN1CCCCCC1',
#  'CC[NH2+]CCCc1cscc1C(=O)NC(C)CC',
#  'CC(=O)C1=C(C(=O)[O-])N(C)C(c2ccccn2)CCCC1',
#  'CC(=O)NCC(=O)N[C@@H]1CC(=O)N[C@@H](C)N(C(=O)C(C)(C)C)C2(C)C(C)CC12C',
#  'CCCCCSN1CCCCC1',
#  'c1cnc(NCCN2CCCOC2)c(NC2CCCC2)c1',
#  'CC(=O)[SH](Nc1nnccc1C)c1cccc(C)c1',
#  'CO[C@@H]1CCOCC(C)(COc2ccccc2O)C1',
#  'CCOc1cccc(C(=O)CN2CCCC2O)c1',
#  'c1cc2c(c(OCOCCOCC3CCCCC3)c1)CC2',
#  'CCC(C)(C)NC[SH](=O)=NNC(=O)N(C)C(=O)N(C)Cc1cc(C)cc(OC)c1Cl',
#  'c1ccc(NC(CNc2cccc(CSc3cccnc3)c2)c2cnccn2)cc1',
#  'c1ccc(CN[NH2+]CC2CCCCC2)cc1',
#  'NC(=O)CSc1cccc(C(=O)N2CCN(c3ccccc3Cl)C2=O)c1',
#  'c1ccc(OCc2ccccc2CCN2COCCCO2)nc1',
#  'COCCCOC(=O)N1CCN(c2ccc(OC)cn2)C1',
#  'O=C(NCCc1ccccc1F)NSc1ccncc1',
#  'CC(NC(=O)CCN1CCC[NH+](Cc2ccccc2)C1)c1ccco1',
#  'CC1CCC(C)[NH2+]C2(CCCCC2)C1',
#  'O=C1COCCN1C1CCC(NC2C[NH+]CCc3ccccc3C2)C1',
#  'O=C1CCC1C1CCC[NH+]1CCCl',
#  'CC(O)CNC(O)c1cccc(OC(C)(C)C)c1',
#  'N#Cc1ccsc1CCCCNCCc1ccccc1',
#  'CNC(C)=O',
#  'O=C([O-])CCCC1(C(=O)[O-])C(Cc2cccc(F)c2)N1Cc1ccccc1',
#  'CC[NH2+][C@H]1CCCN1CCCCOc1ccccc1F',
#  'CNC1=C2C=NC=C(C)N2OC(NC(=O)CCCSc2ccccc2)=C1',
#  'c1ccc(Cc2cncn2CCNCc2cccs2)nc1',
#  'O=C(NC1CCOCC1)c1nc2nccc(=O)n2[nH]1',
#  'CCOc1ccccc1OCC1CCCCC1Cc1ccsc1',
#  'CC(C)C(C)(C)[NH2+]C(=O)NC(C)(C)C(C)(C)C',
#  'C[NH2+]c1ccccc1COCCOc1ccccc1CNC1CCCCCC1',
#  'O=C(NN[SH](c1ccccc1)c1ccncc1)Sc1ccc(N2CCC2)cc1',
#  'CNc1ccccc1Cc1ccccc1F',
#  'Cc1ncoc1-c1ccccc1F',
#  'Cc1ccccc1-n1ncnc1-c1cccc(Cl)c1',
#  'CC[NH+]1CCN(C(=O)C(C)(C)C)CC(c2ccccc2)C1C(=O)[O-]',
#  'O=C(O)CN1CCOC(C(=O)NC(=O)CC2CC=CCC2)C1',
#  'c1csc(CNCCCCOCC2CCCCCc3ccccc32)c1',
#  'CCN(C)C(Nc1ccc(C)cc1)C(=O)N1CCCC[C@H]1c1ccccc1',
#  'Cc1cccc(C(=O)NC(C)c2ccccc2)c1',
#  'O=[N+]([O-])c1occc1-c1cncc(Cc2ccccc2)n1',
#  'CSCc1cc(C)c(-n2cccc2)cn1',
#  'NC(=O)C(=O)NC(CN1CCCOCC1)C[NH+]1CCCC1CN1CCCCC1',
#  'COC(=O)N(C)C(=O)C(C)(C)c1ccc(Cl)cc1N',
#  'O=C(c1sccc1Cl)N1CC(=O)C(c2ccc(Br)cc2)(c2cccc(Br)c2)C1',
#  'O=C(Nc1ccc2c(c1)OC(c1ccccc1)CCC2)Sc1ccccc1',
#  'CN(C)Cc1ccccc1C(F)(F)[NH2+]Cc1csc(Cl)n1',
#  'Oc1ccc(C(Br)NCc2ccccc2)cc1Cl',
#  'C1=CSN(C2CCCSC2)C=C1',
#  'O=C1CN(C(=O)c2ccccc2)CCc2ccc(-c3ccccn3)cc2N1',
#  'O=C(CCNC(=O)NC[C@H]1CCCS1)Nc1ccc(F)cc1',
#  'CCOCCOc1ccccc1NCCN1CCCCC1',
#  'c1ccc(Oc2ccccc2C2CC2[C@@H]2[NH+]CCCO2)cc1',
#  'O=C1CCS(=O)(=O)NCCC1Cc1ccccc1',
#  'CCC(C)(Cc1ccccc1)Nc1ccccc1N1CCCC1',
#  'C[NH2+][C@@H]([C@H]([NH3+])C(C)C)[C@@H](C)c1cc(C)on1',
#  'COc1ccccc1[C@@H]1CCN[C@@H]2C1=NC=CN2CC1CCOC1CCO',
#  'c1ccc(C[NH+]2CCCCCC2)cc1',
#  'O=C1CCCCCCNC1c1ccccc1Cc1ccon1',
#  'CCC(C)C[NH+]1CCCN(c2ccnc(C)c2)C(C)C(=O)N1',
#  'Fc1ccc[nH+]c1CCN1CCCSC1',
#  '[NH3+]C[C@H]1CCC[C@@H](C=O)N1CCNc1ccccc1[N+](=O)[O-]',
#  'COCCC1CC[NH+]1CCc1ccco1',
#  'CSN(Cc1ccc2c(n1)CC(=O)N2)Cc1ccccc1F',
#  'CCC(CC)CNc1ccccc1F',
#  'CCOc1cccc2c(N[C@H](C)CC)cccc12',
#  'CCc1ccoc1CCCCCN1CCCOC1',
#  'C[C@@H](NC(=O)N1CCC1)c1ccccc1F',
#  'O=C1c2ccccc2CC[NH+]1CCC1CCCC1NCCc1ccccc1',
#  'CC(C)(CNC(=O)NCCCn1cccc1)[NH+]1CCC(=O)C1',
#  'CCN1CCCCCC(N)(c2ccccc2)CC(N)=NS1(=O)=S',
#  'C1COC2CCOC(C2)C(CC2CCOCC2)OC1',
#  'Clc1ccccc1OCCC1CCOCC[NH+]1CC1CCCC1',
#  'Clc1ccc(COc2ccccn2)cc1',
#  'Cc1cccc(C(Cl)NC(C)C(=O)NC2CCCCC2)c1',
#  'COC(=O)C1CC2CCNC1C2',
#  'c1cc2nc(C3CCCCC3)nnc2s1',
#  'O=C1C(CNCc2ccccc2)=Nc2occc21',
#  'CC(=O)NC(C(=O)N1CCC(C)CCO1)C(C)(C)C',
#  'CCc1ccsc1CNCc1cccnc1OC',
#  'C[C@@H]1CC[C@H](CNC(=O)NCCc2ccccn2)C1',
#  'Clc1ccccc1CN1CCCOC1',
#  'C1=CN=C2C3CCCN2C(CCNC2OC(=C1)N=NN=C1C=CC=C12)C3',
#  'Cc1ccnc(COC[NH+]2CCOCC(c3ccccc3)C2)c1',
#  'Cc1nc(CCC2CCNCSC2)c(C)o1',
#  'Cc1c(NC(=O)C(F)CC(F)(F)F)cccc1C(=O)N(C)C',
#  'CCOC=C(C)OC(C)n1c(C)ccc1CC',
#  'CC[C@@H](C)C[C@H]1CC[NH2+][C@@H](c2ccccc2)S1',
#  'NC(=O)Nc1ccccc1C[C@H]1CCCN1C(=O)NC1CCCC1',
#  'COC(NCc1ccccc1C)N1CCN(Br)CC1',
#  'CCC(c1ccccc1)C1CCOCC1Nc1ccccc1',
#  'CCSC(C(=O)Nc1ccccc1Cl)[NH+](C)CC',
#  'CNc1cccn1CC(CSCc1ccccc1)OC',
#  'CC[NH+]1CCCN(CCc2ccccc2)NCC1',
#  'O=C(Nc1ccccc1)c1cc2ccccc2s1',
#  'CC1(c2ccc(-c3cnccn3)nn2)CCC1C(=O)[O-]',
#  'O=C(Nc1ccc(F)cc1)NC(CN1CCC[NH+]CC1)C1CCC1',
#  'CCC[NH+]1CCN(C(CC)n2cncc2C)C1',
#  'CCC[C@H]1C=COC[C@H]1Nn1nc(C)cc1CC',
#  'Clc1ccc(OCC2CCCO2)cc1',
#  'Cc1cscc1CCCC1CCCC1CCC[NH3+]',
#  'CC(=O)C(C)(C)NC(=O)C(=Cc1ccc(Cl)cc1)NC(=O)C(N)=O',
#  'CCC(=O)N[NH+]1CC2C=CC(C)=CC=C2C(CC)C1',
#  'CCCC(c1ccccc1)C(C)C(=O)[NH2+]N1C=CC(C)C1',
#  'CCCCC1=CC=CC(C(F)(F)C(F)F)OC(C)=C1F',
#  'CCCOc1nccnc1CNCC1CCCC1',
#  'O=C(C1CCOc2ccccc2C1)N1CCCCC1',
#  'Cc1ccccc1CCNCCc1ncnn1Cl',
#  'O=C(Nc1ncccc1NCCc1ccccn1)c1ccccc1',
#  'Cc1ccc(N2CCC(CNCC3OCCCS3)C2)c(O)c1C(=O)C(C)(C)C',
#  'C[C@@H]1CCNC1c1nn[nH]c1CCCO',
#  'COC(CN1CCCCC1)NC(=O)CCC(=O)N(C)C',
#  'CC(C)(C)C(=O)NCC(=O)Nc1ccc(Cl)c(F)c1',
#  'CN1C(=O)Cc2ccccc21',
#  'O=C(NCc1ncno1)C(NC1CCCC1)c1ccc(Cl)cc1',
#  'CCCNC(=O)C(=O)NNCC(C)Nc1ccc(F)cc1',
#  'CC[NH+](C)CCc1ccccc1Nc1ccccc1Cl',
#  'CC(C)(O)C1CCC[NH+](CC2CCCC(C[NH3+])C2)CC1[NH3+]',
#  'Fc1ccccc1CNCc1cccc(-c2ccccc2Cl)n1',
#  'c1ccc(C(NCc2ccccn2)c2ccccc2)cc1',
#  'CC(CSc1ccc(F)c(F)c1)SC(=O)Nc1cc(O)cc(CC(N)=O)c1',
#  'Fc1ccccc1COCCN1CCCC1c1ccns1',
#  'C(=CCN1CCCCC1)Cc1ccoc1',
#  'O=C(Nc1ccccc1)N(CCC1C[NH+]1)n1[nH]c2ccccc21',
#  'N#Cc1ccccc1Cc1ncccn1',
#  'c1cc(CN2CCCC2c2ncco2)cc(N2CCOC2)n1',
#  'Clc1ccccc1CC1=NCC1Cl',
#  'Clc1ccc(Br)c(C2CC[NH+]2Cc2nccs2)c1',
#  'C=NC(=O)n1c(=O)c2ccc(Cl)cc2n1CC=Cc1ccccc1',
#  'Fc1ccc(CNCCCc2ccccc2)cc1Cl',
#  'c1ccc2c(c1)NC1CCCC(CCC3COCCC2C3)C1',
#  'CC(=O)CC1NCCC(=O)NCCc2sccc21',
#  'CC1(C2CCCCC2)CCc2[nH+]cccc2N1',
#  'CN(C(=O)C(=O)Nc1ccc(N(C)C)c(CCC2CCC2)n1)C(=O)c1ccccc1',
#  'COc1ccccc1C(=O)Nc1c(C)cccc1C1=NN=[SH]CC1',
#  'CC(=O)NCCCN1CCCOC1',
#  'CC(C)CC1CCN(c2ccncc2)CN1',
#  'OC(CCNc1ccccc1)CCSc1cccc2c1N2',
#  'COc1cc(C[C@]2(CC(=O)[O-])CCC(C)C2)cc(F)c1C',
#  'COCC(=O)N1C=C(NC(=O)c2ccccc2F)[C@H](C)C1',
#  'Cc1ccsc1CC(C)NCc1ccc(Br)nc1',
#  'CC(C)C(CNC(=O)NC(C)(C)O)C[NH+](C)C',
#  'CN(CC1CCCC1)C(=O)Cc1ccccc1',
#  'CC1CCC(CCNC(=O)NC2CN(C[NH+]3CCSCC3)C2)C1',
#  'CCOc1ccccc1CCCN1CCN(c2ccccc2)C1',
#  'CCC(C)(C)N(CC(=O)NC(C)c1ccc(C)c(OC)c1)C(C)=O',
#  'CC(F)(F)F',
#  'O=C1CCC(NC2CCCCOC2)CC1',
#  'CC[NH+](C)CC(=O)N(C)C(C)C(C)[NH+]1CCC(C)CC1',
#  'Cn1nccc1CCCNc1ccccc1CCCO',
#  'CC(C)(C)C(=O)N(C(=O)N1CCCC1)C1CSCCCC1=O',
#  'COC(c1ccc(NC(=O)N2CCCCCC2)cc1)C1CCCC1',
#  'CC1=C(NCC(=O)Cc2ccccc2)C=CN2C=CC=CN12',
#  'c1ccc(CCNc2ccccc2NC2CCCCC2)cc1',
#  'COc1ccccc1NC(=O)C(=O)NNC(=O)C1CCC1',
#  'Cc1nncn1C([NH2+]C1CC1)C(F)C1CCC1',
#  'CCC(C)(CN(C)C(=O)[C]1CCCC[NH+](C)[C@@H]([O-])C1)C(F)(F)F',
#  'CC1CCCN(Cc2ccccc2C#N)C1',
#  'C(CNC1CCCOCC1)=[SH]c1cc2ccccc2o1',
#  'C[NH2+]CC1CCC(C2(C)CCCCN2C(C)=O)C1',
#  'c1ccc(COCc2ccccc2-c2cccnc2)cc1',
#  'C1=[NH+]CCCC1CCCN1CCNC(c2ccccc2)C1',
#  'O=C1CCN(C(=O)C2CCCCCN2)C1',
#  'CCC(C)[SH](C)(=O)N=C(N)C(N)=O',
#  'C[NH+]1CC(c2ccccc2Cc2ccccc2)C1',
#  'Fc1ccccc1OCCCN1CCCC[NH+]1C1CCCOC1',
#  'CC(C)C(C)C(=O)C(C)(C(=O)N1CC1)C(C)c1ncccn1',
#  'CC([NH2+]CC1CCC(C)(C)C1)C1(NCC2CC2)CCCC1',
#  'Cc1cc(CN2CCOC2c2ccccc2F)ccc1NC(=O)N1CCOCC1',
#  'C(=C1Cc2ccccc2[SH]1CCON1CCCCc2ccccc2C1)c1ccccc1',
#  'O=C(CSc1ccnn1CCc1ccccc1)Nc1ccccn1',
#  'Cc1ccc(C(=O)N2CCCN(S(=O)c3sccc3F)CC2)c(C)c1',
#  'c1csc(-c2ccccc2CC2CCOCC2)c1',
#  'COCCn1ncnc1SCCSC(=O)C1CCCC1',
#  'O=C1CCN1c1ccn(CNc2cccnn2)c1',
#  'Fc1c[nH+]ccc1CC1(C2CCN2Cc2ccccc2)CCC1',
#  'O=C1CCCC1CO',
#  '[NH3+]CC1CN(c2ccccc2)CC[NH+]1CC1CCCC1',
#  'CN(C)C(=O)CC1CCN(S(=O)(=O)N2CCCCC2)CCN1',
#  'CC(=O)CN1CCC(=C(NC(=O)c2ccc(C)cc2)c2ccccc2)C1',
#  'CCCC(C)CC(=O)NNC(=O)c1occc1-c1cc[nH]c1',
#  'Clc1ccc(-c2nnnn2-c2ccccc2N2CCOCC2)cc1',
#  'C=CC(C)C(NC(=O)CNC(=O)C(C)CC)NC(=O)N1CCCCC1',
#  'O=C(CC1CCC1)NCC1[NH+]CCCc2ccccc21',
#  'CN(CC(=O)CN1CCCN1CCc1ccccc1)C1CCC1',
#  'CCCC[NH+]1CCC1C1CCN(C(=O)C2CCCSC2)C1',
#  'O=C(CC[NH+]1CCCCC1)N1CCC(c2ccccc2)C1',
#  'Fc1nccnc1Cc1ccccn1',
#  'Cc1ccccc1OCCCOCCC[NH+]1CCCN1Cc1cnccc1Cc1cccnc1',
#  'CN1CCC2=C(Br)C=CSC(=C3C=CN=C1CO3)C=N2',
#  'O=C(CNC1CCC12CCCOC2)Cc1ccccn1',
#  'CCC(O)C[C@]12CCCC[NH+](CC(=O)CCC1)C2',
#  'CCCN(C)CCCNC(=S)NC(=O)CCOC',
#  'O=C(c1ccccc1OCCOc1ccco1)C1CCCC1',
#  'C(CNC1CC2CCC[NH+]2C1)CC1CCCO1',
#  'O=C(NCc1ccccc1)[SH]1CC=CCC2CCC[NH+](CC1)C2',
#  'CC(C)(C)NC(=O)CN1CCCC[C@H]1C=[SH]c1ccccn1',
#  'C1CCC[C@@H]2CCCOC2CC1',
#  'N#C[C@@H]1CCCC[C@@H](NS(=O)(=O)c2ccccc2F)C(=O)N1',
#  'CC1CCN(C(=S)NC(=O)Nc2ccccc2F)C1=O',
#  'c1ccc2c(c1)CC[NH+](CCN1CCCCC1)CCCN2',
#  'CC(C)c1cccc(CNC2CCc3ccccc32)c1',
#  'c1ccc(CCc2cccc(CSc3nccnn3)c2)cc1',
#  'CCCC1(C)C=CCN(c2ccccc2)C(=O)[SH]1C',
#  'CC(=O)c1cccnc1NC1CCN(C(=O)N2CCOCC2)CSC1',
#  'CCC(NC(=O)c1ccc(NCC[NH+]2CCC(C)C2)cn1)c1cnccn1',
#  'CC[NH2+]C1CCCCC1C1CN(c2ccccc2)C1',
#  'COc1ccc(N=C2CCN(C(=O)C(C)Nc3ccccc3)C2[NH3+])cc1',
#  'CCC(=O)NC(C)CC(=O)Nc1nc[nH]c1CSC',
#  'CC[C@@H](C)[C@H](Nc1ccccc1Cl)C(=O)[O-]',
#  'COc1ccc(NC2CCCCC2CCCNCC2CCCOC2)cc1',
#  'C1CCC(C[NH+]2CCCCC2CCNC2CCOCC2)C1',
#  'CC1CCN(CCc2cccc(F)c2)C1',
#  'CCC(C)c1cccc(NC(=O)C(=O)Nc2ccccc2)c1',
#  '[O-]c1nncn1C1CCCN1',
#  'c1ccc(COCCc2[nH]ccc2C2CCN(c3ccccc3)CC2)cc1',
#  'c1ccc(CN2CCN(c3ccccn3)CCN2)cc1',
#  'CC(C)OC(=O)N1CCCO[C@@H]2C=CC=CC=C21',
#  'CC(=O)Cc1cccc(NC(=O)C2CCCC2C(C)F)c1',
#  'CON1CCC[SH](C)(=O)C(=O)C2(C)CCCC[NH+]2C1',
#  'COC(C1=C(Cl)[N+]C=NC=C1)N1CCCCC(C)(OC)C1=O',
#  'Fc1ccncc1',
#  'CCO[C@@H](c1ccccc1F)n1cccc1C',
#  'CC1CCC(C(=S)NC(C)(Cc2ccccc2)NC(=O)C2CC(C)[NH2+]C(C)(C)C2)C1',
#  'O=C(NN1CC[S-]CC1)C1CCCCCC1',
#  'CCC1CC(CO)CC1Cc1ccsn1',
#  'OCC=CCCCCCOc1ccccc1S',
#  'Clc1cccc(C=Cc2ccccc2)c1',
#  'COCCc1ccccc1NC(=O)Cc1ccccc1OC',
#  'CCCOCC1CCCCN1Cc1csc(Br)c1',
#  'NC1c2c(C(=O)[O-])cccc2N2CCCC12',
#  'Cc1ccccc1',
#  'O=C(NCCCC[NH+]1CCCCC1)c1ccccc1',
#  'CC(C)NC(=O)C1NCC(C)(C(=O)C(=O)N(C)C(C)(C)C)CC1C',
#  'CSCCNC(=O)c1ccccc1C1CCCCN1',
#  'COCCN1CCCC(C(N)Cc2ccccc2)C1',
#  'COCC[NH+]1CCCNC1Cc1ccnnc1',
#  'O=C1CC(Nc2ccccc2)=N1',
#  'COc1ccccc1C1c2ccccc2[NH+]1N1CCCC(Oc2ccccc2)C1',
#  'Cc1ccccc1OCOCCC1CCCCCC1',
#  'CCCCc1ncc[nH+]c1N1CCCC1',
#  'COC(=O)N1CCN(CC(=O)NC(=O)[C@@H]2CC(C)[SH]2(C)=O)C1',
#  'c1ccc(Nc2cccn2CCCCc2ccc3ccccc3c2)cc1',
#  'Clc1cccc(CC2CCCC[NH+]2CCc2ccncc2O[C@H]2C=COc3ccccc3O2)c1',
#  'CCCC(C)C1C[NH+]=CCN1C',
#  'CCCCOC1CCCC1CCc1nccc2ccccc12',
#  'O=C1CCN(CCn2cccc2)CC1',
#  'Cc1nc(NC(=O)NC2CCCCC2)ccc1OC(C)(C)C',
#  'O=C1CCN2CCCCC2C1',
#  'CCC(C)NC(=O)N1C2=NC1=C2c1ccccc1CCCOc1ccc(OC)cc1',
#  'CCC(C[NH2+]CC(C)C(=O)N1CCCCC1)[NH+](CC)c1ccccc1',
#  'CC(C)CN(C)C(=S)C1CC(C)NC1=O',
#  'CCN(Cl)CCC1CC[NH+]1CCCc1ccccc1']

# %%
# Task 3: Find out how much overlap there is between the generated SMILES
#         and the training data SMILES (from "zinc.smi")

### YOUR CODE #####
# Hint: you should compare canonical SMILES
def canonicalize_smiles(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        return Chem.MolToSmiles(mol)
    else:
        return None

# Function to compare two lists of SMILES
def compare_smiles_lists(list1, list2):
    # Canonicalize both lists
    canonical_list1 = [canonicalize_smiles(smiles) for smiles in list1]
    canonical_list2 = [canonicalize_smiles(smiles) for smiles in list2]

    # Remove None values (invalid SMILES)
    canonical_list1 = [smiles for smiles in canonical_list1 if smiles is not None]
    canonical_list2 = [smiles for smiles in canonical_list2 if smiles is not None]

    # Find intersection
    intersection = set(canonical_list1).intersection(set(canonical_list2))

    # Calculate Jaccard Index
    union = set(canonical_list1).union(set(canonical_list2))
    jaccard_index = len(intersection) / len(union)
    return jaccard_index

# %%
a = compare_smiles_lists(smiles_list, smiles_generated)
a
# Out:
# 0.0

# %% [markdown]
# This is significant - recall in the beginning of this notebook, we said that all `Molecular Generative Models` can generated molecules **not in the training data**. You've just verified this! 🤩
#
# We also said that `Molecular Generative Models` learn to reproduce the properties of the molecules it is trained on. `ZINC` actually contains a lot of `"drug-like"` molecules, empirically (loosely) following [`Lipinski's Rule of 5`](https://www.sciencedirect.com/science/article/pii/S0169409X96004231). `"drug-likeness"` can be quantified by the [`Quantitative Estimate of Drug-likeness (QED) score`](https://www.nature.com/articles/nchem.1243). Your next task is to verify that the `QED` distribution of the `ZINC` training data is reproduced by the pre-trained model.

# %%
# Task 4: Plot the QED score distribution of ZINC and the generated molecules
# Hint 1: RDKit has a function that computes the QED score
# Hint 2: Normalize your plot so you can see the relative distribution
#         (there are 50000 ZINC molecules compared to only 1000 generated molecules)

### YOUR CODE #####
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import QED
import numpy as np

# Function to compute QED scores
def compute_qed_scores(smiles_list):
    qed_scores = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            qed_scores.append(QED.qed(mol))
    return qed_scores

zinc_qed_scores = compute_qed_scores(smiles_list)
generated_qed_scores = compute_qed_scores(smiles_generated)

# Normalize the distributions
zinc_qed_scores_normalized = np.array(zinc_qed_scores) / len(zinc_qed_scores)
generated_qed_scores_normalized = np.array(generated_qed_scores) / len(generated_qed_scores)

# Plot the distributions
plt.figure(figsize=(10, 6))
plt.hist(zinc_qed_scores, bins=50, alpha=0.5, label='ZINC Molecules', density=True)
plt.hist(generated_qed_scores, bins=50, alpha=0.5, label='Generated Molecules', density=True)
plt.xlabel('QED Score')
plt.ylabel('Normalized Frequency')
plt.title('QED Score Distribution of ZINC and Generated Molecules')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# The QED of the generated molecules overlaps with the training data! (actually the pre-trained model provided wasn't trained to the full extent. "Proper" training of generative models will show even more significant overlap). We refer the reader to this [paper](https://www.nature.com/articles/s41467-022-30839-x) - check out the figures showing overlap! You've now verified that `Molecular Generative Models` reproduce the properties of the molecules in the training data 🤩
#
# Now let's answer the big question from this section: **Is it a `Molecular Generative Model` or a Mime?** Let's recap our findings:
#
# 1. The model can generate `SMILES` that are not in the training data
# 2. The properties of the generated `SMILES` overlap with the training data
#
# The answer is that `Molecular Generative Models` are kind of like a mime. You can generate new molecules that fit into the properties distribution in your training data. When could this be useful? Imagine you have a dataset of molecules with properties in the range that you are interested in. The out-of-the-box `Molecular Generative Models` can give you new molecules within this properties range! **What if you want to generate molecules outside the training data properties distribution?** Turns out what we presented here is the foundation for coupling optimization algorithms which can ***shift*** the probability distribution of the `Molecular Generative Model` to the property ranges you want. Next week, you will see this first-hand with a practical tutorial on `REINVENT`.
#
# Finally, let's just take a look at some of the generated molecules.

# %%
# Task 5: Visually inspect a few of the generated molecules

### YOUR CODE ###

# %% [markdown]
# Let's now show another `Molecular Generative Model` class.

# %% [markdown]
# # 2. Variational Autoencoder (VAE)
#
# *Image was generated using [Stable Diffusion](https://stablediffusionweb.com/#demo). The prompt was "a chef flattens a pancake"*
#
# <div align="middle">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/images/pancakes.png?raw=1" width="500"/>
# </div>
#
# What do pancakes have to do with `VAEs`? (but also let me know where the best pancakes in Lausanne are 🥞) In this section, we present a high-level overview of what `VAEs` do. Imagine you have a stack of pancakes, some with blueberries and some with raspberries. You then take the biggest spatula you can find and squash it such that you can't even distinguish the pancakes from each other anymore - they are all combined together into a giant pancake like in the image. Now imagine the surface of this giant flat pancake. You start looking around and you notice some blueberries and think to yourself, "this must have came from the blueberry pancake originally". You look around some more and you see another piece of pancake but with both blueberries and raspberries. There were no original pancakes with both berries so you conclude that this piece of pancake must have been from a little bit of the blueberry pancake and a little bit of the raspberry pancake.
#
# Remembering this analogy, we now present a high-level overview of `VAEs` starting with a classic image of the model. This particular image is from [Saul Dobilas](https://towardsdatascience.com/vae-variational-autoencoders-how-to-employ-neural-networks-to-generate-new-images-bdeb216ed2c0).
#
# <div align="middle">
# <img src="https://github.com/schwallergroup/ai4chem_course/blob/generative_models/notebooks/05%20-%20Generative%20Models/images/vae.png?raw=1" width="900"/>
# </div>
#
# The `Encoder` takes molecules and converts it into a low-dimensional vector and maps it onto a `Gaussian Distribution`. Recall that `Gaussian Distributions` are completely defined by their `mean` and `variance`. Specifically, knowing both the `mean` and `variance` allows you to construct the full `Gaussian Distribution`. The `Latent Vector` is now computed based on the `mean` and `variance` but with some noise added to it. In the image, this noise is drawn from a `Gaussian Distribution`. The job of the `Decoder` is to take this `Latent Vector` and `reconstruct` the input.
#
# Let's tie this back to the pancakes analogy. By converting all molecules into a low-dimensional vector via the `Encoder`, a continuous `Latent Space` is created. We squash all our blueberry and raspberry pancakes into a single giant pancake (we take all our molecules and "flatten" them). The model can be trained to `reconstruct` the blueberry pancake (some molecule) given the squashed blueberry pancake (the `Latent Vector`). What happens when you get to the pancake piece that has both blueberries and raspberries? By defining a continuous `Latent Space`, the `reconstructed` molecule from this chunk of pancake is a hybrid between blueberry and raspberry. This is where the `Generative Molecular Model` comes in: by sampling `Latent Vectors` from the `Latent Space`, the `Decoder` can `reconstruct` different molecules back!
#
# In the [original molecular `VAE` paper](https://pubs.acs.org/doi/10.1021/acscentsci.7b00572), they train a neural network model to predict properties in the `Latent Space`. They also show how you can move in the `Latent Space` to go from some starting molecule to another molecules with desired properties. Here, we omit further details and instead try to visually demonstrate what the `Latent Space` is.

# %% [markdown]
# **Note:** All the code from this section is taken from
# [Akshay Subramanian](https://aksub99.github.io/) who reimplemented the original [VAE](https://pubs.acs.org/doi/10.1021/acscentsci.7b00572) in `PyTorch` in this [Jupyter notebook](https://github.com/aksub99/molecular-vae/blob/master/Molecular_VAE.ipynb)
#
# The code is shown here but you do not have to go over anything/everything. It is shown here to highlight the key steps that occur. Some comments have been added to map the big idea of what is happening back to the `VAE` image above.
#
# **Further Note:** There are no tasks in this section

# %%
# imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import gzip
import pandas
import h5py
import numpy as np
from __future__ import print_function
import argparse
import os
import h5py
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn import model_selection

# %%
# these are utility functions
def one_hot_array(i, n):
    return map(int, [ix == i for ix in xrange(n)])

def one_hot_index(vec, charset):
    return map(charset.index, vec)

def from_one_hot_array(vec):
    oh = np.where(vec == 1)
    if oh[0].shape == (0, ):
        return None
    return int(oh[0][0])

def decode_smiles_from_indexes(vec, charset):
    return b"".join(map(lambda x: charset[x], vec)).strip()

def load_dataset(filename, split = True):
    h5f = h5py.File(filename, 'r')
    if split:
        data_train = h5f['data_train'][:]
    else:
        data_train = None
    data_test = h5f['data_test'][:]
    charset =  h5f['charset'][:]
    h5f.close()
    if split:
        return (data_train, data_test, charset)
    else:
        return (data_test, charset)

# %%
# the main code for the VAE
class MolecularVAE(nn.Module):
    def __init__(self):
        super().__init__()

        # encoder related blocks
        self.conv_1 = nn.Conv1d(120, 9, kernel_size=9)
        self.conv_2 = nn.Conv1d(9, 9, kernel_size=9)
        self.conv_3 = nn.Conv1d(9, 10, kernel_size=11)
        self.linear_0 = nn.Linear(70, 435)
        self.linear_1 = nn.Linear(435, 292)
        self.linear_2 = nn.Linear(435, 292)

        # decoder related blocks
        self.linear_3 = nn.Linear(292, 292)
        self.gru = nn.GRU(292, 501, 3, batch_first=True)
        self.linear_4 = nn.Linear(501, 33)

        # activation function
        self.relu = nn.ReLU()

    def encode(self, x):
        # forward pass through encoder (pancake squashing!)
        x = self.relu(self.conv_1(x))
        x = self.relu(self.conv_2(x))
        x = self.relu(self.conv_3(x))
        x = x.view(x.size(0), -1)
        x = F.selu(self.linear_0(x))
        return self.linear_1(x), self.linear_2(x)

    def sampling(self, z_mean, z_logvar):
        # recall in the VAE figure, noise is added
        # epsilon is the noise
        epsilon = 1e-2 * torch.randn_like(z_logvar)
        # return the latent vector (this is what the decoder will use to reconstruct the input)
        return torch.exp(0.5 * z_logvar) * epsilon + z_mean

    def decode(self, z):
        # forward pass through decoder to go from latent vector back to a molecule
        z = F.selu(self.linear_3(z))
        z = z.view(z.size(0), 1, z.size(-1)).repeat(1, 120, 1)
        output, hn = self.gru(z)
        out_reshape = output.contiguous().view(-1, output.size(-1))
        y0 = F.softmax(self.linear_4(out_reshape), dim=1)
        y = y0.contiguous().view(output.size(0), -1, y0.size(-1))
        return y

    def forward(self, x):
        # the overall forward pass takes the input, passes it to the encoder and then decoder
        # first encode your input to get the mean and variance of the Gaussian distribution it is mapped to
        z_mean, z_logvar = self.encode(x)
        # get the latent vector taking the mean and variance above and adding noise t it
        z = self.sampling(z_mean, z_logvar)
        # decode the latent vector, z, to reconstruct a molecule
        return self.decode(z), z_mean, z_logvar

def vae_loss(x_decoded_mean, x, z_mean, z_logvar):
    # the loss function is a combination of 2 quantities:
    #     1. "reconstruction loss" which measures how different the reconstructed molecule
    #        is to the original. We would want them to be similar

    #     2. "Kullback–Leibler (KL) divergence". We are trying to approximate the distribution
    #         of the latent vector with a Gaussian distribution. The KL divergence measure how "off" we are
    reconstruction_loss = F.binary_cross_entropy(x_decoded_mean, x, size_average=False)
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp())
    return reconstruction_loss + kl_loss

# %%
# this was used when we pre-trained the VAE
# it initializes a PyTorch DataLoader so we can read batches of molecules at a time during training
data_train, data_test, charset = load_dataset('molecular-vae/data/processed.h5')
data_train = torch.utils.data.TensorDataset(torch.from_numpy(data_train))
train_loader = torch.utils.data.DataLoader(data_train, batch_size=500, shuffle=True)

# %%
# initiate an instance of the MolecularVAE
pretrained_vae = MolecularVAE()
# load the pre-trained model (we provide this)
pretrained_vae.load_state_dict(torch.load('pretrained.vae.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Starting below, we will visualize the `Latent Space`.

# %%
# RERUN HERE FOR NEW MOLECULES!
# this bit of code randomly takes 500 molecules from the training data
for batch in train_loader:
    training_data_molecules = batch

# %%
# manually add some noise to the training data molecules --> we will see
# what these "noised" molecules look like in the latent space later
num_noised = 10

noised_molecules = training_data_molecules[0][:num_noised] + torch.normal(0, 0.0001, (num_noised, 120, len(charset)))

# %%
# this bit of code gets the SMILES back from the 500 training data molecules we got above
smiles_list = []
for idx in range(training_data_molecules[0].shape[0]):
    vector = training_data_molecules[0][idx].reshape(1, 120, len(charset)).argmax(axis=2)[0]
    smiles = decode_smiles_from_indexes(vector, charset)
    smiles = str(smiles).replace("'", '').replace('b', '')
    smiles_list.append(smiles)

# %%
# this bit of code gets the SMILES from the "noised" training data molecules
noised_smiles_list = []
for idx in range(noised_molecules.shape[0]):
    vector = noised_molecules[idx].reshape(1, 120, len(charset)).argmax(axis=2)[0]
    smiles = decode_smiles_from_indexes(vector, charset)
    smiles = str(smiles).replace("'", '').replace('b', '')
    noised_smiles_list.append(smiles)

# %%
# encode the training data SMILES
z_mean, z_logvar = pretrained_vae.encode(training_data_molecules[0])
# get the latent space
latent_space = pretrained_vae.sampling(z_mean, z_logvar)

# encode the noised data
noised_z_mean, noised_z_logvar = pretrained_vae.encode(noised_molecules)
# get the latent space of the "noised" molecules
noised_latent_space = pretrained_vae.sampling(noised_z_mean, noised_z_logvar)

# %%
# the code here plots an interative latent space - hover around the space and explore the molecules!
import plotly
import plotly.express as px
import molplotly
import pandas as pd

all_smiles = smiles_list + noised_smiles_list
full_latent_space = torch.vstack([latent_space, noised_latent_space])

plotting_df = pd.DataFrame({'smiles': all_smiles,
                           'group': ['Training Data']*500 + ['Sampled from Latent Space']*num_noised,
                           'latent_space_x': full_latent_space[:, 0].detach(),
                           'latent_space_y': full_latent_space[:, 1].detach()})

fig_scatter = px.scatter(plotting_df,
                         x='latent_space_x',
                         y='latent_space_y',
                         color='group')

app_scatter = molplotly.add_molecules(fig=fig_scatter,
                                      df=plotting_df,
                                      smiles_col='smiles',
                                      title_col='group',
                                      color_col='group')

app_scatter.run_server(mode='inline', height=400)

# the red points are the "sampled" molecules created from adding "noise" to the latent vectors of the
# training data molecules. Here, let's bring back the analogy of the blueberry and raspberry pancakes.
# Locate a red point and look at the training data points around it. You should be able to see some
# structural similarities. One can think of the red point as a "hybrid" between its surrounding neighbours
# of blue points, i.e., it's a hybrid between blueberry and raspberry

# Note: it could be that sometimes "close" points are not that similar - this has to do with the "smoothness"
#       of the latent space such that there are abrupt changes

# Finally, if you want to see new molecules, re-run the cell above marked with "RERUN HERE FOR NEW MOLECULES!"
